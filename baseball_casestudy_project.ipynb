# %% [markdown]
# # EXECUTIVE SUMMARY
#
# 1. Optimum Machine Model Chosen:
# 2. Accuracy Score:
# 3. Cross Validation Score:
# 4. Final Accuracy Score(After Hyperparamter Tunning):
# 5. RMSE:
# 6. Key Operations executed: Exploratory Data Analysis(EDA), Data Preprocessing(Univariate,Bivariate,Multivariate), Metrics Measurement, Model Execution and Hyperparameter Tunning

# %% [markdown]
# # PROJECT CONTENTS
# - Problem Statement
# - Domain Knowledge
# - Step 1: Attributes of Variables
# - Step 2: LOAD DATA SET, DATA DESCRIPTIVE ANALYSIS AND OBSERVATIONS
#      - 2.1:Import all necessary libraries
#      - 2.2:Load Dataset
#      - 2.3:Descriptive Analysis
#      - 2.4:Observations
# - Step 3: Exploratory Data Analysis
#      - 3.1:Encoding
#      - 3.2:Normal Distribution Check(Univariate Analysis)
#      - 3.3:Scatter Plot Check(Bivariate Analysis)
#      - 3.4:Correlation Check(Collinearity and Multicollinearity)- Multivariate Analysis
#      - 3.5:Outlier Check
#      - 3.6:Skewness Check
#      - 3.7:Categorical Variable(s) Check
# - Step 4: DATA PREPROCESSING
#      - 4.1:Removal of Duplicates
#      - 4.2:Dropping of Features that strongly promotes multicollinearity(VIF)
#      - 4.3:Removal of Outliers
#      - 4.4:Transforming Data to Remove Skewness using Power transformation
#      - 4.5:Seperating the datasets into X and Y variables
# - Step 5: MODEL BUILDING
#      - 5.1:Linear Regression
#      - 5.2:RandomForest Regressor
#      - 5.3:AdaBoost Regressor
#      - 5.4:GradientBoosting Regressor
#      - 5.5:XGBoost Regressor
#      - 5.6:ExtraTrees Regressor
#      - 5.7:Support Vector Regressor(SVR)
# - Step 6:COMPARING ALL MACHINE LEARNING MODELS
#      - 6.1:Comparing Differences between Accuracy and Cross_Validation Scores...
#      - 6.2:Conclusion on Choice of Model
# - Step 7:HYPERPARAMETER TUNNING
# - Step 8:MODEL SAVING

# %% [markdown]
# # PROBLEM STATEMENT(Baseball Case Study)
#
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# -- Output: Number of predicted wins (W)
#
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics
#
# For downloading the dataset, use the link given below.
# Downlaod Files:
#
#     https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/baseball.csv

# %% [markdown]
# # Domain Knowledge
# This is critical stage in any machine learning process. It involves brainstorming and coming up with as many hypothesis as possible about what could affect the target variable. It facilitates in exploring the data at hand more efficiently and effectively. Domain Knowledge should be done before seeing the data or else we will end up with biased hypotheses. Below are some anticipated assertions on the problem statement.
#
# - The dataset is made up of only 30 records.
# - The base ball game is a highly technical game,
# Below in the attritbutes of variable we can see a brief explanation of what the game is all about and all the important terms of the game

# %% [markdown]
# # Step 1 - ATTRIBUTES OF VARIABLES
# 1. Runs:A player is awarded a run if he crosses the plate to score his team a run. When tallying runs scored, the way in which a player reached base is not considered. If a player reaches base by an error or a fielder's choice, as long as he comes around to score, he is still credited with a run. If a player enters the game as a pinch-runner and scores, he is also credited with a run.
#
# 2. At Bats:An official at-bat comes when a batter reaches base via a fielder's choice, hit or an error (not including catcher's interference) or when a batter is put out on a non-sacrifice. (Whereas a plate appearance refers to each completed turn batting, regardless of the result.)
#
# 3. Hits:A hit occurs when a batter strikes the baseball into fair territory and reaches base without doing so via an error or a fielder's choice. There are four types of hits in baseball: singles, doubles, triples and home runs. All four are counted equally when deciphering batting average. If a player is thrown out attempting to take an extra base (e.g., turning a single into a double), that still counts as a hit.
#
#
# 4. Doubles:A batter is credited with a double when he hits the ball into play and reaches second base without the help of an intervening error or attempt to put out another baserunner.
#
#
# 5. Triples:Often called "the most exciting play in baseball," a triple occurs when a batter hits the ball into play and reaches third base without the help of an intervening error or attempt to put out another baserunner.
#
# 6. Homeruns:A home run occurs when a batter hits a fair ball and scores on the play without being put out or without the benefit of an error.In almost every instance of a home run, a batter hits the ball in the air over the outfield fence in fair territory. In that situation, the batter is awarded all four bases, and any runners on base score as well. The batter can circle the bases at his leisure, as there is no threat of him being thrown out. (This also occurs when the ball hits the foul pole in left or right field, or when the ball hits an opposing defender on the fly and bounces directly over the wall in fair ground.)
#
#
# 7. Walks:A walk (or base on balls) occurs when a pitcher throws four pitches out of the strike zone, none of which are swung at by the hitter. After refraining from swinging at four pitches out of the zone, the batter is awarded first base. In the scorebook, a walk is denoted by the letters BB.
#
#
# 8. Strikeouts:A strikeout occurs when a pitcher throws any combination of three swinging or looking strikes to a hitter. (A foul ball counts as a strike, but it cannot be the third and final strike of the at-bat. A foul tip, which is caught by the catcher, is considered a third strike.)The batter is automatically out on a strikeout, unless the catcher does not cleanly hold onto the baseball or if the baseball hits the dirt. If the catcher does not catch the third strike, the batter may attempt to run to first base -- if it is open or if there are two outs. However, even if the batter reaches first base safely, the pitcher and the batter are still credited with a strikeout in the scorebook.
#
# 9. Stolen Bases:A stolen base occurs when a baserunner advances by taking a base to which he isn't entitled. This generally occurs when a pitcher is throwing a pitch, but it can also occur while the pitcher still has the ball or is attempting a pickoff, or as the catcher is throwing the ball back to the pitcher.
#
# 10. Runs Allowed:Runs allowed per nine innings pitched -- the title says it all. It's basically ERA with the "E" removed.
#
# 11. Earned Runs:An earned run is any run that scores against a pitcher without the benefit of an error or a passed ball. Often, it is the judgment of the official scorer as to whether a specific run would've scored without the defensive mishap.
#
# 12. Earned Run Average: Earned run average represents the number of earned runs a pitcher allows per nine innings -- with earned runs being any runs that scored without the aid of an error or a passed ball. ERA is the most commonly accepted statistical tool for evaluating pitchers
#
# 13. Shutouts:A starting pitcher is credited with a shutout when he pitches the entire game for a team and does not allow the opposition to score. By definition, any pitcher who throws a shutout is also awarded a win. Because he recorded every out for his team and didn't allow a run, his team could only have won
#
# 14. Saves:A save is awarded to the relief pitcher who finishes a game for the winning team, under certain circumstances. A pitcher cannot receive a save and a win in the same game.
#
# 15. Complete Games:A pitcher earns a complete game if he pitches the entire game for his team regardless of how long it lasts. If the game is shortened by rain or if it lasts into extra innings, it counts as a complete game if the pitcher was the only pitcher to record an appearance for his team
#
# 16. Errors:In baseball statistics, an error is an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out.
#
#
#
# # About the Target/Label:
# 17. Number of predicted wins (W): This is the target variable and has the following properties:In Major League Baseball, a win (denoted W) is generally credited to the pitcher for the winning team who was in the game when they last took the lead. A starting pitcher must generally complete five innings to earn a win.

# %% [markdown]
# # Step 2 - IMPORT ALL NECESSARY LIBRARIES, LOAD DATA SET, DATA DESCRIPTIVE ANALYSIS AND OBSERVATIONS

# %% [markdown]
# # Step 2.1 - Import all necessary libraries

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor,ExtraTreesRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler,power_transform,PowerTransformer,LabelEncoder,OrdinalEncoder
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV, RandomizedSearchCV
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score, classification_report, plot_roc_curve,mean_squared_error,mean_absolute_error
from scipy.stats import zscore
from collections import Counter
from sklearn import metrics
import seaborn as sns
import matplotlib.pyplot as plt
import pickle


import warnings
warnings.filterwarnings('ignore')

# %%
# Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, 
# Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA) 
# Shutouts, Saves, Complete Games and Errors
# Output: Number of predicted wins (W)

# %% [markdown]
# # Step 2.2 - Load Dataset

# %%
#Load dataset
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
#checking the first five rows
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
#checking the last five rows
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
#picking 4 random samples
df.sample(4)
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO  SB   RA   ER   ERA  CG  \
# 23   67  573  5420  1361  251  18  100  471  1107  69  760  698  4.41   3
# 12   85  661  5417  1331  243  21  176  435  1150  52  675  630  3.94   2
# 4    74  689  5605  1515  289  49  151  455  1259  83  803  746  4.64   7
# 15  100  647  5484  1386  288  39  137  506  1267  69  525  478  2.94   1
#
#     SHO  SV   E
# 23   10  44  90
# 12   12  46  93
# 4    12  35  86
# 15   15  62  96

# %% [markdown]
# # Step 2.3 - Data Descriptive Analysis

# %%
#checking the data shape and number of records(features and label)
df.shape
# Out:
# (30, 17)

# %%
#checking for nature of datatypes and the number of data types
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
#Checking data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#Checking data description for all numerical columns and statistics of the dataset
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
#lets check the columns
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
#Checking for null values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
#Checking for null values
df.isnull().sum().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# # Step 2.4 - Observations
#
#
# # The Entire Dataset is made up of;
# - 30 rows and 17 columns
# - 16 features and 1 Target
# 1. Runs:
# - It is made up of Continous data
# - It has no null values
# - Its Datatype is an integer type
#
# 2. At Bats:
# - It is made up of Continuos data
# - It has no null values
# - Its Datatype is an floating type
#
# 3. Hits:
# - It is made up of Continous data
# - It has no null values
# - Its Datatype is an integer type
#
# 4. Doubles:
# - It is made up of Continous data
# - It has no null values
# - Its Datatype is an integer type
#
# 5. Triples:
# - It is made up of Continous data
# - It has no null values
# - Its Datatype is an integer type
#
# 6. Homeruns:
# - It is made up of Continous data
# - It has no null values
# - Its Datatype is an integer type
#
# 7. Walks:
# - - It is made up of Continous data
# - It has no null values
# - Its Datatype is an integer type
#
# 8. Strikeouts:
# - It is made up of Continous data
# - It has no null values
# - Its Datatype is an integer type
#
# 9. Stolen Bases:
# - It is made up of Continous data
# - It has no null values
# - Its Datatype is an integer type
#
# 10. Runs Allowed:
# - It is made up of Continous data
# - It has no null values
# - Its Datatype is an integer type
#
# 11. Earned Runs:
# - It is made up of Continous data
# - It has no null values
# - Its Datatype is an integer type
#
# 12. Earned Run Average:
# - It is made up of Continous data
# - It has no null values
# - Its Datatype is an float type
#
# 13. Shutouts:
# - It is made up of Continous data
# - It has no null values
# - Its Datatype is an integer type
#
# 14. Saves:
# - It is made up of Continous data
# - It has no null values
# - Its Datatype is an integer type
#
# 15. Complete Games:
# - It is made up of Continous data
# - It has no null values
# - Its Datatype is an integer type
#
# 16. Errors:
# - It is made up of Continous data
# - It has no null values
# - Its Datatype is an integer type
#
#
#
# # About the Target/Label:
# 17. Number of predicted wins (W): This is the target variable and has the following properties:
# - It has no null values
# - Its Datatype is a integer type
# - It is made up of Continuos data
#
#
# **Since the target is made up of a continuos data hence this is a REGRESSION PROBLEM!

# %% [markdown]
# # Step 3 - EXPLORATORY DATA ANALYSIS(EDA) AND VISUALIZATION
# The objectives of the EDA is to ensure;
# 1. Independent Features will have a normal distribution using Data Transformation to remove skewness
# 2. Datasets will have the same scale using Normalization and Standardization
# 3. Column mean will be zero
# 4. Standard Deviation of the data should be 1

# %%
# looking at top 5 data
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
# looking at bottom 5 data

df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
# random sample of entire data
df.sample(10)
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 1   83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 24  63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 23  67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 4   74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 3   76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 21  83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22  71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 0   95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 13  76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
#
#     SHO  SV    E
# 1    12  45   86
# 27   12  44   86
# 24    7  35  117
# 23   10  44   90
# 4    12  35   86
# 3     9  37  101
# 21   13  41   90
# 22   12  35   77
# 0     8  56   88
# 13   12  45   94

# %%
# statistics of dataset
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# # Step 3.1 - Normal Distribution Check(Univariate Analysis)

# %%
#Check for normal distribution and see how data is distributed for every column
plt.figure(figsize=(15,8), facecolor='blue')#dimension and color
plotnumber = 1 #like a form of counter which we will see its relevance in the ‘for loop’

for column in df:#triggering your for loop
    if plotnumber<=17:
        ax = plt.subplot(4,5,plotnumber)#2,3 means arrange the graphs in 3-rows and 4-columns spaces as seen below while plotnumber means plot graphs
        sns.distplot(df[column])#performing a distribution plot for all the columns
        plt.xlabel(column,fontsize=20)#labelling the x-axis with their respctive column names with a font size of 20
    plotnumber+=1#incrementals for plot number so as to allow ploting one by one until it gets to 12
plt.tight_layout()#This is just to show you data in a compact form.

# %% [markdown]
# # Observations on Normal Distribution Check
# From the above density plot:
# - We must take into consideration this fact that a gausian distribution(bell like shape) is required for a machine learning model to function properly.
# - As we can see all the visual representation of the distribution of the features is in tandem with a normalized curve and we can see a normal distribution in all of them
#
# - The normal distribution of the wins columns has no contribution to our Model Building since its the Target variable

# %%
#extracting only the features(without the Label) from the original dataset and store in features
features=df.drop(columns=['W'],axis=1)
features
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# 11  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5   13
# 12  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2   12
# 13  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6   12
# 14  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5   15
# 15  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1   15
# 16  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0   13
# 17  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6   21
# 18  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1    7
# 19  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2    8
# 20  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1   14
# 21  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4   13
# 22  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0   12
# 23  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3   10
# 24  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1    7
# 25  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6   21
# 26  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7   18
# 27  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1   12
# 28  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1    6
# 29  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4    4
#
#     SV    E
# 0   56   88
# 1   45   86
# 2   38   79
# 3   37  101
# 4   35   86
# 5   34   88
# 6   48   93
# 7   43   77
# 8   60   95
# 9   40   97
# 10  45  119
# 11  39   85
# 12  46   93
# 13  45   94
# 14  28  126
# 15  62   96
# 16  54  122
# 17  48  111
# 18  40  116
# 19  35   90
# 20  50   88
# 21  41   90
# 22  35   77
# 23  44   90
# 24  35  117
# 25  47   75
# 26  41   78
# 27  44   86
# 28  41   92
# 29  36   95

# %%
#Check for the relatinship between each features and Target
plt.figure(figsize=(15,8), facecolor='blue')#dimension and line color
plotnumber = 1 #like a form of counter which we will see its relevance in the ‘for loop’

for column in features:#triggering your for loop
    if plotnumber<=17:#since there are 3 features
        ax = plt.subplot(4,5,plotnumber)#3,4 means arrange the graphs in 3-rows and 3-columns spaces as seen below while plotnumber means plot graphs
        sns.scatterplot(x=features[column],y=df['W'])#performing a relationship plot between features and label
        plt.xlabel(column,fontsize=20)#labelling the x-axis with their respctive column names with a font size of 20
    plotnumber+=1#incrementals for plot number so as to allow ploting one by one until it gets to 12
plt.tight_layout()#This is just to show you data in a compact form.

# %% [markdown]
# # Observations on Scatter Plot
#
# From the above scatter plot we can see a strong relationship between most of the features and the Label(Number of Wins)
# There is a need to further check for relationship between the features and the label.We will have to perform a correlation check by using a heatmap to check for correlation between the features and the label

# %% [markdown]
# # Step 3.5 - Count Plot Check(Bivariate Analysis)
# - This is not really necessary because we do not have any feature that is categorical in nature

# %% [markdown]
# # Step 3.6 - Correlation Check(Collinearity and Multicollinearity)- Multivariate Analysis;
#  - Collinearity Between Feature and Label
#  - Multicolinearity between features
#
# Lets see/visualize the correlation between (Features vs Label) and (Features vs Features)

# %%
#checking for general correlation
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %%
#checking for correlation between each features and Label
df.corr()['W'].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %%
#Plotting a bar chart to visualize correlation through the stand-alone bars
plt.figure(figsize=(15,8))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='barh', color='b')
plt.show()

# %% [markdown]
# # Multicollinearity Check

# %%
#Plotting a heatmap to show correlation through the brightness of the map-squares
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True, linewidth=0,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# As we can see,most features DO NOT share a 'direct relationship' between each other! as the majority of the map-squares are not bright! But lets conlcude with our findings first:

# %%
#lets also consumate further our quest for Multicollinearity check by ploting a pair plot
sns.pairplot(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation between features and label.
df.corr()['W'].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %% [markdown]
# # Observations on Correlation(Collinearity & Multicollinearity)
# From the above correlation statistics below;
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Collinearity:
#  - Runs has a positive correlation of 43% with the target column which can be considered as a moderate bond
#  - At Bats  has a negative correlation of 9% with the target column which can be considered as a weak bond
#  - Hits  has a negative correlation of 3% with the target column which can be considered as a weak bond
#  - Doubles has a positive correlation of 43% with the target column which can be considered as a moderate bond
#  - Triples  has a negative correlation of 25% with the target column which can be considered as a moderate bond
#  - Homeruns  has a positive correlation of 31% with the target column which can be considered as a moderate bond
#  - Walks  has a positive correlation of 48% with the target column which can be considered as a  moderate bond
#  - Strikeouts  has a positive correlation of 11% with the target column which can be considered as a poor bond
#  - Stolen Bases  has a negative correlation of 81% with the target column which can be considered as a strong bond
#  - Runs Allowed   has a negative correlation of 81% with the target column which can be considered as a strong bond
#  - Earned Run Average  has a negative correlation of 82% with the target column which can be considered as a strong bond
#  - Earned Runs  has a negative correlation of 81% with the target column which can be considered as a strong bond
#  - Shutouts has a positive correlation of 11% with the target column which can be considered as a weak bond
#  - Saves  has a positive correlation of 57% with the target column which can be considered as a good bond
#  - Complete Games  has a positive correlation of 66% with the target column which can be considered as a good bond
#  - Errors  has a negative correlation of 9% with the target column which can be considered as a poor bond
#
#
#
#  - Feature with Maximum correlation = '82%'
#  - Feature with Minimum correlation = '-0.1%'
#
# Multicollinearity:
#  - From the heatmap we can see that the ALMOST ALL pairs of features DOES NOT have noticeable correllation between them
#
# But we will reconfirm this during further steps by finding the Variance Inflation Factor(VIF)
#
#
# NB: Multicollinnearity means two variables are explaining the same thing, meaning one of them is useless and therefore we have to drop one of them!

# %% [markdown]
# # Step 3.4 - Outlier Check

# %%
#Check for allien-datapoints in each features data which has been stored in the dataframe; 'features_continuos'
plt.figure(figsize=(20,10))#dimension only
graph = 1 #like a form of counter which we will see its relevance in the ‘for loop’

for column in df:#triggering your for loop
    if graph<=12:#this was made 8 just to allow for 4 spaces
        plt.subplot(3,4,graph)#3,4 means arrange the graphs in 3-rows and 4-columns spaces as seen below while plotnumber means plot graphs
        ax=sns.boxplot(data=df[column])#performing a box plot for all columns
        plt.xlabel(column,fontsize=10)#labelling the x-axis with their respctive column names with a font size of 20
    graph+=1#incrementals for plot number so as to allow ploting one by one until it gets to 12
plt.tight_layout()#This is just to show you data in a compact form.

# %% [markdown]
# # Observations on Outlier Check
#  - From the above visualization plot its evident that there are no outliers and this also validates the first visualisation we did on the distribution.The distribution is normal so from the distribution there are no outliers
#  -This Data is looking very good for further analysis.
#  - But lets do one more thing,lets check for the skewness of the data

# %% [markdown]
# # Step 3.5 - Skewness Check

# %%
#Visualizing for skewness...
plt.figure(figsize=(20,10), facecolor='yellow')#dimension and line color
plotnumber = 1 #like a form of counter which we will see its relevance in the ‘for loop’

for column in df:#triggering your for loop
    if plotnumber<=17:
        ax = plt.subplot(4,5,plotnumber)
        sns.distplot(df[column])#performing a distribution plot for all the columns
        plt.xlabel(column,fontsize=20)#labelling the x-axis with their respctive column names with a font size of 20
    plotnumber+=1#incrementals for plot number so as to allow ploting one by one until it gets to 12
plt.tight_layout()#This is just to show you data in a compact form.

# %%
#Checking for skewness in each independent variable data which has been stored in the dataframe; 'features'
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# # Observations on Skewness Check:
# Lets assume Skewness threshold is taken as +/-0.50.Meaning any value outside +/-0.50 contains skewness. Hence the below features are skewed:
#
# - Errors
# - Saves
# - Shutouts
# - Hits
# - Complete games
# - Runs

# %% [markdown]
# # Step 4 - DATA PREPROCESSING

# %% [markdown]
# # Step 4.1 - Removal of Duplicates and Unwanted Column

# %%
#Recheking shape of original data
df.shape
# Out:
# (30, 17)

# %%
#Remove duplicates
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (30, 17)

# %% [markdown]
# It appears there are no duplicates since there is no change in the number of rows!

# %% [markdown]
# # Step 4.2 - Dropping of Features that strongly promotes multicollinearity(VIF)

# %%
#Lets have a view of the heatmap again with particular focus on map-squares that are more brightened
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True, linewidth=0,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the heatmap above we can see that there is Visible multicolinearity between the features which is not good for us.
#
# However, lets reconfirm by calculating the Variance Inflation Factor(VIF)!

# %% [markdown]
# # Variance Inflation Factor(VIF)
#
# To solve this multicollinearity problem, we have to first scale our data using Standard Scaler

# %%
X=df.drop(columns=['W'])
Y=df['W']

# %%
scalar=StandardScaler()
X_Scaled = scalar.fit_transform(X)
X_Scaled
# Out:
# array([[ 0.61907797,  0.84773126,  1.66368512,  1.42017307,  1.04119304,
#         -0.7872986 , -1.53490242, -2.69762957,  0.91388329, -0.66623393,
#         -0.50511008, -0.50695519, -0.5398062 , -0.81462859,  1.67160651,
#         -0.46146963],
#        [ 0.13443166, -0.71109353, -0.97068076,  0.12740339,  1.23580856,
#         -0.24396668, -0.5365919 ,  0.15487844, -0.60182558,  0.16597077,
#          0.24892985,  0.25459752, -0.5398062 ,  0.1728    ,  0.24987932,
#         -0.60719689],
#        [-0.33290586, -1.1152333 , -0.15189137,  1.58879521, -0.22380785,
#         -0.56311315, -0.52935379,  1.3004422 ,  1.6539429 , -0.26711238,
#         -1.1901059 ],
#        [ 0.54984278,  1.91581492,  1.61028582,  0.80189192,  1.6250396 ,
#         -0.30788808,  0.37258375,  0.62539523,  2.16211413,  0.3493379 ,
#          0.33593445,  0.1874017 , -0.90785587,  0.1728    ,  0.1206314 ,
#         -0.60719689],
#        [-0.661773  , -0.85542916, -1.415675  , -0.82812203,  0.45734648,
#         -0.49965229, -0.76834256,  0.77243172, -0.06686951,  0.60323086,
#          0.27793138,  0.29939474, -0.90785587, -1.30834289, -0.26711238,
#         -0.17001513],
#        [ 0.84409233,  0.80443057,  1.34328927, -0.04121874,  1.72234737,
#          0.71485434, -1.44576756,  0.34112467,  0.60182558,  2.19711442,
#          2.36604195,  2.42726261,  0.19629316, -1.80205719, -0.91335201,
#          0.04857575]])

# %%
#checking the shape
X_Scaled.shape
# Out:
# (30, 16)

# %% [markdown]
# Now we shall treat the above shape as an array of numbers(tuple) where 30 and 16 are the zeroth and first index respectively.

# %%
#initializing...creating an empty dataframe stored in vif
vif=pd.DataFrame()

# %%
vif['vif']=[variance_inflation_factor(X_Scaled, i) for i in range(X_Scaled.shape[1])]#This is a list comprehension. in the for loop, the range(X_Scaled.shape[1]) which also means range(3) or (0,1,2), since X_Scaled.shape[1] means the first index in the X_Scaled.shape which is 3. Now all the columns in X_Scaled which is (0,1,2) will now be compared with the entire X_Scaled one by one using the other part of the syntax which is variance_inflation_factor(X_Scaled, i). To shed more light, what happens here is that during th comparison using variance_inflation_factor(X_Scaled, i), the i is seen as a ‘Label’ while the X_Scaled is seen as a Feature. The output of this list comprehension is then stored in a column named 'vif' inside the empty ‘vif dataframe’ created above

# %%
vif['Features'] = X.columns#creating another column named 'Features' inside the empty vif Dataframe created earlier and populating it with a data called X.columns(i.e column names from the X DataFrame which was created by dropping the Label – ‘sales’ )
vif
# Out:
#             vif Features
# 0     11.522370        R
# 1     13.311532       AB
# 2     10.070668        H
# 3      4.019297       2B
# 4      3.294146       3B
# 5     10.079902       HR
# 6      3.806098       BB
# 7      2.652401       SO
# 8      2.102684       SB
# 9    191.839155       RA
# 10  1680.387145       ER
# 11  1222.722240      ERA
# 12     3.059904       CG
# 13     3.654331      SHO
# 14     5.798850       SV
# 15     2.186219        E

# %% [markdown]
# From the above vif dataframe,we are setting a vif threshold of 6, meaning any feature with Variance Inflation Factor greater than 5 is assumed to have a multicollinearity problem. it is not standard. The dataset demands.
#
# In lieu of the above assumption, MULTICOLLINEARITY EXISTS!

# %% [markdown]
# # Step 4.3 - Removal of Outliers
#
# There are no outliers

# %%
#Checking the new dataframe with non-outliers
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
#rechecking for allien-datapoints in each features data which are now stored in df_new
plt.figure(figsize=(20,10))#dimension only
graph = 1 #like a form of counter which we will see its relevance in the ‘for loop’

for column in df:#triggering your for loop
    if graph<=12:
        plt.subplot(4,5,graph)#3,4 means arrange the graphs in 3-rows and 3-columns spaces as seen below while plotnumber means plot graphs
        ax=sns.boxplot(data=df[column])#performing box plots
        plt.xlabel(column,fontsize=10)#labelling the x-axis with their respctive column names with a font size of 20
    graph+=1#incrementals for plot number so as to allow ploting one by one until it gets to 12
plt.tight_layout()#This is just to show you data in a compact form.

# %% [markdown]
# # Step 4.4 - Transforming Data to Remove Skewness using Power transformation

# %%
#rechecking for skewness...
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# - Since we don't apply skewness removal on target data, we need to create a sub data frame that does not include the sales         column
#
# - For the skewness data, only the features below are abit skewed from our initial analysis.
# - Errors
# - Saves
# - Shutouts
# - Hits
# - Complete games
# - Runs

# %%
#Visualizing for the current skewness before Power Transformation
plt.figure(figsize=(20,10), facecolor='blue')#dimension and line color
plotnumber = 1 #like a form of counter which we will see its relevance in the ‘for loop’

for column in df:#triggering your for loop
    if plotnumber<=17:#since there are 6 features
        ax = plt.subplot(4,5,plotnumber)#3,3 means arrange the graphs in 3-rows and 4-columns spaces as seen below while plotnumber means plot graphs
        sns.distplot(df[column])#performing a distribution plot for all the columns starting with Length
        plt.xlabel(column,fontsize=20)#labelling the x-axis with their respctive column names with a font size of 20
    plotnumber+=1#incrementals for plot number so as to allow ploting one by one until it gets to 12
plt.tight_layout()#This is just to show you data in a compact form.

# %% [markdown]
# # Lets remove the skewness using power transformation
# Let lets go ahead and apply Power Transformation!

# %%
#Instantiating PowerTransformer,using 'yeo-johnson',into object 'scaler'
scaler = PowerTransformer(method ='yeo-johnson')#intstantiating using the yeo-johnson
'''
parameters:
method = 'box-cox' or 'yeo-johnson'
'''
# Out:
# "\nparameters:\nmethod = 'box-cox' or 'yeo-johnson'\n"

# %%
#extracting the columns that are skewed
data=['E','SV','SHO','H','CG','R']

# %%
pt = PowerTransformer()
pt
# Out:
# PowerTransformer()

# %%
#Now removing skewness by Power Transformation and updating dataset(df_new) with result
df[data] = pt.fit_transform(df[data].values)

# %%
df
# Out:
#       W         R    AB             H   2B  3B   HR   BB    SO   SB   RA   ER  \
# 0    95  0.728218  5575  4.996004e-16  300  42  139  383   973  104  641  601
# 1    83  0.261212  5467 -3.053113e-16  277  44  156  439  1264   70  700  653
# 2    81 -0.244821  5439  0.000000e+00  303  29  141  533  1157   86  640  584
# 3    76 -1.285129  5533 -8.326673e-17  260  27  136  404  1231   68  701  643
# 4    74  0.135622  5605  5.828671e-16  289  49  151  455  1259   83  803  746
# 5    93  2.671903  5509  4.440892e-16  308  17  232  570  1151   88  670  609
# 6    87  1.309688  5567  0.000000e+00  272  19  212  554  1227   63  698  652
# 7    81  0.551199  5485 -1.665335e-16  246  20  217  418  1331   44  693  646
# 8    80 -0.770266  5485 -8.326673e-17  278  32  167  436  1310   87  642  604
# 9    78  1.088096  5640  4.996004e-16  294  33  161  478  1148   71  753  694
# 10   88  1.130709  5511  1.387779e-16  279  32  172  503  1233  101  733  680
# 11   86  0.806086  5459 -2.220446e-16  278  26  230  486  1392  121  618  572
# 12   85 -0.406595  5417 -4.440892e-16  243  21  176  435  1150   52  675  630
# 13   76 -0.510674  5544 -1.110223e-16  262  22  198  478  1336   69  726  677
# 14   68  0.225711  5600  5.551115e-17  277  46  146  475  1119   78  729  664
# 15  100 -0.704034  5484 -5.551115e-17  288  39  137  506  1267   69  525  478
# 16   98  0.278850  5631  3.608225e-16  292  27  140  461  1322   98  596  532
# 17   97  0.135622  5491 -3.885781e-16  272  30  171  567  1518   95  608  546
# 18   68 -0.531772  5480 -1.110223e-16  274  34  145  412  1299   84  737  682
# 19   64 -0.860005  5571 -8.326673e-17  257  27  167  496  1255  134  754  700
# 20   90  0.024936  5527 -3.053113e-16  295  17  177  488  1290   51  613  557
# 21   83  0.383127  5428 -2.220446e-16  265  13  177  539  1344   57  635  577
# 22   71 -1.511637  5463  1.387779e-16  236  40  120  375  1150  112  678  638
# 23   67 -2.648512  5420 -2.220446e-16  251  18  100  471  1107   69  760  698
# 24   63 -1.187531  5529 -1.387779e-16  272  37  130  387  1274   88  809  749
# 25   92 -0.284728  5385 -3.330669e-16  263  26  187  563  1258   59  595  553
# 26   84  0.261212  5565  4.718448e-16  288  39  136  457  1159   93  627  597
# 27   79  0.664771  5649  4.996004e-16  289  48  154  490  1312  132  713  659
# 28   74 -0.638702  5457 -4.996004e-16  260  36  148  426  1327   82  731  655
# 29   68  0.927445  5572  4.440892e-16  274  49  186  388  1283   97  844  799
#
#      ERA        CG       SHO        SV         E
# 0   3.73 -0.359844 -0.789579  1.546378 -0.334953
# 1   4.07 -0.359844  0.251775  0.360444 -0.532211
# 2   3.67  1.993513 -0.245393 -0.607594 -1.342331
# 3   3.98  1.220103 -0.510759 -0.764453  0.678524
# 4   4.64  1.220103  0.251775 -1.095010 -0.532211
# 5   3.80  1.220103 -0.245393 -1.269438 -0.334953
# 6   4.03  0.064630 -2.099326  0.718082  0.104539
# 7   4.05 -1.729889 -0.245393  0.104606 -1.614550
# 8   3.74 -0.909181  0.251775  1.905480  0.261504
# 9   4.31  0.064630 -0.245393 -0.309109  0.409004
# 10  4.24  0.716445 -0.510759  0.360444  1.577725
# 11  3.57  0.716445  0.486160 -0.455910 -0.636014
# 12  3.94 -0.359844  0.251775  0.482968  0.104539
# 13  4.16  0.981874  0.251775  0.360444  0.184254
# 14  4.14  0.716445  0.931345 -2.473461  1.829127
# 15  2.94 -0.909181  0.931345  2.073674  0.336388
# 16  3.21 -1.729889  0.486160  1.354219  1.690704
# 17  3.36  0.981874  2.122859  0.718082  1.231063
# 18  4.28 -0.909181 -1.084158 -0.309109  1.455992
# 19  4.33 -0.359844 -0.789579 -1.095010 -0.150493
# 20  3.43 -0.909181  0.712418  0.940964 -0.334953
# 21  3.62  0.415268  0.486160 -0.166919 -0.150493
# 22  4.02 -1.729889  0.251775 -1.095010 -1.614550
# 23  4.41  0.064630 -0.245393  0.234385 -0.150493
# 24  4.69 -0.909181 -1.084158 -1.095010  1.497597
# 25  3.44  0.981874  2.122859  0.602127 -1.908427
# 26  3.72  1.220103  1.550425 -0.166919 -1.475870
# 27  4.04 -0.909181  0.251775  0.234385 -0.532211
# 28  4.09 -0.909181 -1.397546 -0.166919  0.022251
# 29  5.04  0.415268 -2.099326 -0.926809  0.261504

# %%
#Visualizing for the current skewness(if any) after Power Transformation
plt.figure(figsize=(20,10), facecolor='red')#dimension and line color
plotnumber = 1 #like a form of counter which we will see its relevance in the ‘for loop’

for column in df:#triggering your for loop
    if plotnumber<=17:#since there are 6 features
        ax = plt.subplot(4,5,plotnumber)#3,4 means arrange the graphs in 3-rows and 3-columns spaces as seen below while plotnumber means plot graphs
        sns.distplot(df[column])#performing a distribution plot for all the columns
        plt.xlabel(column,fontsize=20)#labelling the x-axis with their respctive column names with a font size of 20
    plotnumber+=1#incrementals for plot number so as to allow ploting one by one until it gets to 12
plt.tight_layout()#This is just to show you data in a compact form.

# %%
#rechecking for skewness
df.skew()
# Out:
# W      0.047089
# R     -0.055006
# AB     0.183437
# H      0.000000
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG    -0.059785
# SHO    0.006560
# SV     0.000836
# E      0.063909
# dtype: float64

# %% [markdown]
# From the above you can see all skewness in all continuos data are now within the threshold of +/-0.5 which was chosen earlier!

# %% [markdown]
# From the above we can see that skewness has been removed!
#
# NOTE:
# - All continuos data columns was considered for skewness removal
# - The wins column is not considered for skewness since its the Target data

# %%
vif['Features'] = X.columns#creating another column named 'Features' inside the empty vif Dataframe created earlier and populating it with a data called X.columns(i.e column names from the X DataFrame which was created by dropping the Label – ‘sales’ )
vif
# Out:
#             vif Features
# 0     11.522370        R
# 1     13.311532       AB
# 2     10.070668        H
# 3      4.019297       2B
# 4      3.294146       3B
# 5     10.079902       HR
# 6      3.806098       BB
# 7      2.652401       SO
# 8      2.102684       SB
# 9    191.839155       RA
# 10  1680.387145       ER
# 11  1222.722240      ERA
# 12     3.059904       CG
# 13     3.654331      SHO
# 14     5.798850       SV
# 15     2.186219        E

# %% [markdown]
# # Feature selection
#
# -we will have to drop features with multicolinearity issues.Because the less the features the better the performance.Because we want to avoid the curse of dimensionality

# %%
df = df.drop(df.columns[[0, 1, 2,5,9,10,11]],axis = 1)
df.head()
# Out:
#               H   2B   HR   BB    SO   ERA        CG       SHO        SV  \
# 0  4.996004e-16  300  139  383   973  3.73 -0.359844 -0.789579  1.546378
# 1 -3.053113e-16  277  156  439  1264  4.07 -0.359844  0.251775  0.360444
# 2  0.000000e+00  303  141  533  1157  3.67  1.993513 -0.245393 -0.607594
# 3 -8.326673e-17  260  136  404  1231  3.98  1.220103 -0.510759 -0.764453
# 4  5.828671e-16  289  151  455  1259  4.64  1.220103  0.251775 -1.095010
#
#           E
# 0 -0.334953
# 1 -0.532211
# 2 -1.342331
# 3  0.678524
# 4 -0.532211

# %% [markdown]
# # Step 4.5 - Seperating the datasets into X and Y variables

# %%
X.head()
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12  35
#
#      E
# 0   88
# 1   86
# 2   79
# 3  101
# 4   86

# %%
#seperation
X = df
Y.head()
# Out:
# 0    95
# 1    83
# 2    81
# 3    76
# 4    74
# Name: W, dtype: int64

# %% [markdown]
# # Transforming data into standard normal distribution

# %%
#transforming dataset into a standard normal distribution
scalar=StandardScaler()
X_Scaled = scalar.fit_transform(X)
X_Scaled
# Out:
# array([[ 1.53885176,  1.42017307, -0.7872986 , -1.53490242, -2.69762957,
#         -0.50695519, -0.35984364, -0.78957937,  1.546378  , -0.3349525 ],
#        [-1.00156765,  0.12740339, -0.24396668, -0.5365919 ,  0.15487844,
#          0.25459752, -0.35984364,  0.25177537,  0.36044386, -0.53221128],
#        [-0.03796029,  1.58879521, -0.7233772 ,  1.13914361, -0.89398189,
#         -0.64134684,  1.99351257, -0.24539345, -0.6075936 , -1.34233137],
#        [-0.3007623 , -0.82812203, -0.8831807 , -1.16053598, -0.16860185,
#          1.01615023,  0.06463007, -0.24539345,  0.23438459, -0.15049335],
#        [-0.47596364, -0.1536335 , -1.07494491, -1.46359453,  0.25290277,
#          1.64331129, -0.90918054, -1.08415811, -1.09501024,  1.49759735],
#        [-1.08916832, -0.6594999 ,  0.74681504,  1.67395282,  0.09606384,
#         -1.15651485,  0.98187374,  2.1228587 ,  0.60212705, -1.90842687],
#        [ 1.45125109,  0.74568454, -0.8831807 , -0.21570638, -0.87437703,
#         -0.52935379,  1.22010317,  1.55042485, -0.16691871, -1.47586961],
#        [ 1.53885176,  0.80189192, -0.30788808,  0.37258375,  0.62539523,
#          0.1874017 , -0.90918054,  0.25177537,  0.23438459, -0.53221128],
#        [-1.61477234, -0.82812203, -0.49965229, -0.76834256,  0.77243172,
#          0.29939474, -0.90918054, -1.39754579, -0.16691871,  0.02225134],
#        [ 1.36365042, -0.04121874,  0.71485434, -1.44576756,  0.34112467,
#          2.42726261,  0.41526799, -2.09932639, -0.92680917,  0.26150364]])

# %% [markdown]
# What standard scaler does is to bring mean to zero and standard deviation to 1

# %%
#reconfirming that mean is 0
X_Scaled.mean()
# Out:
# -1.3174646558885192e-16

# %%
#reconfirming that standard deviation is 1
X_Scaled.std()
# Out:
# 1.0

# %% [markdown]
# # Step 5 - MODEL BUILDING

# %% [markdown]
# # Step 5.1 - Linear Regression

# %% [markdown]
# # Best Random State

# %%
#Using LinearRegression to get the best Random state
lm=LinearRegression()
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=i,test_size=0.20)
    lm.fit(x_train,y_train)
    pred_train=lm.predict(x_train)
    pred_test=lm.predict(x_test)
    print("At random state of :-",i,"Testing Accuracy and Training Accuracy are:- ",round(metrics.r2_score(y_test,pred_test)*100,2), "and", round(metrics.r2_score(y_train,pred_train)*100,2), "respectively")
    print("At random state of :- ",i, "the mean absolute error of Testing and Training are:- ",round(mean_absolute_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the mean squared error of Testing and Training are:- ",round(mean_squared_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the root mean squared error of Testing and Training are:- ",round(np.sqrt(mean_squared_error(y_test,pred_test)),2), "and", round(np.sqrt(mean_absolute_error(y_train,pred_train)),2), "respectively")
    print("\n")
# Out:
# At random state of :- 0 Testing Accuracy and Training Accuracy are:-  47.32 and 90.31 respectively
# At random state of :-  0 the mean absolute error of Testing and Training are:-  5.6 and 2.48 respectively
# At random state of :-  0 the mean squared error of Testing and Training are:-  34.18 and 2.48 respectively
# At random state of :-  0 the root mean squared error of Testing and Training are:-  5.85 and 1.57 respectively
#
#
# At random state of :- 1 Testing Accuracy and Training Accuracy are:-  61.34 and 91.25 respectively
# At random state of :-  1 the mean absolute error of Testing and Training are:-  6.11 and 2.4 respectively
# At random state of :-  1 the mean squared error of Testing and Training are:-  54.47 and 2.4 respectively
# At random state of :-  1 the root mean squared error of Testing and Training are:-  7.38 and 1.55 respectively
#
#
# At random state of :- 2 Testing Accuracy and Training Accuracy are:-  11.98 and 92.31 respectively
# At random state of :-  2 the mean absolute error of Testing and Training are:-  8.84 and 2.38 respectively
# At random state of :-  2 the mean squared error of Testing and Training are:-  92.94 and 2.38 respectively
# At random state of :-  2 the root mean squared error of Testing and Training are:-  9.64 and 1.54 respectively
#
#
# At random state of :- 3 Testing Accuracy and Training Accuracy are:-  86.58 and 85.43 respectively
# At random state of :-  3 the mean absolute error of Testing and Training are:-  3.48 and 3.02 respectively
# At random state of :-  3 the mean squared error of Testing and Training are:-  21.28 and 3.02 respectively
# At random state of :-  3 the root mean squared error of Testing and Training are:-  4.61 and 1.74 respectively
#
#
# At random state of :- 4 Testing Accuracy and Training Accuracy are:-  90.81 and 85.25 respectively
# At random state of :-  4 the mean absolute error of Testing and Training are:-  1.79 and 3.09 respectively
# At random state of :-  4 the mean squared error of Testing and Training are:-  5.94 and 3.09 respectively
# At random state of :-  4 the root mean squared error of Testing and Training are:-  2.44 and 1.76 respectively
#
#
# At random state of :- 5 Testing Accuracy and Training Accuracy are:-  81.2 and 87.26 respectively
# At random state of :-  5 the mean absolute error of Testing and Training are:-  4.01 and 2.79 respectively
# At random state of :-  5 the mean squared error of Testing and Training are:-  21.34 and 2.79 respectively
# At random state of :-  5 the root mean squared error of Testing and Training are:-  4.62 and 1.67 respectively
#
#
# At random state of :- 6 Testing Accuracy and Training Accuracy are:-  74.77 and 88.64 respectively
# At random state of :-  6 the mean absolute error of Testing and Training are:-  4.83 and 2.56 respectively
# At random state of :-  6 the mean squared error of Testing and Training are:-  34.2 and 2.56 respectively
# At random state of :-  6 the root mean squared error of Testing and Training are:-  5.85 and 1.6 respectively
#
#
# At random state of :- 7 Testing Accuracy and Training Accuracy are:-  30.94 and 89.97 respectively
# At random state of :-  7 the mean absolute error of Testing and Training are:-  4.26 and 2.61 respectively
# At random state of :-  7 the mean squared error of Testing and Training are:-  30.77 and 2.61 respectively
# At random state of :-  7 the root mean squared error of Testing and Training are:-  5.55 and 1.62 respectively
#
#
# At random state of :- 8 Testing Accuracy and Training Accuracy are:-  88.68 and 85.08 respectively
# At random state of :-  8 the mean absolute error of Testing and Training are:-  3.56 and 2.83 respectively
# At random state of :-  8 the mean squared error of Testing and Training are:-  15.09 and 2.83 respectively
# At random state of :-  8 the root mean squared error of Testing and Training are:-  3.88 and 1.68 respectively
#
#
# At random state of :- 9 Testing Accuracy and Training Accuracy are:-  56.66 and 87.92 respectively
# At random state of :-  9 the mean absolute error of Testing and Training are:-  4.52 and 2.88 respectively
# At random state of :-  9 the mean squared error of Testing and Training are:-  27.08 and 2.88 respectively
# At random state of :-  9 the root mean squared error of Testing and Training are:-  5.2 and 1.7 respectively
#
#
# At random state of :- 10 Testing Accuracy and Training Accuracy are:-  39.25 and 87.89 respectively
# At random state of :-  10 the mean absolute error of Testing and Training are:-  4.09 and 3.18 respectively
# At random state of :-  10 the mean squared error of Testing and Training are:-  20.25 and 3.18 respectively
# At random state of :-  10 the root mean squared error of Testing and Training are:-  4.5 and 1.78 respectively
#
#
# At random state of :- 11 Testing Accuracy and Training Accuracy are:-  27.45 and 91.38 respectively
# At random state of :-  11 the mean absolute error of Testing and Training are:-  4.96 and 2.43 respectively
# At random state of :-  11 the mean squared error of Testing and Training are:-  40.57 and 2.43 respectively
# At random state of :-  11 the root mean squared error of Testing and Training are:-  6.37 and 1.56 respectively
#
#
# At random state of :- 12 Testing Accuracy and Training Accuracy are:-  -22.1 and 90.6 respectively
# At random state of :-  12 the mean absolute error of Testing and Training are:-  6.78 and 2.57 respectively
# At random state of :-  12 the mean squared error of Testing and Training are:-  56.03 and 2.57 respectively
# At random state of :-  12 the root mean squared error of Testing and Training are:-  7.49 and 1.6 respectively
#
#
# At random state of :- 13 Testing Accuracy and Training Accuracy are:-  51.98 and 91.67 respectively
# At random state of :-  13 the mean absolute error of Testing and Training are:-  4.88 and 2.32 respectively
# At random state of :-  13 the mean squared error of Testing and Training are:-  40.02 and 2.32 respectively
# At random state of :-  13 the root mean squared error of Testing and Training are:-  6.33 and 1.52 respectively
#
#
# At random state of :- 14 Testing Accuracy and Training Accuracy are:-  80.95 and 87.25 respectively
# At random state of :-  14 the mean absolute error of Testing and Training are:-  3.98 and 2.86 respectively
# At random state of :-  14 the mean squared error of Testing and Training are:-  20.56 and 2.86 respectively
# At random state of :-  14 the root mean squared error of Testing and Training are:-  4.53 and 1.69 respectively
#
#
# At random state of :- 15 Testing Accuracy and Training Accuracy are:-  66.14 and 87.18 respectively
# At random state of :-  15 the mean absolute error of Testing and Training are:-  5.15 and 2.73 respectively
# At random state of :-  15 the mean squared error of Testing and Training are:-
respectively
# At random state of :-  194 the mean squared error of Testing and Training are:-  72.67 and 2.68 respectively
# At random state of :-  194 the root mean squared error of Testing and Training are:-  8.52 and 1.64 respectively
#
#
# At random state of :- 195 Testing Accuracy and Training Accuracy are:-  78.47 and 87.89 respectively
# At random state of :-  195 the mean absolute error of Testing and Training are:-  3.73 and 2.89 respectively
# At random state of :-  195 the mean squared error of Testing and Training are:-  18.83 and 2.89 respectively
# At random state of :-  195 the root mean squared error of Testing and Training are:-  4.34 and 1.7 respectively
#
#
# At random state of :- 196 Testing Accuracy and Training Accuracy are:-  35.46 and 90.66 respectively
# At random state of :-  196 the mean absolute error of Testing and Training are:-  5.27 and 2.54 respectively
# At random state of :-  196 the mean squared error of Testing and Training are:-  33.99 and 2.54 respectively
# At random state of :-  196 the root mean squared error of Testing and Training are:-  5.83 and 1.6 respectively
#
#
# At random state of :- 197 Testing Accuracy and Training Accuracy are:-  74.56 and 88.61 respectively
# At random state of :-  197 the mean absolute error of Testing and Training are:-  3.77 and 2.55 respectively
# At random state of :-  197 the mean squared error of Testing and Training are:-  24.09 and 2.55 respectively
# At random state of :-  197 the root mean squared error of Testing and Training are:-  4.91 and 1.6 respectively
#
#
# At random state of :- 198 Testing Accuracy and Training Accuracy are:-  69.97 and 85.05 respectively
# At random state of :-  198 the mean absolute error of Testing and Training are:-  5.9 and 2.78 respectively
# At random state of :-  198 the mean squared error of Testing and Training are:-  37.04 and 2.78 respectively
# At random state of :-  198 the root mean squared error of Testing and Training are:-  6.09 and 1.67 respectively
#
#
# At random state of :- 199 Testing Accuracy and Training Accuracy are:-  71.37 and 88.09 respectively
# At random state of :-  199 the mean absolute error of Testing and Training are:-  5.08 and 2.59 respectively
# At random state of :-  199 the mean squared error of Testing and Training are:-  35.38 and 2.59 respectively
# At random state of :-  199 the root mean squared error of Testing and Training are:-  5.95 and 1.61 respectively

# %% [markdown]
# The best accuracy is 93.02% at random state 29

# %% [markdown]
# We have found best_random state value as 29. We will now create our tain_test_splitusing this randome_state

# %% [markdown]
# # Creating train_test_split....

# %%
x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=29,test_size=0.20)

# %%
x_train.shape
# Out:
# (24, 10)

# %%
x_test.shape
# Out:
# (6, 10)

# %%
y_train.shape
# Out:
# (24,)

# %%
y_test.shape
# Out:
# (6,)

# %% [markdown]
# # Training Model and Metrics Measurement(r2_Score,MAE,MSE,RMSE)

# %%
lm=LinearRegression()#Initializing...
lm.fit(x_train,y_train)#Training...
pred_test=lm.predict(x_test)#Prediciting using test data...
pred_train=lm.predict(x_train)#Prediciting using training data...
Test_Accuracy_lm= (metrics.r2_score(y_test,pred_test))#Calculating r2 score for test data
Train_Accuracy_lm= (metrics.r2_score(y_train,pred_train))#Calculating r2 score for training data
Test_mae_lm= mean_absolute_error(y_test,pred_test)#Calculating mean absolute error for test data
Train_mae_lm= mean_absolute_error(y_train,pred_train)#Calculating mean absolute error for training data
Test_mse_lm= mean_squared_error(y_test,pred_test)#Calculating mean squared error for test data
Train_mse_lm= mean_squared_error(y_train,pred_train)#Calculating mean squared error for training data
Test_rmse_lm= np.sqrt(mean_squared_error(y_test,pred_test))#Calculating root mean squared error for test data
Train_rmse_lm= np.sqrt(mean_squared_error(y_train,pred_train))#Calculating root mean squared error for training data
print("Test_Accuracy ",round(metrics.r2_score(y_test,pred_test)*100,2))#printing testing accuracy
print("Test_MAE ", Test_mae_lm)#printing mean absolute error
print("Test_MSE ", Test_mse_lm)#printing mean squared error
print("Test_RMSE ", Test_rmse_lm)#printing root mean squared error
# Out:
# Test_Accuracy  93.02
# Test_MAE  2.6635338679863665
# Test_MSE  8.761305125569525
# Test_RMSE  2.9599501897108884

# %% [markdown]
# LinearRegression is producing average accuracy 93.02% which is very Good!. Now we will check Cross Validation score as well for overfitting(if exists).

# %% [markdown]
# # Cross Validation Score

# %%
#Validation accuracy
vac=cross_val_score(lm,X,Y,cv=5)
CV_Score_lm=vac.mean() 
print(vac)
print("Cross Validation Score is ",CV_Score_lm)
# Out:
# [ 0.64185514 -2.58433014  0.42962775  0.72474464  0.90485845]
# Cross Validation Score is  0.023351167671425355

# %%
# cross validation drops the accuracy of the model.And i believe this is as a result of the small sample data we are using in this project
# I wouldnt encourage the use of cross validation seeing that the data is small.

# %% [markdown]
# # Difference between Accuracy Score and Cross Validation Score

# %%
Test_Accuracy_lm
# Out:
# 0.9302196936901542

# %%
CV_Score_lm
# Out:
# 0.023351167671425355

# %%
lm_Acc_vs_CV_Score=np.abs(Test_Accuracy_lm-CV_Score_lm)
print("Difference between Accuracy and Cross Validation Score = ",lm_Acc_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score =  0.9068685260187289

# %% [markdown]
# From the above you can see that difference between Accuracy and Cross Validation score is high and this is as a result of the drop in accuracy during cross validation.I would consider the r2 score under test data.
#
# We would love to improve on this Accuracy by applying the Hyperparameter Tunning, However lets see performance of other Models!

# %% [markdown]
# # Step 5.2 - KNN Regressor

# %% [markdown]
# # Best Random State

# %%
#Using KNeighbors Regressor to get the best Random state
knn=KNeighborsRegressor()
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=i,test_size=0.20)
    knn.fit(x_train,y_train)
    pred_train=knn.predict(x_train)
    pred_test=knn.predict(x_test)
    print("At random state of :-",i,"Testing Accuracy and Training Accuracy are:- ",round(metrics.r2_score(y_test,pred_test)*100,2), "and", round(metrics.r2_score(y_train,pred_train)*100,2), "respectively")
    print("At random state of :- ",i, "the mean absolute error of Testing and Training are:- ",round(mean_absolute_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the mean squared error of Testing and Training are:- ",round(mean_squared_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the root mean squared error of Testing and Training are:- ",round(np.sqrt(mean_squared_error(y_test,pred_test)),2), "and", round(np.sqrt(mean_absolute_error(y_train,pred_train)),2), "respectively")
    print("\n")
# Out:
# At random state of :- 0 Testing Accuracy and Training Accuracy are:-  19.47 and 61.07 respectively
# At random state of :-  0 the mean absolute error of Testing and Training are:-  5.8 and 5.54 respectively
# At random state of :-  0 the mean squared error of Testing and Training are:-  52.25 and 5.54 respectively
# At random state of :-  0 the root mean squared error of Testing and Training are:-  7.23 and 2.35 respectively
#
#
# At random state of :- 1 Testing Accuracy and Training Accuracy are:-  53.99 and 54.92 respectively
# At random state of :-  1 the mean absolute error of Testing and Training are:-  6.87 and 5.47 respectively
# At random state of :-  1 the mean squared error of Testing and Training are:-  64.83 and 5.47 respectively
# At random state of :-  1 the root mean squared error of Testing and Training are:-  8.05 and 2.34 respectively
#
#
# At random state of :- 2 Testing Accuracy and Training Accuracy are:-  52.1 and 64.04 respectively
# At random state of :-  2 the mean absolute error of Testing and Training are:-  5.87 and 5.47 respectively
# At random state of :-  2 the mean squared error of Testing and Training are:-  50.57 and 5.47 respectively
# At random state of :-  2 the root mean squared error of Testing and Training are:-  7.11 and 2.34 respectively
#
#
# At random state of :- 3 Testing Accuracy and Training Accuracy are:-  59.51 and 53.19 respectively
# At random state of :-  3 the mean absolute error of Testing and Training are:-  7.37 and 5.24 respectively
# At random state of :-  3 the mean squared error of Testing and Training are:-  64.21 and 5.24 respectively
# At random state of :-  3 the root mean squared error of Testing and Training are:-  8.01 and 2.29 respectively
#
#
# At random state of :- 4 Testing Accuracy and Training Accuracy are:-  8.54 and 52.21 respectively
# At random state of :-  4 the mean absolute error of Testing and Training are:-  6.53 and 5.77 respectively
# At random state of :-  4 the mean squared error of Testing and Training are:-  59.07 and 5.77 respectively
# At random state of :-  4 the root mean squared error of Testing and Training are:-  7.69 and 2.4 respectively
#
#
# At random state of :- 5 Testing Accuracy and Training Accuracy are:-  50.46 and 53.93 respectively
# At random state of :-  5 the mean absolute error of Testing and Training are:-  6.87 and 5.69 respectively
# At random state of :-  5 the mean squared error of Testing and Training are:-  56.21 and 5.69 respectively
# At random state of :-  5 the root mean squared error of Testing and Training are:-  7.5 and 2.39 respectively
#
#
# At random state of :- 6 Testing Accuracy and Training Accuracy are:-  38.93 and 55.36 respectively
# At random state of :-  6 the mean absolute error of Testing and Training are:-  7.6 and 5.52 respectively
# At random state of :-  6 the mean squared error of Testing and Training are:-  82.79 and 5.52 respectively
# At random state of :-  6 the root mean squared error of Testing and Training are:-  9.1 and 2.35 respectively
#
#
# At random state of :- 7 Testing Accuracy and Training Accuracy are:-  16.4 and 61.23 respectively
# At random state of :-  7 the mean absolute error of Testing and Training are:-  4.57 and 5.74 respectively
# At random state of :-  7 the mean squared error of Testing and Training are:-
respectively
#
#
# At random state of :- 186 Testing Accuracy and Training Accuracy are:-  -23.15 and 59.01 respectively
# At random state of :-  186 the mean absolute error of Testing and Training are:-  7.13 and 5.38 respectively
# At random state of :-  186 the mean squared error of Testing and Training are:-  84.01 and 5.38 respectively
# At random state of :-  186 the root mean squared error of Testing and Training are:-  9.17 and 2.32 respectively
#
#
# At random state of :- 187 Testing Accuracy and Training Accuracy are:-  -19.95 and 65.05 respectively
# At random state of :-  187 the mean absolute error of Testing and Training are:-  7.5 and 5.03 respectively
# At random state of :-  187 the mean squared error of Testing and Training are:-  65.87 and 5.03 respectively
# At random state of :-  187 the root mean squared error of Testing and Training are:-  8.12 and 2.24 respectively
#
#
# At random state of :- 188 Testing Accuracy and Training Accuracy are:-  21.94 and 61.23 respectively
# At random state of :-  188 the mean absolute error of Testing and Training are:-  6.37 and 5.34 respectively
# At random state of :-  188 the mean squared error of Testing and Training are:-  49.7 and 5.34 respectively
# At random state of :-  188 the root mean squared error of Testing and Training are:-  7.05 and 2.31 respectively
#
#
# At random state of :- 189 Testing Accuracy and Training Accuracy are:-  60.35 and 42.12 respectively
# At random state of :-  189 the mean absolute error of Testing and Training are:-  7.77 and 6.29 respectively
# At random state of :-  189 the mean squared error of Testing and Training are:-  69.18 and 6.29 respectively
# At random state of :-  189 the root mean squared error of Testing and Training are:-  8.32 and 2.51 respectively
#
#
# At random state of :- 190 Testing Accuracy and Training Accuracy are:-  43.87 and 51.4 respectively
# At random state of :-  190 the mean absolute error of Testing and Training are:-  7.1 and 5.69 respectively
# At random state of :-  190 the mean squared error of Testing and Training are:-  68.29 and 5.69 respectively
# At random state of :-  190 the root mean squared error of Testing and Training are:-  8.26 and 2.39 respectively
#
#
# At random state of :- 191 Testing Accuracy and Training Accuracy are:-  44.82 and 61.29 respectively
# At random state of :-  191 the mean absolute error of Testing and Training are:-  6.7 and 5.23 respectively
# At random state of :-  191 the mean squared error of Testing and Training are:-  59.37 and 5.23 respectively
# At random state of :-  191 the root mean squared error of Testing and Training are:-  7.7 and 2.29 respectively
#
#
# At random state of :- 192 Testing Accuracy and Training Accuracy are:-  -9.37 and 64.19 respectively
# At random state of :-  192 the mean absolute error of Testing and Training are:-  5.2 and 5.48 respectively
# At random state of :-  192 the mean squared error of Testing and Training are:-  38.07 and 5.48 respectively
# At random state of :-  192 the root mean squared error of Testing and Training are:-  6.17 and 2.34 respectively
#
#
# At random state of :- 193 Testing Accuracy and Training Accuracy are:-  42.84 and 50.65 respectively
# At random state of :-  193 the mean absolute error of Testing and Training are:-  6.5 and 5.53 respectively
# At random state of :-  193 the mean squared error of Testing and Training are:-  78.5 and 5.53 respectively
# At random state of :-  193 the root mean squared error of Testing and Training are:-  8.86 and 2.35 respectively
#
#
# At random state of :- 194 Testing Accuracy and Training Accuracy are:-  -84.59 and 46.18 respectively
# At random state of :-  194 the mean absolute error of Testing and Training are:-  7.93 and 5.81 respectively
# At random state of :-  194 the mean squared error of Testing and Training are:-  85.32 and 5.81 respectively
# At random state of :-  194 the root mean squared error of Testing and Training are:-  9.24 and 2.41 respectively
#
#
# At random state of :- 195 Testing Accuracy and Training Accuracy are:-  53.23 and 55.78 respectively
# At random state of :-  195 the mean absolute error of Testing and Training are:-  5.63 and 5.97 respectively
# At random state of :-  195 the mean squared error of Testing and Training are:-  40.91 and 5.97 respectively
# At random state of :-  195 the root mean squared error of Testing and Training are:-  6.4 and 2.44 respectively
#
#
# At random state of :- 196 Testing Accuracy and Training Accuracy are:-  63.9 and 63.48 respectively
# At random state of :-  196 the mean absolute error of Testing and Training are:-  4.13 and 5.59 respectively
# At random state of :-  196 the mean squared error of Testing and Training are:-  19.01 and 5.59 respectively
# At random state of :-  196 the root mean squared error of Testing and Training are:-  4.36 and 2.36 respectively
#
#
# At random state of :- 197 Testing Accuracy and Training Accuracy are:-  71.0 and 55.26 respectively
# At random state of :-  197 the mean absolute error of Testing and Training are:-  4.73 and 5.88 respectively
# At random state of :-  197 the mean squared error of Testing and Training are:-  27.45 and 5.88 respectively
# At random state of :-  197 the root mean squared error of Testing and Training are:-  5.24 and 2.43 respectively
#
#
# At random state of :- 198 Testing Accuracy and Training Accuracy are:-  44.85 and 43.99 respectively
# At random state of :-  198 the mean absolute error of Testing and Training are:-  6.83 and 6.03 respectively
# At random state of :-  198 the mean squared error of Testing and Training are:-  68.02 and 6.03 respectively
# At random state of :-  198 the root mean squared error of Testing and Training are:-  8.25 and 2.46 respectively
#
#
# At random state of :- 199 Testing Accuracy and Training Accuracy are:-  32.7 and 61.38 respectively
# At random state of :-  199 the mean absolute error of Testing and Training are:-  7.77 and 5.23 respectively
# At random state of :-  199 the mean squared error of Testing and Training are:-  83.17 and 5.23 respectively
# At random state of :-  199 the root mean squared error of Testing and Training are:-  9.12 and 2.29 respectively

# %% [markdown]
# The best accuracy is 73.17% at random state 112

# %% [markdown]
# We have found best_random state value as 112. We will now create our tain_test_splitusing this randome_state

# %% [markdown]
# # Creating train_test_split....

# %%
x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=112,test_size=0.20)

# %% [markdown]
# # Training Model and Metrics Measurement(r2_Score,MAE,MSE,RMSE)

# %%
knn=KNeighborsRegressor()#Initializing...
knn.fit(x_train,y_train)#Training...
pred_test=knn.predict(x_test)#Prediciting using test data...
pred_train=knn.predict(x_train)#Prediciting using training data...
Test_Accuracy_knn= (metrics.r2_score(y_test,pred_test))#Calculating r2 score for test data
Train_Accuracy_knn= (metrics.r2_score(y_train,pred_train))#Calculating r2 score for training data
Test_mae_knn= mean_absolute_error(y_test,pred_test)#Calculating mean absolute error for test data
Train_mae_knn= mean_absolute_error(y_train,pred_train)#Calculating mean absolute error for training data
Test_mse_knn= mean_squared_error(y_test,pred_test)#Calculating mean squared error for test data
Train_mse_knn= mean_squared_error(y_train,pred_train)#Calculating mean squared error for training data
Test_rmse_knn= np.sqrt(mean_squared_error(y_test,pred_test))#Calculating root mean squared error for test data
Train_rmse_knn= np.sqrt(mean_squared_error(y_train,pred_train))#Calculating root mean squared error for training data
print("Test_Accuracy ",round(metrics.r2_score(y_test,pred_test)*100,2))#printing testing accuracy
print("Test_MAE ", Test_mae_knn)#printing mean absolute error
print("Test_MSE ", Test_mse_knn)#printing mean squared error
print("Test_RMSE ", Test_rmse_knn)#printing root mean squared error
# Out:
# Test_Accuracy  73.17
# Test_MAE  3.1000000000000014
# Test_MSE  15.380000000000003
# Test_RMSE  3.9217343102255158

# %% [markdown]
# KNeighbors is producing average accuracy 73.17% which is Good!. Now we will check Cross Validation score as well for overfitting(if exists).

# %% [markdown]
# # Cross Validation Score

# %%
#Validation accuracy
vac=cross_val_score(knn,X,Y,cv=5)
CV_Score_knn=vac.mean() 
print(vac)
print("Cross Validation Score is ",CV_Score_knn)
# Out:
# [-1.17875666  0.19526718 -0.43150038 -0.29863736  0.05540828]
# Cross Validation Score is  -0.331643788918898

# %% [markdown]
# # Difference between Accuracy Score and Cross Validation Score

# %%
Test_Accuracy_knn
# Out:
# 0.7317441860465116

# %%
CV_Score_knn
# Out:
# -0.331643788918898

# %%
knn_Acc_vs_CV_Score=np.abs(Test_Accuracy_knn-CV_Score_knn)
print("Difference between Accuracy and Cross Validation Score = ",knn_Acc_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score =  1.0633879749654096

# %% [markdown]
# From the above you can see that difference between Accuracy and Cross Validation score is negative meaning that cross validation reduced the performance.This is as a result of the size of the dataset which is very small
#
# We would love to improve on this Accuracy by applying the Hyperparameter Tunning, However lets see performance of other Models!

# %% [markdown]
# # Step 5.3 - Decision Tree Regressor

# %%
#Using Decision Tree Regressor to get the best Random state
dt=DecisionTreeRegressor()
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=i,test_size=0.20)
    dt.fit(x_train,y_train)
    pred_train=dt.predict(x_train)
    pred_test=dt.predict(x_test)
    print("At random state of :-",i,"Testing Accuracy and Training Accuracy are:- ",round(metrics.r2_score(y_test,pred_test)*100,2), "and", round(metrics.r2_score(y_train,pred_train)*100,2), "respectively")
    print("At random state of :- ",i, "the mean absolute error of Testing and Training are:- ",round(mean_absolute_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the mean squared error of Testing and Training are:- ",round(mean_squared_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the root mean squared error of Testing and Training are:- ",round(np.sqrt(mean_squared_error(y_test,pred_test)),2), "and", round(np.sqrt(mean_absolute_error(y_train,pred_train)),2), "respectively")
    print("\n")
# Out:
# At random state of :- 0 Testing Accuracy and Training Accuracy are:-  -135.02 and 100.0 respectively
# At random state of :-  0 the mean absolute error of Testing and Training are:-  10.5 and 0.0 respectively
# At random state of :-  0 the mean squared error of Testing and Training are:-  152.5 and 0.0 respectively
# At random state of :-  0 the root mean squared error of Testing and Training are:-  12.35 and 0.0 respectively
#
#
# At random state of :- 1 Testing Accuracy and Training Accuracy are:-  37.54 and 100.0 respectively
# At random state of :-  1 the mean absolute error of Testing and Training are:-  6.67 and 0.0 respectively
# At random state of :-  1 the mean squared error of Testing and Training are:-  88.0 and 0.0 respectively
# At random state of :-  1 the root mean squared error of Testing and Training are:-  9.38 and 0.0 respectively
#
#
# At random state of :- 2 Testing Accuracy and Training Accuracy are:-  52.01 and 100.0 respectively
# At random state of :-  2 the mean absolute error of Testing and Training are:-  6.33 and 0.0 respectively
# At random state of :-  2 the mean squared error of Testing and Training are:-  50.67 and 0.0 respectively
# At random state of :-  2 the root mean squared error of Testing and Training are:-
respectively
# At random state of :-  178 the mean absolute error of Testing and Training are:-  7.67 and 0.0 respectively
# At random state of :-  178 the mean squared error of Testing and Training are:-  72.33 and 0.0 respectively
# At random state of :-  178 the root mean squared error of Testing and Training are:-  8.5 and 0.0 respectively
#
#
# At random state of :- 179 Testing Accuracy and Training Accuracy are:-  32.2 and 100.0 respectively
# At random state of :-  179 the mean absolute error of Testing and Training are:-  7.17 and 0.0 respectively
# At random state of :-  179 the mean squared error of Testing and Training are:-  61.17 and 0.0 respectively
# At random state of :-  179 the root mean squared error of Testing and Training are:-  7.82 and 0.0 respectively
#
#
# At random state of :- 180 Testing Accuracy and Training Accuracy are:-  21.59 and 100.0 respectively
# At random state of :-  180 the mean absolute error of Testing and Training are:-  7.17 and 0.0 respectively
# At random state of :-  180 the mean squared error of Testing and Training are:-  63.17 and 0.0 respectively
# At random state of :-  180 the root mean squared error of Testing and Training are:-  7.95 and 0.0 respectively
#
#
# At random state of :- 181 Testing Accuracy and Training Accuracy are:-  -35.09 and 100.0 respectively
# At random state of :-  181 the mean absolute error of Testing and Training are:-  10.0 and 0.0 respectively
# At random state of :-  181 the mean squared error of Testing and Training are:-  148.0 and 0.0 respectively
# At random state of :-  181 the root mean squared error of Testing and Training are:-  12.17 and 0.0 respectively
#
#
# At random state of :- 182 Testing Accuracy and Training Accuracy are:-  -101.87 and 100.0 respectively
# At random state of :-  182 the mean absolute error of Testing and Training are:-  11.33 and 0.0 respectively
# At random state of :-  182 the mean squared error of Testing and Training are:-  180.33 and 0.0 respectively
# At random state of :-  182 the root mean squared error of Testing and Training are:-  13.43 and 0.0 respectively
#
#
# At random state of :- 183 Testing Accuracy and Training Accuracy are:-  -209.14 and 100.0 respectively
# At random state of :-  183 the mean absolute error of Testing and Training are:-  12.5 and 0.0 respectively
# At random state of :-  183 the mean squared error of Testing and Training are:-  194.5 and 0.0 respectively
# At random state of :-  183 the root mean squared error of Testing and Training are:-  13.95 and 0.0 respectively
#
#
# At random state of :- 184 Testing Accuracy and Training Accuracy are:-  -98.44 and 100.0 respectively
# At random state of :-  184 the mean absolute error of Testing and Training are:-  6.67 and 0.0 respectively
# At random state of :-  184 the mean squared error of Testing and Training are:-  56.67 and 0.0 respectively
# At random state of :-  184 the root mean squared error of Testing and Training are:-  7.53 and 0.0 respectively
#
#
# At random state of :- 185 Testing Accuracy and Training Accuracy are:-  13.95 and 100.0 respectively
# At random state of :-  185 the mean absolute error of Testing and Training are:-  9.5 and 0.0 respectively
# At random state of :-  185 the mean squared error of Testing and Training are:-  127.83 and 0.0 respectively
# At random state of :-  185 the root mean squared error of Testing and Training are:-  11.31 and 0.0 respectively
#
#
# At random state of :- 186 Testing Accuracy and Training Accuracy are:-  -13.6 and 100.0 respectively
# At random state of :-  186 the mean absolute error of Testing and Training are:-  8.5 and 0.0 respectively
# At random state of :-  186 the mean squared error of Testing and Training are:-  77.5 and 0.0 respectively
# At random state of :-  186 the root mean squared error of Testing and Training are:-  8.8 and 0.0 respectively
#
#
# At random state of :- 187 Testing Accuracy and Training Accuracy are:-  44.46 and 100.0 respectively
# At random state of :-  187 the mean absolute error of Testing and Training are:-  4.83 and 0.0 respectively
# At random state of :-  187 the mean squared error of Testing and Training are:-  30.5 and 0.0 respectively
# At random state of :-  187 the root mean squared error of Testing and Training are:-  5.52 and 0.0 respectively
#
#
# At random state of :- 188 Testing Accuracy and Training Accuracy are:-  2.09 and 100.0 respectively
# At random state of :-  188 the mean absolute error of Testing and Training are:-  6.0 and 0.0 respectively
# At random state of :-  188 the mean squared error of Testing and Training are:-  62.33 and 0.0 respectively
# At random state of :-  188 the root mean squared error of Testing and Training are:-  7.9 and 0.0 respectively
#
#
# At random state of :- 189 Testing Accuracy and Training Accuracy are:-  25.2 and 100.0 respectively
# At random state of :-  189 the mean absolute error of Testing and Training are:-  8.83 and 0.0 respectively
# At random state of :-  189 the mean squared error of Testing and Training are:-  130.5 and 0.0 respectively
# At random state of :-  189 the root mean squared error of Testing and Training are:-  11.42 and 0.0 respectively
#
#
# At random state of :- 190 Testing Accuracy and Training Accuracy are:-  -6.85 and 100.0 respectively
# At random state of :-  190 the mean absolute error of Testing and Training are:-  9.0 and 0.0 respectively
# At random state of :-  190 the mean squared error of Testing and Training are:-  130.0 and 0.0 respectively
# At random state of :-  190 the root mean squared error of Testing and Training are:-  11.4 and 0.0 respectively
#
#
# At random state of :- 191 Testing Accuracy and Training Accuracy are:-  49.96 and 100.0 respectively
# At random state of :-  191 the mean absolute error of Testing and Training are:-  6.17 and 0.0 respectively
# At random state of :-  191 the mean squared error of Testing and Training are:-  53.83 and 0.0 respectively
# At random state of :-  191 the root mean squared error of Testing and Training are:-  7.34 and 0.0 respectively
#
#
# At random state of :- 192 Testing Accuracy and Training Accuracy are:-  -463.61 and 100.0 respectively
# At random state of :-  192 the mean absolute error of Testing and Training are:-  12.17 and 0.0 respectively
# At random state of :-  192 the mean squared error of Testing and Training are:-  196.17 and 0.0 respectively
# At random state of :-  192 the root mean squared error of Testing and Training are:-  14.01 and 0.0 respectively
#
#
# At random state of :- 193 Testing Accuracy and Training Accuracy are:-  23.54 and 100.0 respectively
# At random state of :-  193 the mean absolute error of Testing and Training are:-  8.33 and 0.0 respectively
# At random state of :-  193 the mean squared error of Testing and Training are:-  105.0 and 0.0 respectively
# At random state of :-  193 the root mean squared error of Testing and Training are:-  10.25 and 0.0 respectively
#
#
# At random state of :- 194 Testing Accuracy and Training Accuracy are:-  -180.89 and 100.0 respectively
# At random state of :-  194 the mean absolute error of Testing and Training are:-  9.83 and 0.0 respectively
# At random state of :-  194 the mean squared error of Testing and Training are:-  129.83 and 0.0 respectively
# At random state of :-  194 the root mean squared error of Testing and Training are:-  11.39 and 0.0 respectively
#
#
# At random state of :- 195 Testing Accuracy and Training Accuracy are:-  -50.14 and 100.0 respectively
# At random state of :-  195 the mean absolute error of Testing and Training are:-  9.33 and 0.0 respectively
# At random state of :-  195 the mean squared error of Testing and Training are:-  131.33 and 0.0 respectively
# At random state of :-  195 the root mean squared error of Testing and Training are:-  11.46 and 0.0 respectively
#
#
# At random state of :- 196 Testing Accuracy and Training Accuracy are:-  12.66 and 100.0 respectively
# At random state of :-  196 the mean absolute error of Testing and Training are:-  5.67 and 0.0 respectively
# At random state of :-  196 the mean squared error of Testing and Training are:-  46.0 and 0.0 respectively
# At random state of :-  196 the root mean squared error of Testing and Training are:-  6.78 and 0.0 respectively
#
#
# At random state of :- 197 Testing Accuracy and Training Accuracy are:-  25.18 and 100.0 respectively
# At random state of :-  197 the mean absolute error of Testing and Training are:-  7.83 and 0.0 respectively
# At random state of :-  197 the mean squared error of Testing and Training are:-  70.83 and 0.0 respectively
# At random state of :-  197 the root mean squared error of Testing and Training are:-  8.42 and 0.0 respectively
#
#
# At random state of :- 198 Testing Accuracy and Training Accuracy are:-  57.57 and 100.0 respectively
# At random state of :-  198 the mean absolute error of Testing and Training are:-  6.33 and 0.0 respectively
# At random state of :-  198 the mean squared error of Testing and Training are:-  52.33 and 0.0 respectively
# At random state of :-  198 the root mean squared error of Testing and Training are:-  7.23 and 0.0 respectively
#
#
# At random state of :- 199 Testing Accuracy and Training Accuracy are:-  -47.13 and 100.0 respectively
# At random state of :-  199 the mean absolute error of Testing and Training are:-  12.17 and 0.0 respectively
# At random state of :-  199 the mean squared error of Testing and Training are:-  181.83 and 0.0 respectively
# At random state of :-  199 the root mean squared error of Testing and Training are:-  13.48 and 0.0 respectively

# %% [markdown]
# The best accuracy is 74.81% at random state 97

# %% [markdown]
# We have found best_random state value as 97. We will now create our tain_test_splitusing this randome_state

# %% [markdown]
# # Creating train_test_split....

# %%
x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=97,test_size=0.20)

# %% [markdown]
# # Training Model and Metrics Measurement(r2_Score,MAE,MSE,RMSE)

# %%
dt=DecisionTreeRegressor()#Initializing...
dt.fit(x_train,y_train)#Training...
pred_test=dt.predict(x_test)#Prediciting using test data...
pred_train=dt.predict(x_train)#Prediciting using training data...
Test_Accuracy_dt= (metrics.r2_score(y_test,pred_test))#Calculating r2 score for test data
Train_Accuracy_dt= (metrics.r2_score(y_train,pred_train))#Calculating r2 score for training data
Test_mae_dt= mean_absolute_error(y_test,pred_test)#Calculating mean absolute error for test data
Train_mae_dt= mean_absolute_error(y_train,pred_train)#Calculating mean absolute error for training data
Test_mse_dt= mean_squared_error(y_test,pred_test)#Calculating mean squared error for test data
Train_mse_dt= mean_squared_error(y_train,pred_train)#Calculating mean squared error for training data
Test_rmse_dt= np.sqrt(mean_squared_error(y_test,pred_test))#Calculating root mean squared error for test data
Train_rmse_dt= np.sqrt(mean_squared_error(y_train,pred_train))#Calculating root mean squared error for training data
print("Test_Accuracy ",round(metrics.r2_score(y_test,pred_test)*100,2))#printing testing accuracy
print("Test_MAE ", Test_mae_dt)#printing mean absolute error
print("Test_MSE ", Test_mse_dt)#printing mean squared error
print("Test_RMSE ", Test_rmse_dt)#printing root mean squared error
# Out:
# Test_Accuracy  70.03
# Test_MAE  5.0
# Test_MSE  38.666666666666664
# Test_RMSE  6.2182527020592095

# %% [markdown]
# Decision Tree is producing average accuracy 70.03% which is very Good!. Now we will check Cross Validation score as well for overfitting(if exists).

# %% [markdown]
# # Cross Validation Score

# %%
#Validation accuracy
vac=cross_val_score(dt,X,Y,cv=5)
CV_Score_dt=vac.mean() 
print(vac)
print("Cross Validation Score is ",CV_Score_dt)
# Out:
# [ -0.22557726 -11.02290076  -1.03808073   0.53469388   0.40532544]
# Cross Validation Score is  -2.2693078875648904

# %% [markdown]
# # Difference between Accuracy Score and Cross Validation Score

# %%
Test_Accuracy_dt
# Out:
# 0.7002583979328165

# %%
CV_Score_dt
# Out:
# -2.2693078875648904

# %%
dt_Acc_vs_CV_Score=np.abs(Test_Accuracy_dt-CV_Score_dt)
print("Difference between Accuracy and Cross Validation Score = ",dt_Acc_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score =  2.9695662854977067

# %% [markdown]
# From the above you can see that difference between Accuracy and Cross Validation score is high meaning that model is  having overfitting or underfitting problems!!
#
# We would love to improve on this Accuracy by applying the Hyperparameter Tunning, However lets see performance of other Models!

# %% [markdown]
# # Step 5.4 - RandomForest Regressor

# %% [markdown]
# # Best Random State

# %%
#Using RandomForest Regressor to get the best Random state
rf=RandomForestRegressor()
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=i,test_size=0.20)
    rf.fit(x_train,y_train)
    pred_train=rf.predict(x_train)
    pred_test=rf.predict(x_test)
    print("At random state of :-",i,"Testing Accuracy and Training Accuracy are:- ",round(metrics.r2_score(y_test,pred_test)*100,2), "and", round(metrics.r2_score(y_train,pred_train)*100,2), "respectively")
    print("At random state of :- ",i, "the mean absolute error of Testing and Training are:- ",round(mean_absolute_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the mean squared error of Testing and Training are:- ",round(mean_squared_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the root mean squared error of Testing and Training are:- ",round(np.sqrt(mean_squared_error(y_test,pred_test)),2), "and", round(np.sqrt(mean_absolute_error(y_train,pred_train)),2), "respectively")
    print("\n")
# Out:
# At random state of :- 0 Testing Accuracy and Training Accuracy are:-  43.22 and 92.82 respectively
# At random state of :-  0 the mean absolute error of Testing and Training are:-  5.21 and 2.4 respectively
# At random state of :-  0 the mean squared error of Testing and Training are:-  36.84 and 2.4 respectively
# At random state of :-  0 the root mean squared error of Testing and Training are:-  6.07 and 1.55 respectively
#
#
# At random state of :- 1 Testing Accuracy and Training Accuracy are:-  56.87 and 92.8 respectively
# At random state of :-  1 the mean absolute error of Testing and Training are:-  6.71 and 2.34 respectively
# At random state of :-  1 the mean squared error of Testing and Training are:-  60.76 and 2.34 respectively
# At random state of :-  1 the root mean squared error of Testing and Training are:-  7.79 and 1.53 respectively
#
#
# At random state of :- 2 Testing Accuracy and Training Accuracy are:-  33.07 and 92.7 respectively
# At random state of :-  2 the mean absolute error of Testing and Training are:-  6.95 and 2.37 respectively
# At random state of :-  2 the mean squared error of Testing and Training are:-  70.67 and 2.37 respectively
# At random state of :-  2 the root mean squared error of Testing and Training are:-  8.41 and 1.54 respectively
#
#
# At random state of :- 3 Testing Accuracy and Training Accuracy are:-  55.12 and 92.34 respectively
# At random state of :-  3 the mean absolute error of Testing and Training are:-  7.73 and 2.16 respectively
# At random state of :-  3 the mean squared error of Testing and Training are:-  71.17 and 2.16 respectively
# At random state of :-  3 the root mean squared error of Testing and Training are:-  8.44 and 1.47 respectively
#
#
# At random state of :- 4 Testing Accuracy and Training Accuracy are:-  63.52 and 91.04 respectively
# At random state of :-  4 the mean absolute error of Testing and Training are:-  3.75 and 2.62 respectively
# At random state of :-  4 the mean squared error of Testing and Training are:-  23.56 and 2.62 respectively
# At random state of :-  4 the root mean squared error of Testing and Training are:-  4.85 and 1.62 respectively
#
#
# At random state of :- 5 Testing Accuracy and Training Accuracy are:-  57.91 and 92.94 respectively
# At random state of :-  5 the mean absolute error of Testing and Training are:-  5.87 and 2.34 respectively
# At random state of :-  5 the mean squared error of Testing and Training are:-  47.76 and 2.34 respectively
# At random state of :-  5 the root mean squared error of Testing and Training are:-  6.91 and 1.53 respectively
#
#
# At random state of :- 6 Testing Accuracy and Training Accuracy are:-  54.53 and 90.95 respectively
# At random state of :-  6 the mean absolute error of Testing and Training are:-  6.83 and 2.44 respectively
# At random state of :-  6 the mean squared error of Testing and Training are:-  61.63 and 2.44 respectively
# At random state of :-  6 the root mean squared error of Testing and Training are:-  7.85 and 1.56 respectively
#
#
# At random state of :- 7 Testing Accuracy and Training Accuracy are:-  -23.17 and 94.55 respectively
# At random state of :-  7 the mean absolute error of Testing and Training are:-  5.61 and 2.08 respectively
# At random state of :-  7 the mean squared error of Testing and Training are:-  54.88 and 2.08 respectively
# At random state of :-  7 the root mean squared error of Testing and Training are:-  7.41 and 1.44 respectively
#
#
# At random state of :- 8 Testing Accuracy and Training Accuracy are:-  59.81 and 92.14 respectively
# At random state of :-  8 the mean absolute error of Testing and Training are:-  6.42 and 2.31 respectively
# At random state of :-  8 the mean squared error of Testing and Training are:-  53.58 and 2.31 respectively
# At random state of :-  8 the root mean squared error of Testing and Training are:-  7.32 and 1.52 respectively
#
#
# At random state of :- 9 Testing Accuracy and Training Accuracy are:-  -2.38 and 94.83 respectively
# At random state of :-  9 the mean absolute error of Testing and Training are:-  6.29 and 1.92 respectively
# At random state of :-  9 the mean squared error of Testing and Training are:-  63.96 and 1.92 respectively
# At random state of :-  9 the root mean squared error of Testing and Training are:-  8.0 and 1.38 respectively
#
#
# At random state of :- 10 Testing Accuracy and Training Accuracy are:-  -1.38 and 94.77 respectively
# At random state of :-  10 the mean absolute error of Testing and Training are:-  4.12 and 2.19 respectively
# At random state of :-  10 the mean squared error of Testing and Training are:-  33.79 and 2.19 respectively
# At random state of :-  10 the root mean squared error of Testing and Training are:-  5.81 and 1.48 respectively
#
#
# At random state of :- 11 Testing Accuracy and Training Accuracy are:-  47.66 and 93.67 respectively
# At random state of :-  11 the mean absolute error of Testing and Training are:-  4.09 and 2.31 respectively
# At random state of :-  11 the mean squared error of Testing and Training are:-  29.26 and 2.31 respectively
# At random state of :-  11 the root mean squared error of Testing and Training are:-  5.41 and 1.52 respectively
#
#
# At random state of :- 12 Testing Accuracy and Training Accuracy are:-  2.33 and 92.06 respectively
# At random state of :-  12 the mean absolute error of Testing and Training are:-  6.21 and 2.51 respectively
# At random state of :-  12 the mean squared error of Testing and Training are:-  44.82 and 2.51 respectively
# At random state of :-  12 the root mean squared error of Testing and Training are:-  6.69 and 1.58 respectively
#
#
# At random state of :- 13 Testing Accuracy and Training Accuracy are:-  52.55 and 91.43 respectively
# At random state of :-  13 the mean absolute error of Testing and Training are:-  5.49 and 2.49 respectively
# At random state of :-  13 the mean squared error of Testing and Training are:-  39.54 and 2.49 respectively
# At random state of :-  13 the root mean squared error of Testing and Training are:-  6.29 and 1.58 respectively
#
#
# At random state of :- 14 Testing Accuracy and Training Accuracy are:-  61.49 and 93.35 respectively
# At random state of :-  14 the mean absolute error of Testing and Training are:-  5.74 and 2.25 respectively
# At random state of :-  14 the mean squared error of Testing and Training are:-  41.55 and 2.25 respectively
# At random state of :-  14 the root mean squared error of Testing and Training are:-  6.45 and 1.5 respectively
#
#
# At random state of :- 15 Testing Accuracy and Training Accuracy are:-  29.01 and 92.38 respectively
# At random state of :-  15 the mean absolute error of Testing and Training are:-  9.16 and 2.09 respectively
# At random state of :-  15 the mean squared error of Testing and Training are:-  92.2 and 2.09 respectively
# At random state of :-  15 the root mean squared error of Testing and Training are:-  9.6 and 1.44 respectively
#
#
# At random state of :- 16 Testing Accuracy and Training Accuracy are:-  9.34 and 94.48 respectively
# At random state of :-  16 the mean absolute error of Testing and Training are:-  7.05 and 2.05 respectively
# At random state of :-  16 the mean squared error of Testing and Training are:-  63.89 and 2.05 respectively
# At random state of :-  16 the root mean squared error of Testing and Training are:-  7.99 and 1.43 respectively
#
#
# At random state of :- 17 Testing Accuracy and Training Accuracy are:-  -1.9 and 96.19 respectively
# At random state of :-  17 the mean absolute error of Testing and Training are:-  9.51 and 1.66 respectively
# At random state of :-  17 the mean squared error of Testing and Training are:-  123.64 and 1.66 respectively
# At random state of :-  17 the root mean squared error of Testing and Training are:-  11.12 and 1.29 respectively
#
#
# At random state of :- 18 Testing Accuracy and Training Accuracy are:-  24.94 and 94.24 respectively
# At random state of :-  18 the mean absolute error of Testing and Training are:-  4.42 and 2.12 respectively
# At random state of :-  18 the mean squared error of Testing and Training are:-  32.38 and 2.12 respectively
# At random state of :-  18 the root mean squared error of Testing and Training are:-  5.69 and 1.46 respectively
#
#
# At random state of :- 19 Testing Accuracy and Training Accuracy are:-  62.13 and 91.78 respectively
# At random state of :-  19 the mean absolute error of Testing and Training are:-  5.04 and 2.45 respectively
# At random state of :-  19 the mean squared error of Testing and Training are:-  31.89 and 2.45 respectively
# At random state of :-  19 the root mean squared error of Testing and Training are:-  5.65 and 1.56 respectively
#
#
# At random state of :- 20 Testing Accuracy and Training Accuracy are:-  24.84 and 94.0 respectively
# At random state of :-  20 the mean absolute error of Testing and Training are:-  4.7 and 2.24 respectively
# At random state of :-  20 the mean squared error of Testing and Training are:-  36.08 and 2.24 respectively
# At random state of :-  20 the root mean squared error of Testing and Training are:-  6.01 and 1.5 respectively
#
#
# At random state of :- 21 Testing Accuracy and Training Accuracy are:-  27.71 and 93.3 respectively
# At random state of :-  21 the mean absolute error of Testing and Training are:-  5.5 and 2.21 respectively
# At random state of :-  21 the mean squared error of Testing and Training are:-  55.36 and 2.21 respectively
# At random state of :-  21 the root mean squared error of Testing and Training are:-  7.44 and 1.49 respectively
#
#
# At random state of :- 22 Testing Accuracy and Training Accuracy are:-  18.28 and 91.52 respectively
# At random state of :-  22 the mean absolute error of Testing and Training are:-  6.65 and 2.4 respectively
# At random state of :-  22 the mean squared error of Testing and Training are:-  64.47 and 2.4 respectively
# At random state of :-  22 the root mean squared error of Testing and Training are:-  8.03 and 1.55 respectively
#
#
# At random state of :- 23 Testing Accuracy and Training Accuracy are:-  -46.9 and 92.77 respectively
# At random state of :-  23 the mean absolute error of Testing and Training are:-  8.99 and 2.21 respectively
# At random state of :-  23 the mean squared error of Testing and Training are:-  113.81 and 2.21 respectively
# At random state of :-  23 the root mean squared error of Testing and Training are:-  10.67 and 1.49 respectively
#
#
# At random state of :- 24 Testing Accuracy and Training Accuracy are:-  -565.02 and 95.43 respectively
# At random state of :-  24 the mean absolute error of Testing and Training are:-  7.05 and 2.05 respectively
# At random state of :-  24 the mean squared error of Testing and Training are:-  74.08 and 2.05 respectively
# At random state of :-  24 the root mean squared error of Testing and Training are:-  8.61 and 1.43 respectively
#
#
# At random state of :- 25 Testing Accuracy and Training Accuracy are:-  44.37 and 92.19 respectively
# At random state of :-  25 the mean absolute error of Testing and Training are:-  5.42 and 2.39 respectively
# At random state of :-  25 the mean squared error of Testing and Training are:-  41.43 and 2.39 respectively
# At random state of :-  25 the root mean squared error of Testing and Training are:-  6.44 and 1.55 respectively
#
#
# At random state of :- 26 Testing Accuracy and Training Accuracy are:-  65.95 and 91.87 respectively
# At random state of :-  26 the mean absolute error of Testing and Training are:-  3.61 and 2.5 respectively
# At random state of :-  26 the mean squared error of Testing and Training are:-  17.79 and 2.5 respectively
# At random state of :-  26 the root mean squared error of Testing and Training are:-  4.22 and 1.58 respectively
#
#
# At random state of :- 27 Testing Accuracy and Training Accuracy are:-
respectively
# At random state of :-  173 the root mean squared error of Testing and Training are:-  7.34 and 1.54 respectively
#
#
# At random state of :- 174 Testing Accuracy and Training Accuracy are:-  3.62 and 95.11 respectively
# At random state of :-  174 the mean absolute error of Testing and Training are:-  7.88 and 2.0 respectively
# At random state of :-  174 the mean squared error of Testing and Training are:-  78.95 and 2.0 respectively
# At random state of :-  174 the root mean squared error of Testing and Training are:-  8.89 and 1.42 respectively
#
#
# At random state of :- 175 Testing Accuracy and Training Accuracy are:-  78.19 and 93.31 respectively
# At random state of :-  175 the mean absolute error of Testing and Training are:-  3.5 and 2.29 respectively
# At random state of :-  175 the mean squared error of Testing and Training are:-  21.13 and 2.29 respectively
# At random state of :-  175 the root mean squared error of Testing and Training are:-  4.6 and 1.51 respectively
#
#
# At random state of :- 176 Testing Accuracy and Training Accuracy are:-  31.21 and 93.03 respectively
# At random state of :-  176 the mean absolute error of Testing and Training are:-  5.69 and 2.37 respectively
# At random state of :-  176 the mean squared error of Testing and Training are:-  41.9 and 2.37 respectively
# At random state of :-  176 the root mean squared error of Testing and Training are:-  6.47 and 1.54 respectively
#
#
# At random state of :- 177 Testing Accuracy and Training Accuracy are:-  41.1 and 94.89 respectively
# At random state of :-  177 the mean absolute error of Testing and Training are:-  6.32 and 1.95 respectively
# At random state of :-  177 the mean squared error of Testing and Training are:-  65.33 and 1.95 respectively
# At random state of :-  177 the root mean squared error of Testing and Training are:-  8.08 and 1.4 respectively
#
#
# At random state of :- 178 Testing Accuracy and Training Accuracy are:-  22.96 and 94.87 respectively
# At random state of :-  178 the mean absolute error of Testing and Training are:-  5.58 and 1.98 respectively
# At random state of :-  178 the mean squared error of Testing and Training are:-  52.64 and 1.98 respectively
# At random state of :-  178 the root mean squared error of Testing and Training are:-  7.26 and 1.41 respectively
#
#
# At random state of :- 179 Testing Accuracy and Training Accuracy are:-  44.2 and 93.62 respectively
# At random state of :-  179 the mean absolute error of Testing and Training are:-  5.93 and 2.2 respectively
# At random state of :-  179 the mean squared error of Testing and Training are:-  50.35 and 2.2 respectively
# At random state of :-  179 the root mean squared error of Testing and Training are:-  7.1 and 1.48 respectively
#
#
# At random state of :- 180 Testing Accuracy and Training Accuracy are:-  6.24 and 93.08 respectively
# At random state of :-  180 the mean absolute error of Testing and Training are:-  7.29 and 2.16 respectively
# At random state of :-  180 the mean squared error of Testing and Training are:-  75.53 and 2.16 respectively
# At random state of :-  180 the root mean squared error of Testing and Training are:-  8.69 and 1.47 respectively
#
#
# At random state of :- 181 Testing Accuracy and Training Accuracy are:-  3.45 and 96.67 respectively
# At random state of :-  181 the mean absolute error of Testing and Training are:-  9.04 and 1.57 respectively
# At random state of :-  181 the mean squared error of Testing and Training are:-  105.78 and 1.57 respectively
# At random state of :-  181 the root mean squared error of Testing and Training are:-  10.28 and 1.25 respectively
#
#
# At random state of :- 182 Testing Accuracy and Training Accuracy are:-  2.01 and 94.45 respectively
# At random state of :-  182 the mean absolute error of Testing and Training are:-  7.06 and 2.08 respectively
# At random state of :-  182 the mean squared error of Testing and Training are:-  87.53 and 2.08 respectively
# At random state of :-  182 the root mean squared error of Testing and Training are:-  9.36 and 1.44 respectively
#
#
# At random state of :- 183 Testing Accuracy and Training Accuracy are:-  1.62 and 93.7 respectively
# At random state of :-  183 the mean absolute error of Testing and Training are:-  6.98 and 2.16 respectively
# At random state of :-  183 the mean squared error of Testing and Training are:-  61.9 and 2.16 respectively
# At random state of :-  183 the root mean squared error of Testing and Training are:-  7.87 and 1.47 respectively
#
#
# At random state of :- 184 Testing Accuracy and Training Accuracy are:-  33.2 and 92.96 respectively
# At random state of :-  184 the mean absolute error of Testing and Training are:-  4.02 and 2.33 respectively
# At random state of :-  184 the mean squared error of Testing and Training are:-  19.07 and 2.33 respectively
# At random state of :-  184 the root mean squared error of Testing and Training are:-  4.37 and 1.53 respectively
#
#
# At random state of :- 185 Testing Accuracy and Training Accuracy are:-  53.44 and 92.73 respectively
# At random state of :-  185 the mean absolute error of Testing and Training are:-  7.47 and 2.17 respectively
# At random state of :-  185 the mean squared error of Testing and Training are:-  69.17 and 2.17 respectively
# At random state of :-  185 the root mean squared error of Testing and Training are:-  8.32 and 1.47 respectively
#
#
# At random state of :- 186 Testing Accuracy and Training Accuracy are:-  18.43 and 93.47 respectively
# At random state of :-  186 the mean absolute error of Testing and Training are:-  6.21 and 2.32 respectively
# At random state of :-  186 the mean squared error of Testing and Training are:-  55.65 and 2.32 respectively
# At random state of :-  186 the root mean squared error of Testing and Training are:-  7.46 and 1.52 respectively
#
#
# At random state of :- 187 Testing Accuracy and Training Accuracy are:-  36.36 and 93.57 respectively
# At random state of :-  187 the mean absolute error of Testing and Training are:-  5.41 and 2.28 respectively
# At random state of :-  187 the mean squared error of Testing and Training are:-  34.95 and 2.28 respectively
# At random state of :-  187 the root mean squared error of Testing and Training are:-  5.91 and 1.51 respectively
#
#
# At random state of :- 188 Testing Accuracy and Training Accuracy are:-  50.07 and 92.25 respectively
# At random state of :-  188 the mean absolute error of Testing and Training are:-  4.83 and 2.46 respectively
# At random state of :-  188 the mean squared error of Testing and Training are:-  31.79 and 2.46 respectively
# At random state of :-  188 the root mean squared error of Testing and Training are:-  5.64 and 1.57 respectively
#
#
# At random state of :- 189 Testing Accuracy and Training Accuracy are:-  68.84 and 89.15 respectively
# At random state of :-  189 the mean absolute error of Testing and Training are:-  6.88 and 2.59 respectively
# At random state of :-  189 the mean squared error of Testing and Training are:-  54.37 and 2.59 respectively
# At random state of :-  189 the root mean squared error of Testing and Training are:-  7.37 and 1.61 respectively
#
#
# At random state of :- 190 Testing Accuracy and Training Accuracy are:-  58.8 and 93.48 respectively
# At random state of :-  190 the mean absolute error of Testing and Training are:-  6.25 and 2.19 respectively
# At random state of :-  190 the mean squared error of Testing and Training are:-  50.13 and 2.19 respectively
# At random state of :-  190 the root mean squared error of Testing and Training are:-  7.08 and 1.48 respectively
#
#
# At random state of :- 191 Testing Accuracy and Training Accuracy are:-  59.77 and 93.18 respectively
# At random state of :-  191 the mean absolute error of Testing and Training are:-  5.49 and 2.31 respectively
# At random state of :-  191 the mean squared error of Testing and Training are:-  43.28 and 2.31 respectively
# At random state of :-  191 the root mean squared error of Testing and Training are:-  6.58 and 1.52 respectively
#
#
# At random state of :- 192 Testing Accuracy and Training Accuracy are:-  -16.83 and 92.54 respectively
# At random state of :-  192 the mean absolute error of Testing and Training are:-  5.02 and 2.5 respectively
# At random state of :-  192 the mean squared error of Testing and Training are:-  40.66 and 2.5 respectively
# At random state of :-  192 the root mean squared error of Testing and Training are:-  6.38 and 1.58 respectively
#
#
# At random state of :- 193 Testing Accuracy and Training Accuracy are:-  60.04 and 92.17 respectively
# At random state of :-  193 the mean absolute error of Testing and Training are:-  6.46 and 2.26 respectively
# At random state of :-  193 the mean squared error of Testing and Training are:-  54.88 and 2.26 respectively
# At random state of :-  193 the root mean squared error of Testing and Training are:-  7.41 and 1.5 respectively
#
#
# At random state of :- 194 Testing Accuracy and Training Accuracy are:-  -64.34 and 91.03 respectively
# At random state of :-  194 the mean absolute error of Testing and Training are:-  7.69 and 2.37 respectively
# At random state of :-  194 the mean squared error of Testing and Training are:-  75.96 and 2.37 respectively
# At random state of :-  194 the root mean squared error of Testing and Training are:-  8.72 and 1.54 respectively
#
#
# At random state of :- 195 Testing Accuracy and Training Accuracy are:-  42.1 and 93.59 respectively
# At random state of :-  195 the mean absolute error of Testing and Training are:-  5.96 and 2.16 respectively
# At random state of :-  195 the mean squared error of Testing and Training are:-  50.65 and 2.16 respectively
# At random state of :-  195 the root mean squared error of Testing and Training are:-  7.12 and 1.47 respectively
#
#
# At random state of :- 196 Testing Accuracy and Training Accuracy are:-  78.49 and 90.32 respectively
# At random state of :-  196 the mean absolute error of Testing and Training are:-  3.02 and 2.8 respectively
# At random state of :-  196 the mean squared error of Testing and Training are:-  11.33 and 2.8 respectively
# At random state of :-  196 the root mean squared error of Testing and Training are:-  3.37 and 1.67 respectively
#
#
# At random state of :- 197 Testing Accuracy and Training Accuracy are:-  48.04 and 94.17 respectively
# At random state of :-  197 the mean absolute error of Testing and Training are:-  5.81 and 2.05 respectively
# At random state of :-  197 the mean squared error of Testing and Training are:-  49.19 and 2.05 respectively
# At random state of :-  197 the root mean squared error of Testing and Training are:-  7.01 and 1.43 respectively
#
#
# At random state of :- 198 Testing Accuracy and Training Accuracy are:-  58.42 and 89.73 respectively
# At random state of :-  198 the mean absolute error of Testing and Training are:-  6.94 and 2.44 respectively
# At random state of :-  198 the mean squared error of Testing and Training are:-  51.28 and 2.44 respectively
# At random state of :-  198 the root mean squared error of Testing and Training are:-  7.16 and 1.56 respectively
#
#
# At random state of :- 199 Testing Accuracy and Training Accuracy are:-  44.64 and 92.34 respectively
# At random state of :-  199 the mean absolute error of Testing and Training are:-  7.55 and 2.38 respectively
# At random state of :-  199 the mean squared error of Testing and Training are:-  68.41 and 2.38 respectively
# At random state of :-  199 the root mean squared error of Testing and Training are:-  8.27 and 1.54 respectively

# %% [markdown]
# The best accuracy is 81.43 at random state 71

# %% [markdown]
# We have found best_random state value as 71. We will now create our tain_test_splitusing this randome_state

# %% [markdown]
# # Creating train_test_split....

# %%
#using the random state of 6
x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=71,test_size=0.20)

# %% [markdown]
# # Training Model and Metrics Measurement(r2_Score,MAE,MSE,RMSE)

# %%
rf=RandomForestRegressor()#Initializing...
rf.fit(x_train,y_train)#Training...
pred_test=rf.predict(x_test)#Prediciting using test data...
pred_train=rf.predict(x_train)#Prediciting using training data...
Test_Accuracy_rf= (metrics.r2_score(y_test,pred_test))#Calculating r2 score for test data
Train_Accuracy_rf= (metrics.r2_score(y_train,pred_train))#Calculating r2 score for training data
Test_mae_rf= mean_absolute_error(y_test,pred_test)#Calculating mean absolute error for test data
Train_mae_rf= mean_absolute_error(y_train,pred_train)#Calculating mean absolute error for training data
Test_mse_rf= mean_squared_error(y_test,pred_test)#Calculating mean squared error for test data
Train_mse_rf= mean_squared_error(y_train,pred_train)#Calculating mean squared error for training data
Test_rmse_rf= np.sqrt(mean_squared_error(y_test,pred_test))#Calculating root mean squared error for test data
Train_rmse_rf= np.sqrt(mean_squared_error(y_train,pred_train))#Calculating root mean squared error for training data
print("Test_Accuracy ",round(metrics.r2_score(y_test,pred_test)*100,2))#printing testing accuracy
print("Test_MAE ", Test_mae_rf)#printing mean absolute error 
print("Test_MSE ", Test_mse_rf)#printing mean squared error
print("Test_RMSE ", Test_rmse_rf)#printing root mean squared error
# Out:
# Test_Accuracy  72.06
# Test_MAE  2.67333333333333
# Test_MSE  8.257399999999981
# Test_RMSE  2.8735692091891543

# %% [markdown]
# RandomForest is producing good accuracy = 72.06%!. Now we will check Cross Validation score as well for overfitting(if exists).

# %% [markdown]
# # Cross Validation Score

# %%
#Validation accuracy
vac=cross_val_score(rf,X,Y,cv=5)
CV_Score_rf=vac.mean() 
print(vac)
print("Cross Validation Score is ",CV_Score_rf)
# Out:
# [ 0.17123561 -5.36720344  0.21949848  0.44201545  0.81422686]
# Cross Validation Score is  -0.7440454068480109

# %% [markdown]
# # Difference between Accuracy Score and Cross Validation Score

# %%
Test_Accuracy_rf
# Out:
# 0.7206142857142864

# %%
CV_Score_rf
# Out:
# -0.7440454068480109

# %%
rf_Acc_vs_CV_Score=np.abs(Test_Accuracy_rf-CV_Score_rf)
print("Difference between Accuracy and Cross Validation Score = ",rf_Acc_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score =  1.4646596925622974

# %% [markdown]
# From the above you can see that difference between Accuracy and Cross Validation score is high meaning that model is having overfitting or underfitting problems!!
#
# We would love to improve on this Accuracy by applying the Hyperparameter Tunning, However lets see performance of other Models!

# %% [markdown]
# # Step 5.5 - AdaBoost Classifier

# %% [markdown]
# # Best Random State

# %%
#Using AdaBoost Regressor to get the best Random state
ada=AdaBoostRegressor()
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=i,test_size=0.20)
    ada.fit(x_train,y_train)
    pred_train=ada.predict(x_train)
    pred_test=ada.predict(x_test)
    print("At random state of :-",i,"Testing Accuracy and Training Accuracy are:- ",round(metrics.r2_score(y_test,pred_test)*100,2), "and", round(metrics.r2_score(y_train,pred_train)*100,2), "respectively")
    print("At random state of :- ",i, "the mean absolute error of Testing and Training are:- ",round(mean_absolute_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the mean squared error of Testing and Training are:- ",round(mean_squared_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the root mean squared error of Testing and Training are:- ",round(np.sqrt(mean_squared_error(y_test,pred_test)),2), "and", round(np.sqrt(mean_absolute_error(y_train,pred_train)),2), "respectively")
    print("\n")
# Out:
# At random state of :- 0 Testing Accuracy and Training Accuracy are:-  4.49 and 99.07 respectively
# At random state of :-  0 the mean absolute error of Testing and Training are:-  7.34 and 0.68 respectively
# At random state of :-  0 the mean squared error of Testing and Training are:-  61.98 and 0.68 respectively
# At random state of :-  0 the root mean squared error of Testing and Training are:-  7.87 and 0.82 respectively
#
#
# At random state of :- 1 Testing Accuracy and Training Accuracy are:-  60.36 and 98.14 respectively
# At random state of :-  1 the mean absolute error of Testing and Training are:-  6.63 and 0.88 respectively
# At random state of :-  1 the mean squared error of Testing and Training are:-  55.85 and 0.88 respectively
# At random state of :-  1 the root mean squared error of Testing and Training are:-  7.47 and 0.94 respectively
#
#
# At random state of :- 2 Testing Accuracy and Training Accuracy are:-  26.81 and 97.86 respectively
# At random state of :-  2 the mean absolute error of Testing and Training are:-  7.62 and 0.95 respectively
# At random state of :-  2 the mean squared error of Testing and Training are:-  77.27 and 0.95 respectively
# At random state of :-  2 the root mean squared error of Testing and Training are:-  8.79 and 0.97 respectively
#
#
# At random state of :- 3 Testing Accuracy and Training Accuracy are:-  59.97 and 98.42 respectively
# At random state of :-  3 the mean absolute error of Testing and Training are:-  7.29 and 0.89 respectively
# At random state of :-  3 the mean squared error of Testing and Training are:-  63.47 and 0.89 respectively
# At random state of :-  3 the root mean squared error of Testing and Training are:-  7.97 and 0.94 respectively
#
#
# At random state of :- 4 Testing Accuracy and Training Accuracy are:-  67.79 and 98.42 respectively
# At random state of :-  4 the mean absolute error of Testing and Training are:-  4.1 and 0.76 respectively
# At random state of :-  4 the mean squared error of Testing and Training are:-  20.8 and 0.76 respectively
# At random state of :-  4 the root mean squared error of Testing and Training are:-  4.56 and 0.87 respectively
#
#
# At random state of :- 5 Testing Accuracy and Training Accuracy are:-  52.91 and 98.38 respectively
# At random state of :-  5 the mean absolute error of Testing and Training are:-  6.87 and 0.97 respectively
# At random state of :-  5 the mean squared error of Testing and Training are:-  53.44 and 0.97 respectively
# At random state of :-  5 the root mean squared error of Testing and Training are:-  7.31 and 0.98 respectively
#
#
# At random state of :- 6 Testing Accuracy and Training Accuracy are:-  48.56 and 97.93 respectively
# At random state of :-  6 the mean absolute error of Testing and Training are:-  7.14 and 0.91 respectively
# At random state of :-  6 the mean squared error of Testing and Training are:-  69.73 and 0.91 respectively
# At random state of :-  6 the root mean squared error of Testing and Training are:-  8.35 and 0.96 respectively
#
#
# At random state of :- 7 Testing Accuracy and Training Accuracy are:-  3.06 and 98.14 respectively
# At random state of :-  7 the mean absolute error of Testing and Training are:-  5.65 and 1.0 respectively
# At random state of :-  7 the mean squared error of Testing and Training are:-  43.19 and 1.0 respectively
# At random state of :-  7 the root mean squared error of Testing and Training are:-  6.57 and 1.0 respectively
#
#
# At random state of :- 8 Testing Accuracy and Training Accuracy are:-  52.62 and 98.2 respectively
# At random state of :-  8 the mean absolute error of Testing and Training are:-  7.24 and 0.91 respectively
# At random state of :-  8 the mean squared error of Testing and Training are:-  63.18 and 0.91 respectively
# At random state of :-  8 the root mean squared error of Testing and Training are:-  7.95 and 0.95 respectively
#
#
# At random state of :- 9 Testing Accuracy and Training Accuracy are:-  27.52 and 98.74 respectively
# At random state of :-  9 the mean absolute error of Testing and Training are:-  5.57 and 0.77 respectively
# At random state of :-  9 the mean squared error of Testing and Training are:-  45.28 and 0.77 respectively
# At random state of :-  9 the root mean squared error of Testing and Training are:-  6.73 and 0.88 respectively
#
#
# At random state of :- 10 Testing Accuracy and Training Accuracy are:-  32.1 and 98.8 respectively
# At random state of :-  10 the mean absolute error of Testing and Training are:-  4.14 and 0.81 respectively
# At random state of :-  10 the mean squared error of Testing and Training are:-  22.63 and 0.81 respectively
# At random state of :-  10 the root mean squared error of Testing and Training are:-  4.76 and 0.9 respectively
#
#
# At random state of :- 11 Testing Accuracy and Training Accuracy are:-  54.69 and 98.78 respectively
# At random state of :-  11 the mean absolute error of Testing and Training are:-  4.0 and 0.77 respectively
# At random state of :-  11 the mean squared error of Testing and Training are:-  25.33 and 0.77 respectively
# At random state of :-  11 the root mean squared error of Testing and Training are:-  5.03 and 0.88 respectively
#
#
# At random state of :- 12 Testing Accuracy and Training Accuracy are:-  -5.25 and 98.79 respectively
# At random state of :-  12 the mean absolute error of Testing and Training are:-  6.33 and 0.86 respectively
# At random state of :-  12 the mean squared error of Testing and Training are:-  48.3 and 0.86 respectively
# At random state of :-  12 the root mean squared error of Testing and Training are:-  6.95 and 0.93 respectively
#
#
# At random state of :- 13 Testing Accuracy and Training Accuracy are:-  53.8 and 98.71 respectively
# At random state of :-  13 the mean absolute error of Testing and Training are:-  5.4 and 0.74 respectively
# At random state of :-  13 the mean squared error of Testing and Training are:-  38.5 and 0.74 respectively
# At random state of :-  13 the root mean squared error of Testing and Training are:-  6.2 and 0.86 respectively
#
#
# At random state of :- 14 Testing Accuracy and Training Accuracy are:-  59.93 and 97.97 respectively
# At random state of :-  14 the mean absolute error of Testing and Training are:-  6.02 and 1.06 respectively
# At random state of :-  14 the mean squared error of Testing and Training are:-  43.23 and 1.06 respectively
# At random state of :-  14 the root mean squared error of Testing and Training are:-  6.58 and 1.03 respectively
#
#
# At random state of :- 15 Testing Accuracy and Training Accuracy are:-  40.2 and 98.37 respectively
# At random state of :-  15 the mean absolute error of Testing and Training are:-  8.24 and 0.9 respectively
# At random state of :-  15 the mean squared error of Testing and Training are:-  77.68 and 0.9 respectively
# At random state of :-  15 the root mean squared error of Testing and Training are:-  8.81 and 0.95 respectively
#
#
# At random state of :- 16 Testing Accuracy and Training Accuracy are:-  -15.44 and 98.64 respectively
# At random state of :-  16 the mean absolute error of Testing and Training are:-  7.61 and 0.79 respectively
# At random state of :-  16 the mean squared error of Testing and Training are:-  81.35 and 0.79 respectively
# At random state of :-  16 the root mean squared error of Testing and Training are:-  9.02 and 0.89 respectively
#
#
# At random state of :- 17 Testing Accuracy and Training Accuracy are:-  9.99 and 99.27 respectively
# At random state of :-  17 the mean absolute error of Testing and Training are:-  9.0 and 0.57 respectively
# At random state of :-  17 the mean squared error of Testing and Training are:-  109.21 and 0.57 respectively
# At random state of :-  17 the root mean squared error of Testing and Training are:-  10.45 and 0.75 respectively
#
#
# At random state of :- 18 Testing Accuracy and Training Accuracy are:-  -27.99 and 98.3 respectively
# At random state of :-  18 the mean absolute error of Testing and Training are:-  6.51 and 0.93 respectively
# At random state of :-  18 the mean squared error of Testing and Training are:-  55.22 and 0.93 respectively
# At random state of :-  18 the root mean squared error of Testing and Training are:-  7.43 and 0.97 respectively
#
#
# At random state of :- 19 Testing Accuracy and Training Accuracy are:-  49.64 and 98.46 respectively
# At random state of :-  19 the mean absolute error of Testing and Training are:-  5.82 and 0.91 respectively
# At random state of :-  19 the mean squared error of Testing and Training are:-  42.42 and 0.91 respectively
# At random state of :-  19 the root mean squared error of Testing and Training are:-  6.51 and 0.96 respectively
#
#
# At random state of :- 20 Testing Accuracy and Training Accuracy are:-  20.56 and 99.44 respectively
# At random state of :-  20 the mean absolute error of Testing and Training are:-  4.82 and 0.53 respectively
# At random state of :-  20 the mean squared error of Testing and Training are:-  38.13 and 0.53 respectively
# At random state of :-  20 the root mean squared error of Testing and Training are:-  6.18 and 0.73 respectively
#
#
# At random state of :- 21 Testing Accuracy and Training Accuracy are:-  22.47 and 99.29 respectively
# At random state of :-  21 the mean absolute error of Testing and Training are:-  5.89 and 0.58 respectively
# At random state of :-  21 the mean squared error of Testing and Training are:-  59.38 and 0.58 respectively
# At random state of :-  21 the root mean squared error of Testing and Training are:-  7.71 and 0.76 respectively
#
#
# At random state of :- 22 Testing Accuracy and Training Accuracy are:-  26.87 and 99.0 respectively
# At random state of :-  22 the mean absolute error of Testing and Training are:-  6.12 and 0.71 respectively
# At random state of :-  22 the mean squared error of Testing and Training are:-
We will now create our tain_test_splitusing this randome_state

# %% [markdown]
# # Creating train_test_split....

# %%
x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=154,test_size=0.20)

# %% [markdown]
# # Training Model and Metrics Measurement(r2_Score,MAE,MSE,RMSE)

# %%
ada=AdaBoostRegressor()#Initializing...
ada.fit(x_train,y_train)#Training...
pred_test=ada.predict(x_test)#Prediciting using test data...
pred_train=ada.predict(x_train)#Prediciting using training data...
Test_Accuracy_ada= (metrics.r2_score(y_test,pred_test))#Calculating r2 score for test data
Train_Accuracy_ada= (metrics.r2_score(y_train,pred_train))#Calculating r2 score for training data
Test_mae_ada= mean_absolute_error(y_test,pred_test)#Calculating mean absolute error for test data
Train_mae_ada= mean_absolute_error(y_train,pred_train)#Calculating mean absolute error for training data
Test_mse_ada= mean_squared_error(y_test,pred_test)#Calculating mean squared error for test data
Train_mse_ada= mean_squared_error(y_train,pred_train)#Calculating mean squared error for training data
Test_rmse_ada= np.sqrt(mean_squared_error(y_test,pred_test))#Calculating root mean squared error for test data
Train_rmse_ada= np.sqrt(mean_squared_error(y_train,pred_train))#Calculating root mean squared error for training data
print("Test_Accuracy ",round(metrics.r2_score(y_test,pred_test)*100,2))#printing testing accuracy
print("Test_MAE ", Test_mae_ada)#printing mean absolute error
print("Test_MSE ", Test_mse_ada)#printing mean squared error
print("Test_RMSE ", Test_rmse_ada)#printing root mean squared error
# Out:
# Test_Accuracy  72.15
# Test_MAE  4.166666666666667
# Test_MSE  25.5
# Test_RMSE  5.049752469181039

# %% [markdown]
# AdaBoost is producing good accuracy = 72.15%!. Now we will check Cross Validation score as well for overfitting(if exists).

# %% [markdown]
# # Cross Validation Score

# %%
#Validation accuracy
vac=cross_val_score(ada,X,Y,cv=5)
CV_Score_ada=vac.mean() 
print(vac)
print("Cross Validation Score is ",CV_Score_ada)
# Out:
# [ 0.31666593 -5.70316794  0.38505966  0.34840071  0.86667365]
# Cross Validation Score is  -0.7572735996178933

# %% [markdown]
# # Difference between Accuracy Score and Cross Validation Score

# %%
Test_Accuracy_ada
# Out:
# 0.7214805825242718

# %%
CV_Score_ada
# Out:
# -0.7572735996178933

# %%
ada_Acc_vs_CV_Score=np.abs(Test_Accuracy_ada-CV_Score_ada)
print("Difference between Accuracy and Cross Validation Score = ",ada_Acc_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score =  1.4787541821421653

# %% [markdown]
# From the above you can see that difference between Accuracy and Cross Validation score is high meaning that model is having overfitting or underfitting problems!!
#
# We would love to improve on this Accuracy by applying the Hyperparameter Tunning, However lets see performance of other Models!

# %% [markdown]
# # Step 5.6 - GradientBoosting Classifier

# %% [markdown]
# # Best Random State

# %%
#Using GradientBoosting to get the best Random state
gb=GradientBoostingRegressor()
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=i,test_size=0.20)
    gb.fit(x_train,y_train)
    pred_train=gb.predict(x_train)
    pred_test=gb.predict(x_test)
    print("At random state of :-",i,"Testing Accuracy and Training Accuracy are:- ",round(metrics.r2_score(y_test,pred_test)*100,2), "and", round(metrics.r2_score(y_train,pred_train)*100,2), "respectively")
    print("At random state of :- ",i, "the mean absolute error of Testing and Training are:- ",round(mean_absolute_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the mean squared error of Testing and Training are:- ",round(mean_squared_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the root mean squared error of Testing and Training are:- ",round(np.sqrt(mean_squared_error(y_test,pred_test)),2), "and", round(np.sqrt(mean_absolute_error(y_train,pred_train)),2), "respectively")
    print("\n")
# Out:
# At random state of :- 0 Testing Accuracy and Training Accuracy are:-  -32.62 and 100.0 respectively
# At random state of :-  0 the mean absolute error of Testing and Training are:-  7.95 and 0.01 respectively
# At random state of :-  0 the mean squared error of Testing and Training are:-  86.05 and 0.01 respectively
# At random state of :-  0 the root mean squared error of Testing and Training are:-  9.28 and 0.09 respectively
#
#
# At random state of :- 1 Testing Accuracy and Training Accuracy are:-  56.72 and 100.0 respectively
# At random state of :-  1 the mean absolute error of Testing and Training are:-  6.18 and 0.01 respectively
# At random state of :-  1 the mean squared error of Testing and Training are:-  60.98 and 0.01 respectively
# At random state of :-  1 the root mean squared error of Testing and Training are:-  7.81 and 0.12 respectively
#
#
# At random state of :- 2 Testing Accuracy and Training Accuracy are:-  28.02 and 100.0 respectively
# At random state of :-  2 the mean absolute error of Testing and Training are:-  8.05 and 0.01 respectively
# At random state of :-  2 the mean squared error of Testing and Training are:-  76.0 and 0.01 respectively
# At random state of :-  2 the root mean squared error of Testing and Training are:-  8.72 and 0.12 respectively
#
#
# At random state of :- 3 Testing Accuracy and Training Accuracy are:-  61.74 and 100.0 respectively
# At random state of :-  3 the mean absolute error of Testing and Training are:-  7.03 and 0.0 respectively
# At random state of :-  3 the mean squared error of Testing and Training are:-  60.67 and 0.0 respectively
# At random state of :-  3 the root mean squared error of Testing and Training are:-  7.79 and 0.06 respectively
#
#
# At random state of :- 4 Testing Accuracy and Training Accuracy are:-  59.93 and 100.0 respectively
# At random state of :-  4 the mean absolute error of Testing and Training are:-  3.26 and 0.01 respectively
# At random state of :-  4 the mean squared error of Testing and Training are:-  25.88 and 0.01 respectively
# At random state of :-  4 the root mean squared error of Testing and Training are:-  5.09 and 0.09 respectively
#
#
# At random state of :- 5 Testing Accuracy and Training Accuracy are:-  60.03 and 100.0 respectively
# At random state of :-  5 the mean absolute error of Testing and Training are:-  5.99 and 0.01 respectively
# At random state of :-  5 the mean squared error of Testing and Training are:-  45.36 and 0.01 respectively
# At random state of :-  5 the root mean squared error of Testing and Training are:-  6.73 and 0.12 respectively
#
#
# At random state of :- 6 Testing Accuracy and Training Accuracy are:-  44.17 and 100.0 respectively
# At random state of :-  6 the mean absolute error of Testing and Training are:-  6.58 and 0.02 respectively
# At random state of :-  6 the mean squared error of Testing and Training are:-  75.69 and 0.02 respectively
# At random state of :-  6 the root mean squared error of Testing and Training are:-  8.7 and 0.15 respectively
#
#
# At random state of :- 7 Testing Accuracy and Training Accuracy are:-  -21.61 and 100.0 respectively
# At random state of :-  7 the mean absolute error of Testing and Training are:-  5.49 and 0.01 respectively
# At random state of :-  7 the mean squared error of Testing and Training are:-  54.18 and 0.01 respectively
# At random state of :-  7 the root mean squared error of Testing and Training are:-  7.36 and 0.09 respectively
#
#
# At random state of :- 8 Testing Accuracy and Training Accuracy are:-  63.54 and 100.0 respectively
# At random state of :-  8 the mean absolute error of Testing and Training are:-  5.81 and 0.01 respectively
# At random state of :-  8 the mean squared error of Testing and Training are:-  48.62 and 0.01 respectively
# At random state of :-  8 the root mean squared error of Testing and Training are:-  6.97 and 0.09 respectively
#
#
# At random state of :- 9 Testing Accuracy and Training Accuracy are:-  -66.74 and 100.0 respectively
# At random state of :-  9 the mean absolute error of Testing and Training are:-  7.82 and 0.0 respectively
# At random state of :-  9 the mean squared error of Testing and Training are:-  104.17 and 0.0 respectively
# At random state of :-  9 the root mean squared error of Testing and Training are:-  10.21 and 0.06 respectively
#
#
# At random state of :- 10 Testing Accuracy and Training Accuracy are:-  -66.62 and 100.0 respectively
# At random state of :-  10 the mean absolute error of Testing and Training are:-  6.41 and 0.0 respectively
# At random state of :-  10 the mean squared error of Testing and Training are:-  55.54 and 0.0 respectively
# At random state of :-  10 the root mean squared error of Testing and Training are:-  7.45 and 0.06 respectively
#
#
# At random state of :- 11 Testing Accuracy and Training Accuracy are:-  5.16 and 100.0 respectively
# At random state of :-  11 the mean absolute error of Testing and Training are:-  5.71 and 0.0 respectively
# At random state of :-  11 the mean squared error of Testing and Training are:-  53.03 and 0.0 respectively
# At random state of :-  11 the root mean squared error of Testing and Training are:-  7.28 and 0.07 respectively
#
#
# At random state of :- 12 Testing Accuracy and Training Accuracy are:-  -2.47 and 100.0 respectively
# At random state of :-  12 the mean absolute error of Testing and Training are:-  6.53 and 0.01 respectively
# At random state of :-  12 the mean squared error of Testing and Training are:-  47.02 and 0.01 respectively
# At random state of :-  12 the root mean squared error of Testing and Training are:-  6.86 and 0.09 respectively
#
#
# At random state of :- 13 Testing Accuracy and Training Accuracy are:-  44.74 and 100.0 respectively
# At random state of :-  13 the mean absolute error of Testing and Training are:-  5.18 and 0.0 respectively
# At random state of :-  13 the mean squared error of Testing and Training are:-  46.05 and 0.0 respectively
# At random state of :-  13 the root mean squared error of Testing and Training are:-  6.79 and 0.06 respectively
#
#
# At random state of :- 14 Testing Accuracy and Training Accuracy are:-  31.85 and 100.0 respectively
# At random state of :-  14 the mean absolute error of Testing and Training are:-  8.23 and 0.0 respectively
# At random state of :-  14 the mean squared error of Testing and Training are:-  73.53 and 0.0 respectively
# At random state of :-  14 the root mean squared error of Testing and Training are:-  8.58 and 0.06 respectively
#
#
# At random state of :- 15 Testing Accuracy and Training Accuracy are:-  25.24 and 100.0 respectively
# At random state of :-  15 the mean absolute error of Testing and Training are:-  8.74 and 0.01 respectively
# At random state of :-  15 the mean squared error of Testing and Training are:-  97.1 and 0.01 respectively
# At random state of :-  15 the root mean squared error of Testing and Training are:-  9.85 and 0.09 respectively
#
#
# At random state of :- 16 Testing Accuracy and Training Accuracy are:-  -24.55 and 100.0 respectively
# At random state of :-  16 the mean absolute error of Testing and Training are:-  7.92 and 0.01 respectively
# At random state of :-  16 the mean squared error of Testing and Training are:-  87.77 and 0.01 respectively
# At random state of :-  16 the root mean squared error of Testing and Training are:-  9.37 and 0.07 respectively
#
#
# At random state of :- 17 Testing Accuracy and Training Accuracy are:-  -20.04 and 100.0 respectively
# At random state of :-  17 the mean absolute error of Testing and Training are:-  10.95 and 0.01 respectively
# At random state of :-  17 the mean squared error of Testing and Training are:-  145.65 and 0.01 respectively
# At random state of :-  17 the root mean squared error of Testing and Training are:-  12.07 and 0.09 respectively
#
#
# At random state of :- 18 Testing Accuracy and Training Accuracy are:-  -11.43 and 100.0 respectively
# At random state of :-  18 the mean absolute error of Testing and Training are:-
respectively
# At random state of :-  196 the root mean squared error of Testing and Training are:-  4.36 and 0.13 respectively
#
#
# At random state of :- 197 Testing Accuracy and Training Accuracy are:-  30.4 and 100.0 respectively
# At random state of :-  197 the mean absolute error of Testing and Training are:-  6.44 and 0.01 respectively
# At random state of :-  197 the mean squared error of Testing and Training are:-  65.88 and 0.01 respectively
# At random state of :-  197 the root mean squared error of Testing and Training are:-  8.12 and 0.09 respectively
#
#
# At random state of :- 198 Testing Accuracy and Training Accuracy are:-  58.03 and 100.0 respectively
# At random state of :-  198 the mean absolute error of Testing and Training are:-  5.53 and 0.02 respectively
# At random state of :-  198 the mean squared error of Testing and Training are:-  51.76 and 0.02 respectively
# At random state of :-  198 the root mean squared error of Testing and Training are:-  7.19 and 0.13 respectively
#
#
# At random state of :- 199 Testing Accuracy and Training Accuracy are:-  33.6 and 100.0 respectively
# At random state of :-  199 the mean absolute error of Testing and Training are:-  8.38 and 0.01 respectively
# At random state of :-  199 the mean squared error of Testing and Training are:-  82.06 and 0.01 respectively
# At random state of :-  199 the root mean squared error of Testing and Training are:-  9.06 and 0.12 respectively

# %% [markdown]
# The best accuracy is 82.12% at random state 29

# %% [markdown]
# We have found best_random state value as 29. We will now create our tain_test_splitusing this randome_state

# %% [markdown]
# # Creating train_test_split....

# %%
x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=29,test_size=0.20)

# %% [markdown]
# # Training Model and Metrics Measurement(r2_Score,MAE,MSE,RMSE)

# %%
gb=GradientBoostingRegressor()#Initializing...
gb.fit(x_train,y_train)#Training...
pred_test=gb.predict(x_test)#Prediciting using test data...
pred_train=gb.predict(x_train)#Prediciting using training data...
Test_Accuracy_gb= (metrics.r2_score(y_test,pred_test))#Calculating r2 score for test data
Train_Accuracy_gb= (metrics.r2_score(y_train,pred_train))#Calculating r2 score for training data
Test_mae_gb= mean_absolute_error(y_test,pred_test)#Calculating mean absolute error for test data
Train_mae_gb= mean_absolute_error(y_train,pred_train)#Calculating mean absolute error for training data
Test_mse_gb= mean_squared_error(y_test,pred_test)#Calculating mean squared error for test data
Train_mse_gb= mean_squared_error(y_train,pred_train)#Calculating mean squared error for training data
Test_rmse_gb= np.sqrt(mean_squared_error(y_test,pred_test))#Calculating root mean squared error for test data
Train_rmse_gb= np.sqrt(mean_squared_error(y_train,pred_train))#Calculating root mean squared error for training data
print("Test_Accuracy ",round(metrics.r2_score(y_test,pred_test)*100,2))#printing testing accuracy
print("Test_MAE ", Test_mae_gb)#printing mean absolute error
print("Test_MSE ", Test_mse_gb)#printing mean squared error
print("Test_RMSE ", Test_rmse_gb)#printing root mean squared error
# Out:
# Test_Accuracy  81.44
# Test_MAE  4.361939327616663
# Test_MSE  23.30823727171311
# Test_RMSE  4.827860527367491

# %% [markdown]
# GradientBoosting is producing good accuracy = 81.44%. Now we will check Cross Validation score as well for overfitting(if exists).

# %% [markdown]
# # Cross Validation Score

# %%
#Validation accuracy
vac=cross_val_score(gb,X,Y,cv=5)
CV_Score_gb=vac.mean() 
print(vac)
print("Cross Validation Score is ",CV_Score_gb)
# Out:
# [ 0.20335796 -7.67899176 -0.11147641  0.6646991   0.92785758]
# Cross Validation Score is  -1.1989107072795737

# %% [markdown]
# # Difference between Accuracy Score and Cross Validation Score

# %%
Test_Accuracy_gb
# Out:
# 0.8143591721721964

# %%
CV_Score_gb
# Out:
# -1.1989107072795737

# %%
gb_Acc_vs_CV_Score=np.abs(Test_Accuracy_gb-CV_Score_gb)
print("Difference between Accuracy and Cross Validation Score = ",gb_Acc_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score =  2.0132698794517703

# %% [markdown]
# From the above you can see that difference between Accuracy and Cross Validation score is high meaning that model is having overfitting or underfitting problems!!
#
# We would love to improve on this Accuracy by applying the Hyperparameter Tunning, However lets see performance of other Models!

# %% [markdown]
# # Step 5.7 - XGBoost Classifier

# %% [markdown]
# # Best Random State

# %%
#Using XGBoost Regressor to get the best Random state
xgb=XGBRegressor()
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=i,test_size=0.20)
    xgb.fit(x_train,y_train)
    pred_train=xgb.predict(x_train)
    pred_test=xgb.predict(x_test)
    print("At random state of :-",i,"Testing Accuracy and Training Accuracy are:- ",round(metrics.r2_score(y_test,pred_test)*100,2), "and", round(metrics.r2_score(y_train,pred_train)*100,2), "respectively")
    print("At random state of :- ",i, "the mean absolute error of Testing and Training are:- ",round(mean_absolute_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the mean squared error of Testing and Training are:- ",round(mean_squared_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the root mean squared error of Testing and Training are:- ",round(np.sqrt(mean_squared_error(y_test,pred_test)),2), "and", round(np.sqrt(mean_absolute_error(y_train,pred_train)),2), "respectively")
    print("\n")
# Out:
# At random state of :- 0 Testing Accuracy and Training Accuracy are:-  -23.55 and 100.0 respectively
# At random state of :-  0 the mean absolute error of Testing and Training are:-  6.88 and 0.0 respectively
# At random state of :-  0 the mean squared error of Testing and Training are:-  80.17 and 0.0 respectively
# At random state of :-  0 the root mean squared error of Testing and Training are:-  8.95 and 0.02 respectively
#
#
# At random state of :- 1 Testing Accuracy and Training Accuracy are:-  55.71 and 100.0 respectively
# At random state of :-  1 the mean absolute error of Testing and Training are:-  6.35 and 0.0 respectively
# At random state of :-  1 the mean squared error of Testing and Training are:-  62.4 and 0.0 respectively
# At random state of :-  1 the root mean squared error of Testing and Training are:-  7.9 and 0.02 respectively
#
#
# At random state of :- 2 Testing Accuracy and Training Accuracy are:-  21.31 and 100.0 respectively
# At random state of :-  2 the mean absolute error of Testing and Training are:-  7.42 and 0.0 respectively
# At random state of :-  2 the mean squared error of Testing and Training are:-  83.09 and 0.0 respectively
# At random state of :-  2 the root mean squared error of Testing and Training are:-  9.12 and 0.02 respectively
#
#
# At random state of :- 3 Testing Accuracy and Training Accuracy are:-  13.61 and 100.0 respectively
# At random state of :-  3 the mean absolute error of Testing and Training are:-  10.63 and 0.0 respectively
# At random state of :-  3 the mean squared error of Testing and Training are:-  136.98 and 0.0 respectively
# At random state of :-  3 the root mean squared error of Testing and Training are:-  11.7 and 0.02 respectively
#
#
# At random state of :- 4 Testing Accuracy and Training Accuracy are:-  6.04 and 100.0 respectively
# At random state of :-  4 the mean absolute error of Testing and Training are:-  6.24 and 0.0 respectively
# At random state of :-  4 the mean squared error of Testing and Training are:-  60.68 and 0.0 respectively
# At random state of :-  4 the root mean squared error of Testing and Training are:-  7.79 and 0.02 respectively
#
#
# At random state of :- 5 Testing Accuracy and Training Accuracy are:-  57.64 and 100.0 respectively
# At random state of :-  5 the mean absolute error of Testing and Training are:-  4.05 and 0.0 respectively
# At random state of :-  5 the mean squared error of Testing and Training are:-  48.07 and 0.0 respectively
# At random state of :-  5 the root mean squared error of Testing and Training are:-  6.93 and 0.02 respectively
#
#
# At random state of :- 6 Testing Accuracy and Training Accuracy are:-  -10.06 and 100.0 respectively
# At random state of :-  6 the mean absolute error of Testing and Training are:-  9.11 and 0.0 respectively
# At random state of :-  6 the mean squared error of Testing and Training are:-  149.19 and 0.0 respectively
# At random state of :-  6 the root mean squared error of Testing and Training are:-  12.21 and 0.02 respectively
#
#
# At random state of :- 7 Testing Accuracy and Training Accuracy are:-  -100.33 and 100.0 respectively
# At random state of :-  7 the mean absolute error of Testing and Training are:-  7.8 and 0.0 respectively
# At random state of :-  7 the mean squared error of Testing and Training are:-  89.26 and 0.0 respectively
# At random state of :-  7 the root mean squared error of Testing and Training are:-  9.45 and 0.02 respectively
#
#
# At random state of :- 8 Testing Accuracy and Training Accuracy are:-  38.45 and 100.0 respectively
# At random state of :-  8 the mean absolute error of Testing and Training are:-  7.8 and 0.0 respectively
# At random state of :-  8 the mean squared error of Testing and Training are:-  82.07 and 0.0 respectively
# At random state of :-  8 the root mean squared error of Testing and Training are:-  9.06 and 0.02 respectively
#
#
# At random state of :- 9 Testing Accuracy and Training Accuracy are:-  -40.31 and 100.0 respectively
# At random state of :-  9 the mean absolute error of Testing and Training are:-  6.89 and 0.0 respectively
# At random state of :-  9 the mean squared error of Testing and Training are:-  87.66 and 0.0 respectively
# At random state of :-  9 the root mean squared error of Testing and Training are:-  9.36 and 0.02 respectively
#
#
# At random state of :- 10 Testing Accuracy and Training Accuracy are:-  -110.44 and 100.0 respectively
# At random state of :-  10 the mean absolute error of Testing and Training are:-  6.84 and 0.0 respectively
# At random state of :-  10 the mean squared error of Testing and Training are:-  70.15 and 0.0 respectively
# At random state of :-  10 the root mean squared error of Testing and Training are:-  8.38 and 0.02 respectively
#
#
# At random state of :- 11 Testing Accuracy and Training Accuracy are:-  0.8 and 100.0 respectively
# At random state of :-  11 the mean absolute error of Testing and Training are:-  6.13 and 0.0 respectively
# At random state of :-  11 the mean squared error of Testing and Training are:-  55.47 and 0.0 respectively
# At random state of :-  11 the root mean squared error of Testing and Training are:-  7.45 and 0.02 respectively
#
#
# At random state of :- 12 Testing Accuracy and Training Accuracy are:-  -24.75 and 100.0 respectively
# At random state of :-  12 the mean absolute error of Testing and Training are:-  6.26 and 0.0 respectively
# At random state of :-  12 the mean squared error of Testing and Training are:-  57.25 and 0.0 respectively
# At random state of :-  12 the root mean squared error of Testing and Training are:-  7.57 and 0.02 respectively
#
#
# At random state of :- 13 Testing Accuracy and Training Accuracy are:-  55.82 and 100.0 respectively
# At random state of :-  13 the mean absolute error of Testing and Training are:-  4.49 and 0.0 respectively
# At random state of :-  13 the mean squared error of Testing and Training are:-
respectively
# At random state of :-  189 the root mean squared error of Testing and Training are:-  6.96 and 0.02 respectively
#
#
# At random state of :- 190 Testing Accuracy and Training Accuracy are:-  29.08 and 100.0 respectively
# At random state of :-  190 the mean absolute error of Testing and Training are:-  8.26 and 0.0 respectively
# At random state of :-  190 the mean squared error of Testing and Training are:-  86.28 and 0.0 respectively
# At random state of :-  190 the root mean squared error of Testing and Training are:-  9.29 and 0.02 respectively
#
#
# At random state of :- 191 Testing Accuracy and Training Accuracy are:-  46.4 and 100.0 respectively
# At random state of :-  191 the mean absolute error of Testing and Training are:-  5.79 and 0.0 respectively
# At random state of :-  191 the mean squared error of Testing and Training are:-  57.67 and 0.0 respectively
# At random state of :-  191 the root mean squared error of Testing and Training are:-  7.59 and 0.02 respectively
#
#
# At random state of :- 192 Testing Accuracy and Training Accuracy are:-  -126.15 and 100.0 respectively
# At random state of :-  192 the mean absolute error of Testing and Training are:-  7.46 and 0.0 respectively
# At random state of :-  192 the mean squared error of Testing and Training are:-  78.71 and 0.0 respectively
# At random state of :-  192 the root mean squared error of Testing and Training are:-  8.87 and 0.02 respectively
#
#
# At random state of :- 193 Testing Accuracy and Training Accuracy are:-  56.5 and 100.0 respectively
# At random state of :-  193 the mean absolute error of Testing and Training are:-  6.37 and 0.0 respectively
# At random state of :-  193 the mean squared error of Testing and Training are:-  59.74 and 0.0 respectively
# At random state of :-  193 the root mean squared error of Testing and Training are:-  7.73 and 0.02 respectively
#
#
# At random state of :- 194 Testing Accuracy and Training Accuracy are:-  -62.96 and 100.0 respectively
# At random state of :-  194 the mean absolute error of Testing and Training are:-  6.93 and 0.0 respectively
# At random state of :-  194 the mean squared error of Testing and Training are:-  75.32 and 0.0 respectively
# At random state of :-  194 the root mean squared error of Testing and Training are:-  8.68 and 0.02 respectively
#
#
# At random state of :- 195 Testing Accuracy and Training Accuracy are:-  38.7 and 100.0 respectively
# At random state of :-  195 the mean absolute error of Testing and Training are:-  4.55 and 0.0 respectively
# At random state of :-  195 the mean squared error of Testing and Training are:-  53.62 and 0.0 respectively
# At random state of :-  195 the root mean squared error of Testing and Training are:-  7.32 and 0.02 respectively
#
#
# At random state of :- 196 Testing Accuracy and Training Accuracy are:-  66.56 and 100.0 respectively
# At random state of :-  196 the mean absolute error of Testing and Training are:-  3.12 and 0.0 respectively
# At random state of :-  196 the mean squared error of Testing and Training are:-  17.61 and 0.0 respectively
# At random state of :-  196 the root mean squared error of Testing and Training are:-  4.2 and 0.02 respectively
#
#
# At random state of :- 197 Testing Accuracy and Training Accuracy are:-  4.52 and 100.0 respectively
# At random state of :-  197 the mean absolute error of Testing and Training are:-  7.89 and 0.0 respectively
# At random state of :-  197 the mean squared error of Testing and Training are:-  90.38 and 0.0 respectively
# At random state of :-  197 the root mean squared error of Testing and Training are:-  9.51 and 0.02 respectively
#
#
# At random state of :- 198 Testing Accuracy and Training Accuracy are:-  75.81 and 100.0 respectively
# At random state of :-  198 the mean absolute error of Testing and Training are:-  4.1 and 0.0 respectively
# At random state of :-  198 the mean squared error of Testing and Training are:-  29.84 and 0.0 respectively
# At random state of :-  198 the root mean squared error of Testing and Training are:-  5.46 and 0.02 respectively
#
#
# At random state of :- 199 Testing Accuracy and Training Accuracy are:-  43.7 and 100.0 respectively
# At random state of :-  199 the mean absolute error of Testing and Training are:-  7.62 and 0.0 respectively
# At random state of :-  199 the mean squared error of Testing and Training are:-  69.57 and 0.0 respectively
# At random state of :-  199 the root mean squared error of Testing and Training are:-  8.34 and 0.02 respectively

# %% [markdown]
# The best accuracy is 86.44% at random state 29

# %% [markdown]
# We have found best_random state value as 29. We will now create our tain_test_splitusing this randome_state

# %% [markdown]
# # Creating train_test_split....

# %%
x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=29,test_size=0.20)

# %% [markdown]
# # Training Model and Metrics Measurement(r2_Score,MAE,MSE,RMSE)

# %%
xgb=XGBRegressor()#Initializing...
xgb.fit(x_train,y_train)#Training...
pred_test=xgb.predict(x_test)#Prediciting using test data...
pred_train=xgb.predict(x_train)#Prediciting using training data...
Test_Accuracy_xgb=(metrics.r2_score(y_test,pred_test))#Calculating r2 score for test data
Train_Accuracy_xgb= (metrics.r2_score(y_train,pred_train))#Calculating r2 score for training data
Test_mae_xgb= mean_absolute_error(y_test,pred_test)#Calculating mean absolute error for test data
Train_mae_xgb= mean_absolute_error(y_train,pred_train)#Calculating mean absolute error for training data
Test_mse_xgb= mean_squared_error(y_test,pred_test)#Calculating mean squared error for test data
Train_mse_xgb= mean_squared_error(y_train,pred_train)#Calculating mean squared error for training data
Test_rmse_xgb= np.sqrt(mean_squared_error(y_test,pred_test))#Calculating root mean squared error for test data
Train_rmse_xgb= np.sqrt(mean_squared_error(y_train,pred_train))#Calculating root mean squared error for training data
print("Test_Accuracy ",round(metrics.r2_score(y_test,pred_test)*100,2))#printing testing accuracy
print("Test_MAE ", Test_mae_xgb)#printing mean absolute error
print("Test_MSE ", Test_mse_xgb)#printing mean squared error
print("Test_RMSE ", Test_rmse_xgb)#printing root mean squared error
# Out:
# Test_Accuracy  86.44
# Test_MAE  3.7108167012532554
# Test_MSE  17.0286381955472
# Test_RMSE  4.12657705556884

# %% [markdown]
# XGBoost is producing good accuracy = 86.44%. Now we will check Cross Validation score as well for overfitting(if exists).

# %% [markdown]
# # Cross Validation Score

# %%
#Validation accuracy
vac=cross_val_score(xgb,X,Y,cv=5)
CV_Score_xgb=vac.mean() 
print(vac)
print("Cross Validation Score is ",CV_Score_xgb)
# Out:
# [-1.1132855  -4.21131684 -0.43666512  0.57395226  0.82105132]
# Cross Validation Score is  -0.8732527783192247

# %% [markdown]
# # Difference between Accuracy Score and Cross Validation Score

# %%
Test_Accuracy_xgb
# Out:
# 0.8643736780885621

# %%
CV_Score_xgb
# Out:
# -0.8732527783192247

# %%
xgb_Acc_vs_CV_Score=np.abs(Test_Accuracy_xgb-CV_Score_xgb)
print("Difference between Accuracy and Cross Validation Score = ",xgb_Acc_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score =  1.7376264564077868

# %% [markdown]
# From the above you can see that difference between Accuracy and Cross Validation score is high meaning that model is having overfitting or underfitting problems!!
#
# We would love to improve on this Accuracy by applying the Hyperparameter Tunning, However lets see performance of other Models!

# %% [markdown]
# # Step 5.8 - ExtraTrees Regressor

# %% [markdown]
# # Best Random State

# %%
#Using ExtraTree Regressor to get the best Random state
ex=ExtraTreesRegressor()
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=i,test_size=0.20)
    ex.fit(x_train,y_train)
    pred_train=ex.predict(x_train)
    pred_test=ex.predict(x_test)
    print("At random state of :-",i,"Testing Accuracy and Training Accuracy are:- ",round(metrics.r2_score(y_test,pred_test)*100,2), "and", round(metrics.r2_score(y_train,pred_train)*100,2), "respectively")
    print("At random state of :- ",i, "the mean absolute error of Testing and Training are:- ",round(mean_absolute_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the mean squared error of Testing and Training are:- ",round(mean_squared_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the root mean squared error of Testing and Training are:- ",round(np.sqrt(mean_squared_error(y_test,pred_test)),2), "and", round(np.sqrt(mean_absolute_error(y_train,pred_train)),2), "respectively")
    print("\n")
# Out:
# At random state of :- 0 Testing Accuracy and Training Accuracy are:-  42.46 and 100.0 respectively
# At random state of :-  0 the mean absolute error of Testing and Training are:-  4.68 and 0.0 respectively
# At random state of :-  0 the mean squared error of Testing and Training are:-  37.34 and 0.0 respectively
# At random state of :-  0 the root mean squared error of Testing and Training are:-  6.11 and 0.0 respectively
#
#
# At random state of :- 1 Testing Accuracy and Training Accuracy are:-  59.09 and 100.0 respectively
# At random state of :-  1 the mean absolute error of Testing and Training are:-  6.25 and 0.0 respectively
# At random state of :-  1 the mean squared error of Testing and Training are:-  57.64 and 0.0 respectively
# At random state of :-  1 the root mean squared error of Testing and Training are:-  7.59 and 0.0 respectively
#
#
# At random state of :- 2 Testing Accuracy and Training Accuracy are:-  8.86 and 100.0 respectively
# At random state of :-  2 the mean absolute error of Testing and Training are:-  7.85 and 0.0 respectively
# At random state of :-  2 the mean squared error of Testing and Training are:-  96.23 and 0.0 respectively
# At random state of :-  2 the root mean squared error of Testing and Training are:-  9.81 and 0.0 respectively
#
#
# At random state of :- 3 Testing Accuracy and Training Accuracy are:-  59.76 and 100.0 respectively
# At random state of :-  3 the mean absolute error of Testing and Training are:-  6.45 and 0.0 respectively
# At random state of :-  3 the mean squared error of Testing and Training are:-  63.8 and 0.0 respectively
# At random state of :-  3 the root mean squared error of Testing and Training are:-  7.99 and 0.0 respectively
#
#
# At random state of :- 4 Testing Accuracy and Training Accuracy are:-  81.2 and 100.0 respectively
# At random state of :-  4 the mean absolute error of Testing and Training are:-  2.52 and 0.0 respectively
# At random state of :-  4 the mean squared error of Testing and Training are:-  12.14 and 0.0 respectively
# At random state of :-  4 the root mean squared error of Testing and Training are:-  3.48 and 0.0 respectively
#
#
# At random state of :- 5 Testing Accuracy and Training Accuracy are:-  60.01 and 100.0 respectively
# At random state of :-  5 the mean absolute error of Testing and Training are:-  4.97 and 0.0 respectively
# At random state of :-  5 the mean squared error of Testing and Training are:-  45.38 and 0.0 respectively
# At random state of :-  5 the root mean squared error of Testing and Training are:-  6.74 and 0.0 respectively
#
#
# At random state of :- 6 Testing Accuracy and Training Accuracy are:-  44.05 and 100.0 respectively
# At random state of :-  6 the mean absolute error of Testing and Training are:-  6.9 and 0.0 respectively
# At random state of :-  6 the mean squared error of Testing and Training are:-
respectively
#
#
# At random state of :- 182 Testing Accuracy and Training Accuracy are:-  53.46 and 100.0 respectively
# At random state of :-  182 the mean absolute error of Testing and Training are:-  4.86 and 0.0 respectively
# At random state of :-  182 the mean squared error of Testing and Training are:-  41.57 and 0.0 respectively
# At random state of :-  182 the root mean squared error of Testing and Training are:-  6.45 and 0.0 respectively
#
#
# At random state of :- 183 Testing Accuracy and Training Accuracy are:-  4.14 and 100.0 respectively
# At random state of :-  183 the mean absolute error of Testing and Training are:-  6.21 and 0.0 respectively
# At random state of :-  183 the mean squared error of Testing and Training are:-  60.31 and 0.0 respectively
# At random state of :-  183 the root mean squared error of Testing and Training are:-  7.77 and 0.0 respectively
#
#
# At random state of :- 184 Testing Accuracy and Training Accuracy are:-  18.47 and 100.0 respectively
# At random state of :-  184 the mean absolute error of Testing and Training are:-  4.6 and 0.0 respectively
# At random state of :-  184 the mean squared error of Testing and Training are:-  23.28 and 0.0 respectively
# At random state of :-  184 the root mean squared error of Testing and Training are:-  4.83 and 0.0 respectively
#
#
# At random state of :- 185 Testing Accuracy and Training Accuracy are:-  54.07 and 100.0 respectively
# At random state of :-  185 the mean absolute error of Testing and Training are:-  7.15 and 0.0 respectively
# At random state of :-  185 the mean squared error of Testing and Training are:-  68.24 and 0.0 respectively
# At random state of :-  185 the root mean squared error of Testing and Training are:-  8.26 and 0.0 respectively
#
#
# At random state of :- 186 Testing Accuracy and Training Accuracy are:-  25.89 and 100.0 respectively
# At random state of :-  186 the mean absolute error of Testing and Training are:-  5.36 and 0.0 respectively
# At random state of :-  186 the mean squared error of Testing and Training are:-  50.56 and 0.0 respectively
# At random state of :-  186 the root mean squared error of Testing and Training are:-  7.11 and 0.0 respectively
#
#
# At random state of :- 187 Testing Accuracy and Training Accuracy are:-  51.22 and 100.0 respectively
# At random state of :-  187 the mean absolute error of Testing and Training are:-  4.57 and 0.0 respectively
# At random state of :-  187 the mean squared error of Testing and Training are:-  26.79 and 0.0 respectively
# At random state of :-  187 the root mean squared error of Testing and Training are:-  5.18 and 0.0 respectively
#
#
# At random state of :- 188 Testing Accuracy and Training Accuracy are:-  51.6 and 100.0 respectively
# At random state of :-  188 the mean absolute error of Testing and Training are:-  4.79 and 0.0 respectively
# At random state of :-  188 the mean squared error of Testing and Training are:-  30.82 and 0.0 respectively
# At random state of :-  188 the root mean squared error of Testing and Training are:-  5.55 and 0.0 respectively
#
#
# At random state of :- 189 Testing Accuracy and Training Accuracy are:-  83.91 and 100.0 respectively
# At random state of :-  189 the mean absolute error of Testing and Training are:-  4.78 and 0.0 respectively
# At random state of :-  189 the mean squared error of Testing and Training are:-  28.07 and 0.0 respectively
# At random state of :-  189 the root mean squared error of Testing and Training are:-  5.3 and 0.0 respectively
#
#
# At random state of :- 190 Testing Accuracy and Training Accuracy are:-  64.07 and 100.0 respectively
# At random state of :-  190 the mean absolute error of Testing and Training are:-  5.12 and 0.0 respectively
# At random state of :-  190 the mean squared error of Testing and Training are:-  43.72 and 0.0 respectively
# At random state of :-  190 the root mean squared error of Testing and Training are:-  6.61 and 0.0 respectively
#
#
# At random state of :- 191 Testing Accuracy and Training Accuracy are:-  54.55 and 100.0 respectively
# At random state of :-  191 the mean absolute error of Testing and Training are:-  6.38 and 0.0 respectively
# At random state of :-  191 the mean squared error of Testing and Training are:-  48.89 and 0.0 respectively
# At random state of :-  191 the root mean squared error of Testing and Training are:-  6.99 and 0.0 respectively
#
#
# At random state of :- 192 Testing Accuracy and Training Accuracy are:-  15.62 and 100.0 respectively
# At random state of :-  192 the mean absolute error of Testing and Training are:-  4.5 and 0.0 respectively
# At random state of :-  192 the mean squared error of Testing and Training are:-  29.37 and 0.0 respectively
# At random state of :-  192 the root mean squared error of Testing and Training are:-  5.42 and 0.0 respectively
#
#
# At random state of :- 193 Testing Accuracy and Training Accuracy are:-  60.35 and 100.0 respectively
# At random state of :-  193 the mean absolute error of Testing and Training are:-  5.88 and 0.0 respectively
# At random state of :-  193 the mean squared error of Testing and Training are:-  54.46 and 0.0 respectively
# At random state of :-  193 the root mean squared error of Testing and Training are:-  7.38 and 0.0 respectively
#
#
# At random state of :- 194 Testing Accuracy and Training Accuracy are:-  -40.03 and 100.0 respectively
# At random state of :-  194 the mean absolute error of Testing and Training are:-  7.02 and 0.0 respectively
# At random state of :-  194 the mean squared error of Testing and Training are:-  64.72 and 0.0 respectively
# At random state of :-  194 the root mean squared error of Testing and Training are:-  8.05 and 0.0 respectively
#
#
# At random state of :- 195 Testing Accuracy and Training Accuracy are:-  41.64 and 100.0 respectively
# At random state of :-  195 the mean absolute error of Testing and Training are:-  5.33 and 0.0 respectively
# At random state of :-  195 the mean squared error of Testing and Training are:-  51.05 and 0.0 respectively
# At random state of :-  195 the root mean squared error of Testing and Training are:-  7.15 and 0.0 respectively
#
#
# At random state of :- 196 Testing Accuracy and Training Accuracy are:-  73.76 and 100.0 respectively
# At random state of :-  196 the mean absolute error of Testing and Training are:-  3.38 and 0.0 respectively
# At random state of :-  196 the mean squared error of Testing and Training are:-  13.82 and 0.0 respectively
# At random state of :-  196 the root mean squared error of Testing and Training are:-  3.72 and 0.0 respectively
#
#
# At random state of :- 197 Testing Accuracy and Training Accuracy are:-  40.41 and 100.0 respectively
# At random state of :-  197 the mean absolute error of Testing and Training are:-  5.95 and 0.0 respectively
# At random state of :-  197 the mean squared error of Testing and Training are:-  56.42 and 0.0 respectively
# At random state of :-  197 the root mean squared error of Testing and Training are:-  7.51 and 0.0 respectively
#
#
# At random state of :- 198 Testing Accuracy and Training Accuracy are:-  84.45 and 100.0 respectively
# At random state of :-  198 the mean absolute error of Testing and Training are:-  4.12 and 0.0 respectively
# At random state of :-  198 the mean squared error of Testing and Training are:-  19.18 and 0.0 respectively
# At random state of :-  198 the root mean squared error of Testing and Training are:-  4.38 and 0.0 respectively
#
#
# At random state of :- 199 Testing Accuracy and Training Accuracy are:-  63.2 and 100.0 respectively
# At random state of :-  199 the mean absolute error of Testing and Training are:-  5.86 and 0.0 respectively
# At random state of :-  199 the mean squared error of Testing and Training are:-  45.48 and 0.0 respectively
# At random state of :-  199 the root mean squared error of Testing and Training are:-  6.74 and 0.0 respectively

# %% [markdown]
# The best accuracy is 84.45% at random state 198

# %% [markdown]
# We have found best_random state value as 198. We will now create our tain_test_splitusing this randome_state

# %% [markdown]
# # Creating train_test_split....

# %%
x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=198,test_size=0.20)

# %% [markdown]
# # Training Model and Metrics Measurement(r2_Score,MAE,MSE,RMSE)

# %%
ex=ExtraTreesRegressor()#Initializing...
ex.fit(x_train,y_train)#Training...
pred_test=ex.predict(x_test)#Prediciting using test data...
pred_train=ex.predict(x_train)#Prediciting using training data...
Test_Accuracy_ex= (metrics.r2_score(y_test,pred_test))#Calculating r2 score for test data
Train_Accuracy_ex= (metrics.r2_score(y_train,pred_train))#Calculating r2 score for training data
Test_mae_ex= mean_absolute_error(y_test,pred_test)#Calculating mean absolute error for test data
Train_mae_ex= mean_absolute_error(y_train,pred_train)#Calculating mean absolute error for training data
Test_mse_ex= mean_squared_error(y_test,pred_test)#Calculating mean squared error for test data
Train_mse_ex= mean_squared_error(y_train,pred_train)#Calculating mean squared error for training data
Test_rmse_ex= np.sqrt(mean_squared_error(y_test,pred_test))#Calculating root mean squared error for test data
Train_rmse_ex= np.sqrt(mean_squared_error(y_train,pred_train))#Calculating root mean squared error for training data
print("Test_Accuracy ",round(metrics.r2_score(y_test,pred_test)*100,2))#printing testing accuracy
print("Test_MAE ", Test_mae_ex)#printing mean absolute error
print("Test_MSE ", Test_mse_ex)#printing mean squared error
print("Test_RMSE ", Test_rmse_ex)#printing root mean squared error
# Out:
# Test_Accuracy  81.08
# Test_MAE  4.411666666666666
# Test_MSE  23.33878333333335
# Test_RMSE  4.831023011054009

# %% [markdown]
# ExtraTress  is producing good accuracy = 81.08%. Now we will check Cross Validation score as well for overfitting(if exists).

# %% [markdown]
# # Cross Validation Score

# %%
#Validation of accuracy
vac=cross_val_score(ex,X,Y,cv=5)
CV_Score_ex=vac.mean() 
print(vac)
print("Cross Validation Score is ",CV_Score_ex)
# Out:
# [-0.16108819 -3.86207824  0.33227997  0.34067724  0.85511775]
# Cross Validation Score is  -0.49901829489770455

# %% [markdown]
# # Difference between Accuracy Score and Cross Validation Score

# %%
Test_Accuracy_ex
# Out:
# 0.8107666216216215

# %%
CV_Score_ex
# Out:
# -0.49901829489770455

# %%
ex_Acc_vs_CV_Score=np.abs(Test_Accuracy_ex-CV_Score_ex)
print("Difference between Accuracy and Cross Validation Score = ",ex_Acc_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score =  1.309784916519326

# %% [markdown]
# From the above you can see that difference between Accuracy and Cross Validation score is high meaning that model is having overfitting or underfitting problems!!
#
# We would love to improve on this Accuracy by applying the Hyperparameter Tunning, However lets see performance of other Models!

# %% [markdown]
# # Step 5.9 - Support Vector Regressor(SVR)

# %% [markdown]
# # Best Random State

# %%
#Using Support Vector Regressor to get the best Random state
sv=SVR()
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=i,test_size=0.20)
respectively
# At random state of :-  177 the mean absolute error of Testing and Training are:-  8.54 and 7.2 respectively
# At random state of :-  177 the mean squared error of Testing and Training are:-  109.25 and 7.2 respectively
# At random state of :-  177 the root mean squared error of Testing and Training are:-  10.45 and 2.68 respectively
#
#
# At random state of :- 178 Testing Accuracy and Training Accuracy are:-  11.28 and 22.97 respectively
# At random state of :-  178 the mean absolute error of Testing and Training are:-  6.7 and 7.65 respectively
# At random state of :-  178 the mean squared error of Testing and Training are:-  60.63 and 7.65 respectively
# At random state of :-  178 the root mean squared error of Testing and Training are:-  7.79 and 2.77 respectively
#
#
# At random state of :- 179 Testing Accuracy and Training Accuracy are:-  -21.28 and 22.51 respectively
# At random state of :-  179 the mean absolute error of Testing and Training are:-  9.16 and 7.08 respectively
# At random state of :-  179 the mean squared error of Testing and Training are:-  109.42 and 7.08 respectively
# At random state of :-  179 the root mean squared error of Testing and Training are:-  10.46 and 2.66 respectively
#
#
# At random state of :- 180 Testing Accuracy and Training Accuracy are:-  -3.7 and 23.29 respectively
# At random state of :-  180 the mean absolute error of Testing and Training are:-  7.74 and 7.35 respectively
# At random state of :-  180 the mean squared error of Testing and Training are:-  83.53 and 7.35 respectively
# At random state of :-  180 the root mean squared error of Testing and Training are:-  9.14 and 2.71 respectively
#
#
# At random state of :- 181 Testing Accuracy and Training Accuracy are:-  11.06 and 26.9 respectively
# At random state of :-  181 the mean absolute error of Testing and Training are:-  8.84 and 6.91 respectively
# At random state of :-  181 the mean squared error of Testing and Training are:-  97.44 and 6.91 respectively
# At random state of :-  181 the root mean squared error of Testing and Training are:-  9.87 and 2.63 respectively
#
#
# At random state of :- 182 Testing Accuracy and Training Accuracy are:-  -21.05 and 26.43 respectively
# At random state of :-  182 the mean absolute error of Testing and Training are:-  9.26 and 6.8 respectively
# At random state of :-  182 the mean squared error of Testing and Training are:-  108.14 and 6.8 respectively
# At random state of :-  182 the root mean squared error of Testing and Training are:-  10.4 and 2.61 respectively
#
#
# At random state of :- 183 Testing Accuracy and Training Accuracy are:-  -82.43 and 26.04 respectively
# At random state of :-  183 the mean absolute error of Testing and Training are:-  8.89 and 7.11 respectively
# At random state of :-  183 the mean squared error of Testing and Training are:-  114.78 and 7.11 respectively
# At random state of :-  183 the root mean squared error of Testing and Training are:-  10.71 and 2.67 respectively
#
#
# At random state of :- 184 Testing Accuracy and Training Accuracy are:-  -53.36 and 25.27 respectively
# At random state of :-  184 the mean absolute error of Testing and Training are:-  5.2 and 8.09 respectively
# At random state of :-  184 the mean squared error of Testing and Training are:-  43.79 and 8.09 respectively
# At random state of :-  184 the root mean squared error of Testing and Training are:-  6.62 and 2.84 respectively
#
#
# At random state of :- 185 Testing Accuracy and Training Accuracy are:-  7.08 and 23.15 respectively
# At random state of :-  185 the mean absolute error of Testing and Training are:-  10.94 and 6.57 respectively
# At random state of :-  185 the mean squared error of Testing and Training are:-  138.04 and 6.57 respectively
# At random state of :-  185 the root mean squared error of Testing and Training are:-  11.75 and 2.56 respectively
#
#
# At random state of :- 186 Testing Accuracy and Training Accuracy are:-  -50.17 and 25.41 respectively
# At random state of :-  186 the mean absolute error of Testing and Training are:-  8.43 and 7.11 respectively
# At random state of :-  186 the mean squared error of Testing and Training are:-  102.45 and 7.11 respectively
# At random state of :-  186 the root mean squared error of Testing and Training are:-  10.12 and 2.67 respectively
#
#
# At random state of :- 187 Testing Accuracy and Training Accuracy are:-  2.9 and 25.57 respectively
# At random state of :-  187 the mean absolute error of Testing and Training are:-  6.89 and 7.37 respectively
# At random state of :-  187 the mean squared error of Testing and Training are:-  53.32 and 7.37 respectively
# At random state of :-  187 the root mean squared error of Testing and Training are:-  7.3 and 2.72 respectively
#
#
# At random state of :- 188 Testing Accuracy and Training Accuracy are:-  -19.73 and 24.17 respectively
# At random state of :-  188 the mean absolute error of Testing and Training are:-  6.69 and 7.56 respectively
# At random state of :-  188 the mean squared error of Testing and Training are:-  76.23 and 7.56 respectively
# At random state of :-  188 the root mean squared error of Testing and Training are:-  8.73 and 2.75 respectively
#
#
# At random state of :- 189 Testing Accuracy and Training Accuracy are:-  13.68 and 18.34 respectively
# At random state of :-  189 the mean absolute error of Testing and Training are:-  11.91 and 6.55 respectively
# At random state of :-  189 the mean squared error of Testing and Training are:-  150.6 and 6.55 respectively
# At random state of :-  189 the root mean squared error of Testing and Training are:-  12.27 and 2.56 respectively
#
#
# At random state of :- 190 Testing Accuracy and Training Accuracy are:-  -3.99 and 20.52 respectively
# At random state of :-  190 the mean absolute error of Testing and Training are:-  9.22 and 7.17 respectively
# At random state of :-  190 the mean squared error of Testing and Training are:-  126.52 and 7.17 respectively
# At random state of :-  190 the root mean squared error of Testing and Training are:-  11.25 and 2.68 respectively
#
#
# At random state of :- 191 Testing Accuracy and Training Accuracy are:-  3.21 and 23.56 respectively
# At random state of :-  191 the mean absolute error of Testing and Training are:-  9.09 and 7.03 respectively
# At random state of :-  191 the mean squared error of Testing and Training are:-  104.14 and 7.03 respectively
# At random state of :-  191 the root mean squared error of Testing and Training are:-  10.2 and 2.65 respectively
#
#
# At random state of :- 192 Testing Accuracy and Training Accuracy are:-  -149.17 and 23.24 respectively
# At random state of :-  192 the mean absolute error of Testing and Training are:-  8.41 and 7.44 respectively
# At random state of :-  192 the mean squared error of Testing and Training are:-  86.73 and 7.44 respectively
# At random state of :-  192 the root mean squared error of Testing and Training are:-  9.31 and 2.73 respectively
#
#
# At random state of :- 193 Testing Accuracy and Training Accuracy are:-  -10.41 and 18.75 respectively
# At random state of :-  193 the mean absolute error of Testing and Training are:-  10.77 and 7.02 respectively
# At random state of :-  193 the mean squared error of Testing and Training are:-  151.63 and 7.02 respectively
# At random state of :-  193 the root mean squared error of Testing and Training are:-  12.31 and 2.65 respectively
#
#
# At random state of :- 194 Testing Accuracy and Training Accuracy are:-  -367.56 and 21.37 respectively
# At random state of :-  194 the mean absolute error of Testing and Training are:-  13.24 and 6.66 respectively
# At random state of :-  194 the mean squared error of Testing and Training are:-  216.12 and 6.66 respectively
# At random state of :-  194 the root mean squared error of Testing and Training are:-  14.7 and 2.58 respectively
#
#
# At random state of :- 195 Testing Accuracy and Training Accuracy are:-  8.38 and 23.21 respectively
# At random state of :-  195 the mean absolute error of Testing and Training are:-  7.8 and 7.28 respectively
# At random state of :-  195 the mean squared error of Testing and Training are:-  80.14 and 7.28 respectively
# At random state of :-  195 the root mean squared error of Testing and Training are:-  8.95 and 2.7 respectively
#
#
# At random state of :- 196 Testing Accuracy and Training Accuracy are:-  9.02 and 24.12 respectively
# At random state of :-  196 the mean absolute error of Testing and Training are:-  4.85 and 7.94 respectively
# At random state of :-  196 the mean squared error of Testing and Training are:-  47.92 and 7.94 respectively
# At random state of :-  196 the root mean squared error of Testing and Training are:-  6.92 and 2.82 respectively
#
#
# At random state of :- 197 Testing Accuracy and Training Accuracy are:-  9.25 and 21.52 respectively
# At random state of :-  197 the mean absolute error of Testing and Training are:-  8.52 and 7.27 respectively
# At random state of :-  197 the mean squared error of Testing and Training are:-  85.91 and 7.27 respectively
# At random state of :-  197 the root mean squared error of Testing and Training are:-  9.27 and 2.7 respectively
#
#
# At random state of :- 198 Testing Accuracy and Training Accuracy are:-  -37.39 and 17.89 respectively
# At random state of :-  198 the mean absolute error of Testing and Training are:-  12.3 and 6.73 respectively
# At random state of :-  198 the mean squared error of Testing and Training are:-  169.45 and 6.73 respectively
# At random state of :-  198 the root mean squared error of Testing and Training are:-  13.02 and 2.59 respectively
#
#
# At random state of :- 199 Testing Accuracy and Training Accuracy are:-  -0.83 and 25.18 respectively
# At random state of :-  199 the mean absolute error of Testing and Training are:-  9.22 and 7.0 respectively
# At random state of :-  199 the mean squared error of Testing and Training are:-  124.61 and 7.0 respectively
# At random state of :-  199 the root mean squared error of Testing and Training are:-  11.16 and 2.65 respectively

# %% [markdown]
# The best accuracy is 30.64% at random state 143

# %% [markdown]
# We have found best_random state value as 143. We will now create our tain_test_splitusing this randome_state

# %% [markdown]
# # Creating train_test_split....

# %%
x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=143,test_size=0.20)

# %% [markdown]
# # Training Model and Metrics Measurement(r2_Score,MAE,MSE,RMSE)

# %%
sv=SVR()#Initializing...
sv.fit(x_train,y_train)#Training...
pred_test=sv.predict(x_test)#Prediciting using test data...
pred_train=sv.predict(x_train)#Prediciting using training data...
Test_Accuracy_sv= (metrics.r2_score(y_test,pred_test))#Calculating r2 score for test data
Train_Accuracy_sv= (metrics.r2_score(y_train,pred_train))#Calculating r2 score for training data
Test_mae_sv= mean_absolute_error(y_test,pred_test)#Calculating mean absolute error for test data
Train_mae_sv= mean_absolute_error(y_train,pred_train)#Calculating mean absolute error for training data
Test_mse_sv= mean_squared_error(y_test,pred_test)#Calculating mean squared error for test data
Train_mse_sv= mean_squared_error(y_train,pred_train)#Calculating mean squared error for training data
Test_rmse_sv= np.sqrt(mean_squared_error(y_test,pred_test))#Calculating root mean squared error for test data
Train_rmse_sv= np.sqrt(mean_squared_error(y_train,pred_train))#Calculating root mean squared error for training data
print("Test_Accuracy ",round(metrics.r2_score(y_test,pred_test)*100,2))#printing testing accuracy
print("Test_MAE ", Test_mae_sv)#printing mean absolute error
print("Test_MSE ", Test_mse_sv)#printing mean squared error
print("Test_RMSE ", Test_rmse_sv)#printing root mean squared error
# Out:
# Test_Accuracy  30.64
# Test_MAE  3.930327592062459
# Test_MSE  20.268154211218143
# Test_RMSE  4.502016682689897

# %% [markdown]
# Support Vector is producing poor accuracy = 30.64%. Now we will check Cross Validation score as well for overfitting(if exists).

# %% [markdown]
# # Cross Validation Score

# %%
#Validation accuracy
vac=cross_val_score(sv,X,Y,cv=5)
CV_Score_sv=vac.mean() 
print(vac)
print("Cross Validation Score is ",CV_Score_sv)
# Out:
# [-0.17886913 -0.76175069 -0.32134358 -0.75772061 -0.29094017]
# Cross Validation Score is  -0.46212483450688424

# %% [markdown]
# # Difference between Accuracy Score and Cross Validation Score

# %%
Test_Accuracy_sv
# Out:
# 0.30641297376059595

# %%
CV_Score_sv
# Out:
# -0.46212483450688424

# %%
sv_Acc_vs_CV_Score=np.abs(Test_Accuracy_sv-CV_Score_sv)
print("Difference between Accuracy and Cross Validation Score = ",sv_Acc_vs_CV_Score)
# Out:
# Difference between Accuracy and Cross Validation Score =  0.7685378082674802

# %% [markdown]
# From the above you can see that difference between Accuracy and Cross Validation score is high meaning that our model is having overfitting or underfitting problems!!

# %% [markdown]
#  Now that we have build 9 models in total lets compare each of them and find the best Model!

# %% [markdown]
# # Step 6 - COMPARING ALL MACHINE LEARNING MODELS

# %% [markdown]
# Lets create a dataframe that will juxtapose the metrics of all the models...

# %%
#Constructing a dataframe...
models = pd.DataFrame({'ML_Model' : ['Linear Regression','KNeigbors Regressor','DecisionTree Regressor','Random Forest Regressor','Ada Boosting Regressor','Gradient Boosting Regressor', 'XgBoost','Extra Trees Regressor','SVR'],'Accuracy_Score' : [Test_Accuracy_lm,Test_Accuracy_knn,Test_Accuracy_dt,Test_Accuracy_rf,Test_Accuracy_ada,Test_Accuracy_gb,Test_Accuracy_xgb,Test_Accuracy_ex,Test_Accuracy_sv],'Cross_Validation_Score':[CV_Score_lm,CV_Score_knn,CV_Score_dt,CV_Score_rf,CV_Score_ada,CV_Score_gb,CV_Score_xgb,CV_Score_ex,CV_Score_sv],'Accuracy_VS_CVScore':[lm_Acc_vs_CV_Score,knn_Acc_vs_CV_Score,dt_Acc_vs_CV_Score,rf_Acc_vs_CV_Score,ada_Acc_vs_CV_Score,gb_Acc_vs_CV_Score,xgb_Acc_vs_CV_Score,ex_Acc_vs_CV_Score,sv_Acc_vs_CV_Score],'MAE':[Test_mae_lm,Test_mae_knn,Test_mae_dt,Test_mae_rf,Test_mae_ada,Test_mae_gb,Test_mae_xgb,Test_mae_ex,Test_mae_sv],'MSE':[Test_mse_lm,Test_mse_knn,Test_mse_dt,Test_mse_rf,Test_mse_ada,Test_mse_gb,Test_mse_xgb,Test_mse_ex,Test_mse_sv],'RMSE':[Test_rmse_lm,Test_rmse_knn,Test_rmse_dt,Test_rmse_rf,Test_rmse_ada,Test_rmse_gb,Test_rmse_xgb,Test_rmse_ex,Test_rmse_sv]})
models
# Out:
#                       ML_Model  Accuracy_Score  Cross_Validation_Score  \
# 0            Linear Regression        0.930220                0.023351
# 1          KNeigbors Regressor        0.731744               -0.331644
# 2       DecisionTree Regressor        0.700258               -2.269308
# 3      Random Forest Regressor        0.720614               -0.744045
# 4       Ada Boosting Regressor        0.721481               -0.757274
# 5  Gradient Boosting Regressor        0.814359               -1.198911
# 6                      XgBoost        0.864374               -0.873253
# 7        Extra Trees Regressor        0.810767               -0.499018
# 8                          SVR        0.306413               -0.462125
#
#    Accuracy_VS_CVScore       MAE        MSE      RMSE
# 0             0.906869  2.663534   8.761305  2.959950
# 1             1.063388  3.100000  15.380000  3.921734
# 2             2.969566  5.000000  38.666667  6.218253
# 3             1.464660  2.673333   8.257400  2.873569
# 4             1.478754  4.166667  25.500000  5.049752
# 5             2.013270  4.361939  23.308237  4.827861
# 6             1.737626  3.710817  17.028638  4.126577
# 7             1.309785  4.411667  23.338783  4.831023
# 8             0.768538  3.930328  20.268154  4.502017

# %%
#Converting Accuracy and Cross_Validation_Score into Percentage....
models["Accuracy_Score"] = np.ceil((models["Accuracy_Score"] * 100))
models["Cross_Validation_Score"] = np.ceil((models["Cross_Validation_Score"] * 100))
models.sort_values(by = 'Accuracy_Score', ascending = False)
# Out:
#                       ML_Model  Accuracy_Score  Cross_Validation_Score  \
# 0            Linear Regression            94.0                     3.0
# 6                      XgBoost            87.0                   -87.0
# 5  Gradient Boosting Regressor            82.0                  -119.0
# 7        Extra Trees Regressor            82.0                   -49.0
# 1          KNeigbors Regressor            74.0                   -33.0
# 3      Random Forest Regressor            73.0                   -74.0
# 4       Ada Boosting Regressor            73.0                   -75.0
# 2       DecisionTree Regressor            71.0                  -226.0
# 8                          SVR            31.0                   -46.0
#
#    Accuracy_VS_CVScore       MAE        MSE      RMSE
# 0             0.906869  2.663534   8.761305  2.959950
# 6             1.737626  3.710817  17.028638  4.126577
# 5             2.013270  4.361939  23.308237  4.827861
# 7             1.309785  4.411667  23.338783  4.831023
# 1             1.063388  3.100000  15.380000  3.921734
# 3             1.464660  2.673333   8.257400  2.873569
# 4             1.478754  4.166667  25.500000  5.049752
# 2             2.969566  5.000000  38.666667  6.218253
# 8             0.768538  3.930328  20.268154  4.502017

# %%
#Now focusing on the Accuracy Score....
plt.figure(figsize = (10, 5))
sns.set_style('darkgrid')

sns.barplot(x = 'Accuracy_Score', y = 'ML_Model', data = models)

plt.xlabel('Accuracy Score in %', fontsize = 15)
plt.ylabel('ML Model', fontsize = 15)

plt.title('ML Model Comparison', fontsize = 16)

plt.show()

# %% [markdown]
# Now from the above diagram it seems that Linear Regression(93%) has the highest Accuracy, However, our aim is to find the BEST MODEL, so lets consider the difference Between Accuracy_Score and Cross_Validation_Score....

# %% [markdown]
# # Step 6.1 - Comparing Differences between Accuracy and Cross_Validation Scores...

# %% [markdown]
# Lets sort by the column; Accuracy_VS_CVScore to have a good view of the differential between Accuracy_Score and CVScore

# %%
#Sorting....
models.sort_values(by = 'Accuracy_VS_CVScore', ascending = True)
# Out:
#                       ML_Model  Accuracy_Score  Cross_Validation_Score  \
# 8                          SVR            31.0                   -46.0
# 0            Linear Regression            94.0                     3.0
# 1          KNeigbors Regressor            74.0                   -33.0
# 7        Extra Trees Regressor            82.0                   -49.0
# 3      Random Forest Regressor            73.0                   -74.0
# 4       Ada Boosting Regressor            73.0                   -75.0
# 6                      XgBoost            87.0                   -87.0
# 5  Gradient Boosting Regressor            82.0                  -119.0
# 2       DecisionTree Regressor            71.0                  -226.0
#
#    Accuracy_VS_CVScore       MAE        MSE      RMSE
# 8             0.768538  3.930328  20.268154  4.502017
# 0             0.906869  2.663534   8.761305  2.959950
# 1             1.063388  3.100000  15.380000  3.921734
# 7             1.309785  4.411667  23.338783  4.831023
# 3             1.464660  2.673333   8.257400  2.873569
# 4             1.478754  4.166667  25.500000  5.049752
# 6             1.737626  3.710817  17.028638  4.126577
# 5             2.013270  4.361939  23.308237  4.827861
# 2             2.969566  5.000000  38.666667  6.218253

# %%
#A more clearer visualization.....
plt.figure(figsize = (10, 5))
sns.set_style('darkgrid')

sns.barplot(x = 'Accuracy_VS_CVScore', y = 'ML_Model', data = models)

plt.xlabel('Difference btw Accuracy Score and Cross_Validation Score ', fontsize = 15)
plt.ylabel('ML Model', fontsize = 15)

plt.title('Accuracy VS CVScore Comparison', fontsize = 16)

plt.show()

# %% [markdown]
# From the above we can see the Model with least difference is decision tree regressor!

# %% [markdown]
# # Step 6.2 - Conclusion on Best Choice of Model

# %% [markdown]
# From the above we can see:
#  - The Model with Linear regression model has the best performance.Eventhough the difference between the cross validation score and the accuracy is a bit high which is as a result of the size of the data which is small.As we all know that small data doesnt perform well under cross validations.

# %% [markdown]
# # Hence Optimum Machine Model Chosen = LINEAR REGRESSION MODEL!

# %% [markdown]
# # Step 7 - HYPERPARAMETER TUNNING
#  - Lets prepare list of parameters with options

# %%
# Lets import ridge and lasso regularisation models for linear regression hyper parameter tuning
from sklearn.linear_model import Lasso,Ridge,LinearRegression

# %%
#Using LinearRegression to get the best Random state
lm=LinearRegression()
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=i,test_size=0.20)
    lm.fit(x_train,y_train)
    pred_train=lm.predict(x_train)
    pred_test=lm.predict(x_test)
    print("At random state of :-",i,"Testing Accuracy and Training Accuracy are:- ",round(metrics.r2_score(y_test,pred_test)*100,2), "and", round(metrics.r2_score(y_train,pred_train)*100,2), "respectively")
    print("At random state of :- ",i, "the mean absolute error of Testing and Training are:- ",round(mean_absolute_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the mean squared error of Testing and Training are:- ",round(mean_squared_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the root mean squared error of Testing and Training are:- ",round(np.sqrt(mean_squared_error(y_test,pred_test)),2), "and", round(np.sqrt(mean_absolute_error(y_train,pred_train)),2), "respectively")
    print("\n")
# Out:
# At random state of :- 0 Testing Accuracy and Training Accuracy are:-  47.32 and 90.31 respectively
# At random state of :-  0 the mean absolute error of Testing and Training are:-  5.6 and 2.48 respectively
# At random state of :-  0 the mean squared error of Testing and Training are:-  34.18 and 2.48 respectively
# At random state of :-  0 the root mean squared error of Testing and Training are:-  5.85 and 1.57 respectively
#
#
# At random state of :- 1 Testing Accuracy and Training Accuracy are:-  61.34 and 91.25 respectively
# At random state of :-  1 the mean absolute error of Testing and Training are:-  6.11 and 2.4 respectively
# At random state of :-  1 the mean squared error of Testing and Training are:-  54.47 and 2.4 respectively
# At random state of :-  1 the root mean squared error of Testing and Training are:-  7.38 and 1.55 respectively
#
#
# At random state of :- 2 Testing Accuracy and Training Accuracy are:-  11.98 and 92.31 respectively
# At random state of :-  2 the mean absolute error of Testing and Training are:-  8.84 and 2.38 respectively
# At random state of :-  2 the mean squared error of Testing and Training are:-  92.94 and 2.38 respectively
# At random state of :-  2 the root mean squared error of Testing and Training are:-  9.64 and 1.54 respectively
#
#
# At random state of :- 3 Testing Accuracy and Training Accuracy are:-  86.58 and 85.43 respectively
# At random state of :-  3 the mean absolute error of Testing and Training are:-  3.48 and 3.02 respectively
# At random state of :-  3 the mean squared error of Testing and Training are:-  21.28 and 3.02 respectively
# At random state of :-  3 the root mean squared error of Testing and Training are:-  4.61 and 1.74 respectively
#
#
# At random state of :- 4 Testing Accuracy and Training Accuracy are:-  90.81 and 85.25 respectively
# At random state of :-  4 the mean absolute error of Testing and Training are:-  1.79 and 3.09 respectively
# At random state of :-  4 the mean squared error of Testing and Training are:-  5.94 and 3.09 respectively
# At random state of :-  4 the root mean squared error of Testing and Training are:-  2.44 and 1.76 respectively
#
#
# At random state of :- 5 Testing Accuracy and Training Accuracy are:-  81.2 and 87.26 respectively
# At random state of :-  5 the mean absolute error of Testing and Training are:-  4.01 and 2.79 respectively
# At random state of :-  5 the mean squared error of Testing and Training are:-  21.34 and 2.79 respectively
# At random state of :-  5 the root mean squared error of Testing and Training are:-  4.62 and 1.67 respectively
#
#
# At random state of :- 6 Testing Accuracy and Training Accuracy are:-  74.77 and 88.64 respectively
# At random state of :-  6 the mean absolute error of Testing and Training are:-  4.83 and 2.56 respectively
# At random state of :-  6 the mean squared error of Testing and Training are:-  34.2 and 2.56 respectively
# At random state of :-  6 the root mean squared error of Testing and Training are:-  5.85 and 1.6 respectively
#
#
# At random state of :- 7 Testing Accuracy and Training Accuracy are:-  30.94 and 89.97 respectively
# At random state of :-  7 the mean absolute error of Testing and Training are:-  4.26 and 2.61 respectively
# At random state of :-  7 the mean squared error of Testing and Training are:-  30.77 and 2.61 respectively
# At random state of :-  7 the root mean squared error of Testing and Training are:-  5.55 and 1.62 respectively
#
#
# At random state of :- 8 Testing Accuracy and Training Accuracy are:-  88.68 and 85.08 respectively
# At random state of :-  8 the mean absolute error of Testing and Training are:-  3.56 and 2.83 respectively
# At random state of :-  8 the mean squared error of Testing and Training are:-  15.09 and 2.83 respectively
# At random state of :-  8 the root mean squared error of Testing and Training are:-  3.88 and 1.68 respectively
#
#
# At random state of :- 9 Testing Accuracy and Training Accuracy are:-  56.66 and 87.92 respectively
# At random state of :-  9 the mean absolute error of Testing and Training are:-  4.52 and 2.88 respectively
# At random state of :-  9 the mean squared error of Testing and Training are:-  27.08 and 2.88 respectively
# At random state of :-  9 the root mean squared error of Testing and Training are:-  5.2 and 1.7 respectively
#
#
# At random state of :- 10 Testing Accuracy and Training Accuracy are:-  39.25 and 87.89 respectively
# At random state of :-  10 the mean absolute error of Testing and Training are:-  4.09 and 3.18 respectively
# At random state of :-  10 the mean squared error of Testing and Training are:-  20.25 and 3.18 respectively
# At random state of :-  10 the root mean squared error of Testing and Training are:-  4.5 and 1.78 respectively
#
#
# At random state of :- 11 Testing Accuracy and Training Accuracy are:-  27.45 and 91.38 respectively
# At random state of :-  11 the mean absolute error of Testing and Training are:-  4.96 and 2.43 respectively
# At random state of :-  11 the mean squared error of Testing and Training are:-  40.57 and 2.43 respectively
# At random state of :-  11 the root mean squared error of Testing and Training are:-  6.37 and 1.56 respectively
#
#
# At random state of :- 12 Testing Accuracy and Training Accuracy are:-  -22.1 and 90.6 respectively
# At random state of :-  12 the mean absolute error of Testing and Training are:-  6.78 and 2.57 respectively
# At random state of :-  12 the mean squared error of Testing and Training are:-  56.03 and 2.57 respectively
# At random state of :-  12 the root mean squared error of Testing and Training are:-  7.49 and 1.6 respectively
#
#
# At random state of :- 13 Testing Accuracy and Training Accuracy are:-  51.98 and 91.67 respectively
# At random state of :-  13 the mean absolute error of Testing and Training are:-  4.88 and 2.32 respectively
# At random state of :-  13 the mean squared error of Testing and Training are:-  40.02 and 2.32 respectively
# At random state of :-  13 the root mean squared error of Testing and Training are:-  6.33 and 1.52 respectively
#
#
# At random state of :- 14 Testing Accuracy and Training Accuracy are:-  80.95 and 87.25 respectively
# At random state of :-  14 the mean absolute error of Testing and Training are:-  3.98 and 2.86 respectively
# At random state of :-  14 the mean squared error of Testing and Training are:-  20.56 and 2.86 respectively
# At random state of :-  14 the root mean squared error of Testing and Training are:-  4.53 and 1.69 respectively
#
#
# At random state of :- 15 Testing Accuracy and Training Accuracy are:-  66.14 and 87.18 respectively
# At random state of :-  15 the mean absolute error of Testing and Training are:-  5.15 and 2.73 respectively
# At random state of :-  15 the mean squared error of Testing and Training are:-  43.98 and 2.73 respectively
# At random state of :-  15 the root mean squared error of Testing and Training are:-  6.63 and 1.65 respectively
#
#
# At random state of :- 16 Testing Accuracy and Training Accuracy are:-  53.45 and 91.92 respectively
# At random state of :-  16 the mean absolute error of Testing and Training are:-  4.19 and 2.57 respectively
# At random state of :-  16 the mean squared error of Testing and Training are:-  32.8 and 2.57 respectively
# At random state of :-  16 the root mean squared error of Testing and Training are:-  5.73 and 1.6 respectively
#
#
# At random state of :- 17 Testing Accuracy and Training Accuracy are:-  80.62 and 86.65 respectively
# At random state of :-  17 the mean absolute error of Testing and Training are:-  4.39 and 2.66 respectively
# At random state of :-  17 the mean squared error of Testing and Training are:-  23.52 and 2.66 respectively
# At random state of :-  17 the root mean squared error of Testing and Training are:-  4.85 and 1.63 respectively
#
#
# At random state of :- 18 Testing Accuracy and Training Accuracy are:-  53.1 and 88.83 respectively
# At random state of :-  18 the mean absolute error of Testing and Training are:-  3.48 and 2.9 respectively
# At random state of :-  18 the mean squared error of Testing and Training are:-  20.23 and 2.9 respectively
# At random state of :-  18 the root mean squared error of Testing and Training are:-  4.5 and 1.7 respectively
#
#
# At random state of :- 19 Testing Accuracy and Training Accuracy are:-  75.98 and 88.11 respectively
# At random state of :-  19 the mean absolute error of Testing and Training are:-
respectively
# At random state of :-  198 the mean absolute error of Testing and Training are:-  5.9 and 2.78 respectively
# At random state of :-  198 the mean squared error of Testing and Training are:-  37.04 and 2.78 respectively
# At random state of :-  198 the root mean squared error of Testing and Training are:-  6.09 and 1.67 respectively
#
#
# At random state of :- 199 Testing Accuracy and Training Accuracy are:-  71.37 and 88.09 respectively
# At random state of :-  199 the mean absolute error of Testing and Training are:-  5.08 and 2.59 respectively
# At random state of :-  199 the mean squared error of Testing and Training are:-  35.38 and 2.59 respectively
# At random state of :-  199 the root mean squared error of Testing and Training are:-  5.95 and 1.61 respectively

# %%
lasso_params = {'alpha':[0.02, 0.024, 0.025, 0.026, 0.03]}
ridge_params = {'alpha':[200, 230, 250,265, 270, 275, 290, 300, 500]}

models = {'Lasso': GridSearchCV(Lasso(), 
                               param_grid=lasso_params).fit(x_train,y_train).best_estimator_,
           'Ridge': GridSearchCV(Ridge(), 
                               param_grid=ridge_params).fit(x_train,y_train).best_estimator_,}

# %%
models
# Out:
# {'Lasso': Lasso(alpha=0.03), 'Ridge': Ridge(alpha=200)}

# %%
#Using LinearRegression to get the best Random state
lr=Lasso(alpha=0.03)
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print("At random state of :-",i,"Testing Accuracy and Training Accuracy are:- ",round(metrics.r2_score(y_test,pred_test)*100,2), "and", round(metrics.r2_score(y_train,pred_train)*100,2), "respectively")
    print("At random state of :- ",i, "the mean absolute error of Testing and Training are:- ",round(mean_absolute_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the mean squared error of Testing and Training are:- ",round(mean_squared_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the root mean squared error of Testing and Training are:- ",round(np.sqrt(mean_squared_error(y_test,pred_test)),2), "and", round(np.sqrt(mean_absolute_error(y_train,pred_train)),2), "respectively")
    print("\n")
# Out:
# At random state of :- 0 Testing Accuracy and Training Accuracy are:-  50.69 and 90.27 respectively
# At random state of :-  0 the mean absolute error of Testing and Training are:-  5.49 and 2.52 respectively
# At random state of :-  0 the mean squared error of Testing and Training are:-  32.0 and 2.52 respectively
# At random state of :-  0 the root mean squared error of Testing and Training are:-  5.66 and 1.59 respectively
#
#
# At random state of :- 1 Testing Accuracy and Training Accuracy are:-  61.86 and 91.23 respectively
# At random state of :-  1 the mean absolute error of Testing and Training are:-  6.05 and 2.39 respectively
# At random state of :-  1 the mean squared error of Testing and Training are:-  53.74 and 2.39 respectively
# At random state of :-  1 the root mean squared error of Testing and Training are:-  7.33 and 1.54 respectively
#
#
# At random state of :- 2 Testing Accuracy and Training Accuracy are:-  14.24 and 92.29 respectively
# At random state of :-  2 the mean absolute error of Testing and Training are:-  8.72 and 2.39 respectively
# At random state of :-  2 the mean squared error of Testing and Training are:-  90.55 and 2.39 respectively
# At random state of :-  2 the root mean squared error of Testing and Training are:-  9.52 and 1.54 respectively
#
#
# At random state of :- 3 Testing Accuracy and Training Accuracy are:-  87.39 and 85.41 respectively
# At random state of :-  3 the mean absolute error of Testing and Training are:-  3.41 and 3.04 respectively
# At random state of :-  3 the mean squared error of Testing and Training are:-  20.0 and 3.04 respectively
# At random state of :-  3 the root mean squared error of Testing and Training are:-  4.47 and 1.74 respectively
#
#
# At random state of :- 4 Testing Accuracy and Training Accuracy are:-  91.52 and 85.23 respectively
# At random state of :-  4 the mean absolute error of Testing and Training are:-  1.75 and 3.11 respectively
# At random state of :-  4 the mean squared error of Testing and Training are:-  5.48 and 3.11 respectively
# At random state of :-  4 the root mean squared error of Testing and Training are:-  2.34 and 1.76 respectively
#
#
# At random state of :- 5 Testing Accuracy and Training Accuracy are:-  82.16 and 87.24 respectively
# At random state of :-  5 the mean absolute error of Testing and Training are:-  3.83 and 2.8 respectively
# At random state of :-  5 the mean squared error of Testing and Training are:-  20.25 and 2.8 respectively
# At random state of :-  5 the root mean squared error of Testing and Training are:-  4.5 and 1.67 respectively
#
#
# At random state of :- 6 Testing Accuracy and Training Accuracy are:-  75.59 and 88.62 respectively
# At random state of :-  6 the mean absolute error of Testing and Training are:-  4.83 and 2.58 respectively
# At random state of :-  6 the mean squared error of Testing and Training are:-  33.09 and 2.58 respectively
# At random state of :-  6 the root mean squared error of Testing and Training are:-  5.75 and 1.61 respectively
#
#
# At random state of :- 7 Testing Accuracy and Training Accuracy are:-  32.97 and 89.95 respectively
# At random state of :-  7 the mean absolute error of Testing and Training are:-  4.21 and 2.59 respectively
# At random state of :-  7 the mean squared error of Testing and Training are:-  29.87 and 2.59 respectively
# At random state of :-  7 the root mean squared error of Testing and Training are:-  5.47 and 1.61 respectively
#
#
# At random state of :- 8 Testing Accuracy and Training Accuracy are:-  88.86 and 85.07 respectively
# At random state of :-  8 the mean absolute error of Testing and Training are:-  3.51 and 2.85 respectively
# At random state of :-  8 the mean squared error of Testing and Training are:-  14.85 and 2.85 respectively
# At random state of :-  8 the root mean squared error of Testing and Training are:-  3.85 and 1.69 respectively
#
#
# At random state of :- 9 Testing Accuracy and Training Accuracy are:-  56.99 and 87.9 respectively
# At random state of :-  9 the mean absolute error of Testing and Training are:-  4.46 and 2.88 respectively
# At random state of :-  9 the mean squared error of Testing and Training are:-  26.87 and 2.88 respectively
# At random state of :-  9 the root mean squared error of Testing and Training are:-  5.18 and 1.7 respectively
#
#
# At random state of :- 10 Testing Accuracy and Training Accuracy are:-  45.89 and 87.86 respectively
# At random state of :-  10 the mean absolute error of Testing and Training are:-  3.8 and 3.19 respectively
# At random state of :-  10 the mean squared error of Testing and Training are:-  18.04 and 3.19 respectively
# At random state of :-  10 the root mean squared error of Testing and Training are:-  4.25 and 1.79 respectively
#
#
# At random state of :- 11 Testing Accuracy and Training Accuracy are:-  31.39 and 91.36 respectively
# At random state of :-  11 the mean absolute error of Testing and Training are:-  4.69 and 2.45 respectively
# At random state of :-  11 the mean squared error of Testing and Training are:-  38.36 and 2.45 respectively
# At random state of :-  11 the root mean squared error of Testing and Training are:-  6.19 and 1.57 respectively
#
#
# At random state of :- 12 Testing Accuracy and Training Accuracy are:-  -15.98 and 90.59 respectively
# At random state of :-  12 the mean absolute error of Testing and Training are:-  6.63 and 2.59 respectively
# At random state of :-  12 the mean squared error of Testing and Training are:-  53.22 and 2.59 respectively
# At random state of :-  12 the root mean squared error of Testing and Training are:-  7.3 and 1.61 respectively
#
#
# At random state of :- 13 Testing Accuracy and Training Accuracy are:-  53.5 and 91.65 respectively
# At random state of :-  13 the mean absolute error of Testing and Training are:-  4.79 and 2.36 respectively
# At random state of :-  13 the mean squared error of Testing and Training are:-  38.75 and 2.36 respectively
# At random state of :-  13 the root mean squared error of Testing and Training are:-  6.23 and 1.54 respectively
#
#
# At random state of :- 14 Testing Accuracy and Training Accuracy are:-  83.32 and 87.2 respectively
# At random state of :-  14 the mean absolute error of Testing and Training are:-  3.69 and 2.88 respectively
# At random state of :-  14 the mean squared error of Testing and Training are:-  18.0 and 2.88 respectively
# At random state of :-  14 the root mean squared error of Testing and Training are:-  4.24 and 1.7 respectively
#
#
# At random state of :- 15 Testing Accuracy and Training Accuracy are:-  66.05 and 87.17 respectively
# At random state of :-  15 the mean absolute error of Testing and Training are:-  5.25 and 2.73 respectively
# At random state of :-  15 the mean squared error of Testing and Training are:-  44.1 and 2.73 respectively
# At random state of :-  15 the root mean squared error of Testing and Training are:-  6.64 and 1.65 respectively
#
#
# At random state of :- 16 Testing Accuracy and Training Accuracy are:-  53.28 and 91.91 respectively
# At random state of :-  16 the mean absolute error of Testing and Training are:-  4.21 and 2.57 respectively
# At random state of :-  16 the mean squared error of Testing and Training are:-  32.93 and 2.57 respectively
# At random state of :-  16 the root mean squared error of Testing and Training are:-  5.74 and 1.6 respectively
#
#
# At random state of :- 17 Testing Accuracy and Training Accuracy are:-  79.75 and 86.63 respectively
# At random state of :-  17 the mean absolute error of Testing and Training are:-  4.48 and 2.67 respectively
# At random state of :-  17 the mean squared error of Testing and Training are:-  24.57 and 2.67 respectively
# At random state of :-  17 the root mean squared error of Testing and Training are:-  4.96 and 1.63 respectively
#
#
# At random state of :- 18 Testing Accuracy and Training Accuracy are:-  53.8 and 88.82 respectively
# At random state of :-  18 the mean absolute error of Testing and Training are:-  3.45 and 2.91 respectively
# At random state of :-  18 the mean squared error of Testing and Training are:-  19.93 and 2.91 respectively
# At random state of :-  18 the root mean squared error of Testing and Training are:-  4.46 and 1.71 respectively
#
#
# At random state of :- 19 Testing Accuracy and Training Accuracy are:-  77.1 and 88.07 respectively
# At random state of :-  19 the mean absolute error of Testing and Training are:-  3.46 and 2.72 respectively
# At random state of :-  19 the mean squared error of Testing and Training are:-  19.28 and 2.72 respectively
# At random state of :-  19 the root mean squared error of Testing and Training are:-  4.39 and 1.65 respectively
#
#
# At random state of :- 20 Testing Accuracy and Training Accuracy are:-  19.98 and 92.07 respectively
# At random state of :-  20 the mean absolute error of Testing and Training are:-  6.02 and 2.38 respectively
# At random state of :-  20 the mean squared error of Testing and Training are:-  38.41 and 2.38 respectively
# At random state of :-  20 the root mean squared error of Testing and Training are:-  6.2 and 1.54 respectively
#
#
# At random state of :- 21 Testing Accuracy and Training Accuracy are:-  75.46 and 88.51 respectively
# At random state of :-  21 the mean absolute error of Testing and Training are:-  3.82 and 2.77 respectively
# At random state of :-  21 the mean squared error of Testing and Training are:-  18.79 and 2.77 respectively
# At random state of :-  21 the root mean squared error of Testing and Training are:-  4.34 and 1.66 respectively
#
#
# At random state of :- 22 Testing Accuracy and Training Accuracy are:-  65.24 and 87.71 respectively
# At random state of :-  22 the mean absolute error of Testing and Training are:-  4.74 and 2.75 respectively
# At random state of :-  22 the mean squared error of Testing and Training are:-  27.43 and 2.75 respectively
# At random state of :-  22 the root mean squared error of Testing and Training are:-  5.24 and 1.66 respectively
#
#
# At random state of :- 23 Testing Accuracy and Training Accuracy are:-  73.95 and 85.89 respectively
# At random state of :-  23 the mean absolute error of Testing and Training are:-  3.58 and 2.86 respectively
# At random state of :-  23 the mean squared error of Testing and Training are:-  20.18 and 2.86 respectively
# At random state of :-  23 the root mean squared error of Testing and Training are:-  4.49 and 1.69 respectively
#
#
# At random state of :- 24 Testing Accuracy and Training Accuracy are:-  -447.65 and 94.27 respectively
# At random state of :-  24 the mean absolute error of Testing and Training are:-
respectively
# At random state of :-  27 the root mean squared error of Testing and Training are:-  2.13 and 1.94 respectively

# %% [markdown]
# # With hyper parameter tuning of the best parameter of alpha we have improved accuracy of 95.24%
# At random state of :- 162 Testing Accuracy and Training Accuracy are:-  95.24 and 80.63 respectively
# At random state of :-  162 the mean absolute error of Testing and Training are:-  2.5 and 3.15 respectively
# At random state of :-  162 the mean squared error of Testing and Training are:-  9.86 and 3.15 respectively
# At random state of :-  162 the root mean squared error of Testing and Training are:-  3.14 and 1.77 respectively

# %%
#Using ridge regularisation to get the best Random state
rr=Ridge(alpha=200)
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(X_Scaled,Y,random_state=i,test_size=0.20)
    lm.fit(x_train,y_train)
    pred_train=lm.predict(x_train)
    pred_test=lm.predict(x_test)
    print("At random state of :-",i,"Testing Accuracy and Training Accuracy are:- ",round(metrics.r2_score(y_test,pred_test)*100,2), "and", round(metrics.r2_score(y_train,pred_train)*100,2), "respectively")
    print("At random state of :- ",i, "the mean absolute error of Testing and Training are:- ",round(mean_absolute_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the mean squared error of Testing and Training are:- ",round(mean_squared_error(y_test,pred_test),2), "and", round(mean_absolute_error(y_train,pred_train),2), "respectively")
    print("At random state of :- ",i, "the root mean squared error of Testing and Training are:- ",round(np.sqrt(mean_squared_error(y_test,pred_test)),2), "and", round(np.sqrt(mean_absolute_error(y_train,pred_train)),2), "respectively")
    print("\n")
# Out:
# At random state of :- 0 Testing Accuracy and Training Accuracy are:-  47.32 and 90.31 respectively
# At random state of :-  0 the mean absolute error of Testing and Training are:-  5.6 and 2.48 respectively
# At random state of :-  0 the mean squared error of Testing and Training are:-  34.18 and 2.48 respectively
# At random state of :-  0 the root mean squared error of Testing and Training are:-  5.85 and 1.57 respectively
#
#
# At random state of :- 1 Testing Accuracy and Training Accuracy are:-  61.34 and 91.25 respectively
# At random state of :-  1 the mean absolute error of Testing and Training are:-  6.11 and 2.4 respectively
# At random state of :-  1 the mean squared error of Testing and Training are:-  54.47 and 2.4 respectively
# At random state of :-  1 the root mean squared error of Testing and Training are:-  7.38 and 1.55 respectively
#
#
# At random state of :- 2 Testing Accuracy and Training Accuracy are:-  11.98 and 92.31 respectively
# At random state of :-  2 the mean absolute error of Testing and Training are:-  8.84 and 2.38 respectively
# At random state of :-  2 the mean squared error of Testing and Training are:-  92.94 and 2.38 respectively
# At random state of :-  2 the root mean squared error of Testing and Training are:-  9.64 and 1.54 respectively
#
#
# At random state of :- 3 Testing Accuracy and Training Accuracy are:-  86.58 and 85.43 respectively
# At random state of :-  3 the mean absolute error of Testing and Training are:-  3.48 and 3.02 respectively
# At random state of :-  3 the mean squared error of Testing and Training are:-  21.28 and 3.02 respectively
# At random state of :-  3 the root mean squared error of Testing and Training are:-  4.61 and 1.74 respectively
#
#
# At random state of :- 4 Testing Accuracy and Training Accuracy are:-  90.81 and 85.25 respectively
# At random state of :-  4 the mean absolute error of Testing and Training are:-  1.79 and 3.09 respectively
# At random state of :-  4 the mean squared error of Testing and Training are:-  5.94 and 3.09 respectively
# At random state of :-  4 the root mean squared error of Testing and Training are:-  2.44 and 1.76 respectively
#
#
# At random state of :- 5 Testing Accuracy and Training Accuracy are:-  81.2 and 87.26 respectively
# At random state of :-  5 the mean absolute error of Testing and Training are:-  4.01 and 2.79 respectively
# At random state of :-  5 the mean squared error of Testing and Training are:-  21.34 and 2.79 respectively
# At random state of :-  5 the root mean squared error of Testing and Training are:-  4.62 and 1.67 respectively
#
#
# At random state of :- 6 Testing Accuracy and Training Accuracy are:-  74.77 and 88.64 respectively
# At random state of :-  6 the mean absolute error of Testing and Training are:-  4.83 and 2.56 respectively
# At random state of :-  6 the mean squared error of Testing and Training are:-  34.2 and 2.56 respectively
# At random state of :-  6 the root mean squared error of Testing and Training are:-  5.85 and 1.6 respectively
#
#
# At random state of :- 7 Testing Accuracy and Training Accuracy are:-  30.94 and 89.97 respectively
# At random state of :-  7 the mean absolute error of Testing and Training are:-  4.26 and 2.61 respectively
# At random state of :-  7 the mean squared error of Testing and Training are:-  30.77 and 2.61 respectively
# At random state of :-  7 the root mean squared error of Testing and Training are:-  5.55 and 1.62 respectively
#
#
# At random state of :- 8 Testing Accuracy and Training Accuracy are:-  88.68 and 85.08 respectively
# At random state of :-  8 the mean absolute error of Testing and Training are:-  3.56 and 2.83 respectively
# At random state of :-  8 the mean squared error of Testing and Training are:-  15.09 and 2.83 respectively
# At random state of :-  8 the root mean squared error of Testing and Training are:-  3.88 and 1.68 respectively
#
#
# At random state of :- 9 Testing Accuracy and Training Accuracy are:-  56.66 and 87.92 respectively
# At random state of :-  9 the mean absolute error of Testing and Training are:-  4.52 and 2.88 respectively
# At random state of :-  9 the mean squared error of Testing and Training are:-  27.08 and 2.88 respectively
# At random state of :-  9 the root mean squared error of Testing and Training are:-  5.2 and 1.7 respectively
#
#
# At random state of :- 10 Testing Accuracy and Training Accuracy are:-  39.25 and 87.89 respectively
# At random state of :-  10 the mean absolute error of Testing and Training are:-  4.09 and 3.18 respectively
# At random state of :-  10 the mean squared error of Testing and Training are:-  20.25 and 3.18 respectively
# At random state of :-  10 the root mean squared error of Testing and Training are:-  4.5 and 1.78 respectively
#
#
# At random state of :- 11 Testing Accuracy and Training Accuracy are:-  27.45 and 91.38 respectively
# At random state of :-  11 the mean absolute error of Testing and Training are:-  4.96 and 2.43 respectively
# At random state of :-  11 the mean squared error of Testing and Training are:-  40.57 and 2.43 respectively
# At random state of :-  11 the root mean squared error of Testing and Training are:-  6.37 and 1.56 respectively
#
#
# At random state of :- 12 Testing Accuracy and Training Accuracy are:-  -22.1 and 90.6 respectively
# At random state of :-  12 the mean absolute error of Testing and Training are:-  6.78 and 2.57 respectively
# At random state of :-  12 the mean squared error of Testing and Training are:-  56.03 and 2.57 respectively
# At random state of :-  12 the root mean squared error of Testing and Training are:-  7.49 and 1.6 respectively
#
#
# At random state of :- 13 Testing Accuracy and Training Accuracy are:-  51.98 and 91.67 respectively
# At random state of :-  13 the mean absolute error of Testing and Training are:-  4.88 and 2.32 respectively
# At random state of :-  13 the mean squared error of Testing and Training are:-  40.02 and 2.32 respectively
# At random state of :-  13 the root mean squared error of Testing and Training are:-  6.33 and 1.52 respectively
#
#
# At random state of :- 14 Testing Accuracy and Training Accuracy are:-  80.95 and 87.25 respectively
# At random state of :-  14 the mean absolute error of Testing and Training are:-  3.98 and 2.86 respectively
# At random state of :-  14 the mean squared error of Testing and Training are:-  20.56 and 2.86 respectively
# At random state of :-  14 the root mean squared error of Testing and Training are:-  4.53 and 1.69 respectively
#
#
# At random state of :- 15 Testing Accuracy and Training Accuracy are:-  66.14 and 87.18 respectively
# At random state of :-  15 the mean absolute error of Testing and Training are:-  5.15 and 2.73 respectively
# At random state of :-  15 the mean squared error of Testing and Training are:-  43.98 and 2.73 respectively
# At random state of :-  15 the root mean squared error of Testing and Training are:-  6.63 and 1.65 respectively
#
#
# At random state of :- 16 Testing Accuracy and Training Accuracy are:-  53.45 and 91.92 respectively
# At random state of :-  16 the mean absolute error of Testing and Training are:-  4.19 and 2.57 respectively
# At random state of :-  16 the mean squared error of Testing and Training are:-  32.8 and 2.57 respectively
# At random state of :-  16 the root mean squared error of Testing and Training are:-  5.73 and 1.6 respectively
#
#
# At random state of :- 17 Testing Accuracy and Training Accuracy are:-  80.62 and 86.65 respectively
# At random state of :-  17 the mean absolute error of Testing and Training are:-  4.39 and 2.66 respectively
# At random state of :-  17 the mean squared error of Testing and Training are:-  23.52 and 2.66 respectively
# At random state of :-  17 the root mean squared error of Testing and Training are:-  4.85 and 1.63 respectively
#
#
# At random state of :- 18 Testing Accuracy and Training Accuracy are:-  53.1 and 88.83 respectively
# At random state of :-  18 the mean absolute error of Testing and Training are:-  3.48 and 2.9 respectively
# At random state of :-  18 the mean squared error of Testing and Training are:-  20.23 and 2.9 respectively
# At random state of :-  18 the root mean squared error of Testing and Training are:-  4.5 and 1.7 respectively
#
#
# At random state of :- 19 Testing Accuracy and Training Accuracy are:-  75.98 and 88.11 respectively
# At random state of :-  19 the mean absolute error of Testing and Training are:-  3.56 and 2.72 respectively
# At random state of :-  19 the mean squared error of Testing and Training are:-  20.23 and 2.72 respectively
# At random state of :-  19 the root mean squared error of Testing and Training are:-  4.5 and 1.65 respectively
#
#
# At random state of :- 20 Testing Accuracy and Training Accuracy are:-  18.87 and 92.1 respectively
# At random state of :-  20 the mean absolute error of Testing and Training are:-  6.05 and 2.34 respectively
# At random state of :-  20 the mean squared error of Testing and Training are:-  38.94 and 2.34 respectively
# At random state of :-  20 the root mean squared error of Testing and Training are:-  6.24 and 1.53 respectively
#
#
# At random state of :- 21 Testing Accuracy and Training Accuracy are:-  73.76 and 88.54 respectively
# At random state of :-  21 the mean absolute error of Testing and Training are:-  3.89 and 2.76 respectively
# At random state of :-  21 the mean squared error of Testing and Training are:-  20.09 and 2.76 respectively
# At random state of :-  21 the root mean squared error of Testing and Training are:-  4.48 and 1.66 respectively
#
#
# At random state of :- 22 Testing Accuracy and Training Accuracy are:-  64.17 and 87.74 respectively
# At random state of :-  22 the mean absolute error of Testing and Training are:-  4.83 and 2.74 respectively
# At random state of :-  22 the mean squared error of Testing and Training are
respectively
#
#
# At random state of :- 183 Testing Accuracy and Training Accuracy are:-  -46.21 and 92.03 respectively
# At random state of :-  183 the mean absolute error of Testing and Training are:-  8.58 and 2.23 respectively
# At random state of :-  183 the mean squared error of Testing and Training are:-  91.99 and 2.23 respectively
# At random state of :-  183 the root mean squared error of Testing and Training are:-  9.59 and 1.49 respectively
#
#
# At random state of :- 184 Testing Accuracy and Training Accuracy are:-  -33.72 and 90.06 respectively
# At random state of :-  184 the mean absolute error of Testing and Training are:-  5.72 and 2.87 respectively
# At random state of :-  184 the mean squared error of Testing and Training are:-  38.19 and 2.87 respectively
# At random state of :-  184 the root mean squared error of Testing and Training are:-  6.18 and 1.69 respectively
#
#
# At random state of :- 185 Testing Accuracy and Training Accuracy are:-  60.05 and 88.96 respectively
# At random state of :-  185 the mean absolute error of Testing and Training are:-  6.28 and 2.61 respectively
# At random state of :-  185 the mean squared error of Testing and Training are:-  59.34 and 2.61 respectively
# At random state of :-  185 the root mean squared error of Testing and Training are:-  7.7 and 1.62 respectively
#
#
# At random state of :- 186 Testing Accuracy and Training Accuracy are:-  72.65 and 87.38 respectively
# At random state of :-  186 the mean absolute error of Testing and Training are:-  3.47 and 2.89 respectively
# At random state of :-  186 the mean squared error of Testing and Training are:-  18.66 and 2.89 respectively
# At random state of :-  186 the root mean squared error of Testing and Training are:-  4.32 and 1.7 respectively
#
#
# At random state of :- 187 Testing Accuracy and Training Accuracy are:-  37.78 and 91.02 respectively
# At random state of :-  187 the mean absolute error of Testing and Training are:-  4.92 and 2.66 respectively
# At random state of :-  187 the mean squared error of Testing and Training are:-  34.17 and 2.66 respectively
# At random state of :-  187 the root mean squared error of Testing and Training are:-  5.85 and 1.63 respectively
#
#
# At random state of :- 188 Testing Accuracy and Training Accuracy are:-  42.63 and 90.73 respectively
# At random state of :-  188 the mean absolute error of Testing and Training are:-  4.02 and 2.63 respectively
# At random state of :-  188 the mean squared error of Testing and Training are:-  36.53 and 2.63 respectively
# At random state of :-  188 the root mean squared error of Testing and Training are:-  6.04 and 1.62 respectively
#
#
# At random state of :- 189 Testing Accuracy and Training Accuracy are:-  85.77 and 85.28 respectively
# At random state of :-  189 the mean absolute error of Testing and Training are:-  3.22 and 2.85 respectively
# At random state of :-  189 the mean squared error of Testing and Training are:-  24.83 and 2.85 respectively
# At random state of :-  189 the root mean squared error of Testing and Training are:-  4.98 and 1.69 respectively
#
#
# At random state of :- 190 Testing Accuracy and Training Accuracy are:-  83.61 and 86.2 respectively
# At random state of :-  190 the mean absolute error of Testing and Training are:-  3.7 and 3.1 respectively
# At random state of :-  190 the mean squared error of Testing and Training are:-  19.94 and 3.1 respectively
# At random state of :-  190 the root mean squared error of Testing and Training are:-  4.47 and 1.76 respectively
#
#
# At random state of :- 191 Testing Accuracy and Training Accuracy are:-  83.14 and 87.8 respectively
# At random state of :-  191 the mean absolute error of Testing and Training are:-  3.51 and 2.68 respectively
# At random state of :-  191 the mean squared error of Testing and Training are:-  18.13 and 2.68 respectively
# At random state of :-  191 the root mean squared error of Testing and Training are:-  4.26 and 1.64 respectively
#
#
# At random state of :- 192 Testing Accuracy and Training Accuracy are:-  -9.62 and 90.18 respectively
# At random state of :-  192 the mean absolute error of Testing and Training are:-  5.14 and 2.46 respectively
# At random state of :-  192 the mean squared error of Testing and Training are:-  38.15 and 2.46 respectively
# At random state of :-  192 the root mean squared error of Testing and Training are:-  6.18 and 1.57 respectively
#
#
# At random state of :- 193 Testing Accuracy and Training Accuracy are:-  87.77 and 85.48 respectively
# At random state of :-  193 the mean absolute error of Testing and Training are:-  3.34 and 3.0 respectively
# At random state of :-  193 the mean squared error of Testing and Training are:-  16.79 and 3.0 respectively
# At random state of :-  193 the root mean squared error of Testing and Training are:-  4.1 and 1.73 respectively
#
#
# At random state of :- 194 Testing Accuracy and Training Accuracy are:-  -57.22 and 87.25 respectively
# At random state of :-  194 the mean absolute error of Testing and Training are:-  7.23 and 2.68 respectively
# At random state of :-  194 the mean squared error of Testing and Training are:-  72.67 and 2.68 respectively
# At random state of :-  194 the root mean squared error of Testing and Training are:-  8.52 and 1.64 respectively
#
#
# At random state of :- 195 Testing Accuracy and Training Accuracy are:-  78.47 and 87.89 respectively
# At random state of :-  195 the mean absolute error of Testing and Training are:-  3.73 and 2.89 respectively
# At random state of :-  195 the mean squared error of Testing and Training are:-  18.83 and 2.89 respectively
# At random state of :-  195 the root mean squared error of Testing and Training are:-  4.34 and 1.7 respectively
#
#
# At random state of :- 196 Testing Accuracy and Training Accuracy are:-  35.46 and 90.66 respectively
# At random state of :-  196 the mean absolute error of Testing and Training are:-  5.27 and 2.54 respectively
# At random state of :-  196 the mean squared error of Testing and Training are:-  33.99 and 2.54 respectively
# At random state of :-  196 the root mean squared error of Testing and Training are:-  5.83 and 1.6 respectively
#
#
# At random state of :- 197 Testing Accuracy and Training Accuracy are:-  74.56 and 88.61 respectively
# At random state of :-  197 the mean absolute error of Testing and Training are:-  3.77 and 2.55 respectively
# At random state of :-  197 the mean squared error of Testing and Training are:-  24.09 and 2.55 respectively
# At random state of :-  197 the root mean squared error of Testing and Training are:-  4.91 and 1.6 respectively
#
#
# At random state of :- 198 Testing Accuracy and Training Accuracy are:-  69.97 and 85.05 respectively
# At random state of :-  198 the mean absolute error of Testing and Training are:-  5.9 and 2.78 respectively
# At random state of :-  198 the mean squared error of Testing and Training are:-  37.04 and 2.78 respectively
# At random state of :-  198 the root mean squared error of Testing and Training are:-  6.09 and 1.67 respectively
#
#
# At random state of :- 199 Testing Accuracy and Training Accuracy are:-  71.37 and 88.09 respectively
# At random state of :-  199 the mean absolute error of Testing and Training are:-  5.08 and 2.59 respectively
# At random state of :-  199 the mean squared error of Testing and Training are:-  35.38 and 2.59 respectively
# At random state of :-  199 the root mean squared error of Testing and Training are:-  5.95 and 1.61 respectively

# %% [markdown]
# # using Ridge the model gives us as a performance of 95.54% at a random state of 162 without tuning the parameter
# At random state of :- 162 Testing Accuracy and Training Accuracy are:-  95.54 and 80.64 respectively
# At random state of :-  162 the mean absolute error of Testing and Training are:-  2.46 and 3.15 respectively
# At random state of :-  162 the mean squared error of Testing and Training are:-  9.24 and 3.15 respectively
# At random state of :-  162 the root mean squared error of Testing and Training are:-  3.04 and 1.78 respectively

# %% [markdown]
# # Using parameter tuning of alpha equals 200 we have the same accuracy
# At random state of :- 162 Testing Accuracy and Training Accuracy are:-  95.54 and 80.64 respectively
# At random state of :-  162 the mean absolute error of Testing and Training are:-  2.46 and 3.15 respectively
# At random state of :-  162 the mean squared error of Testing and Training are:-  9.24 and 3.15 respectively
# At random state of :-  162 the root mean squared error of Testing and Training are:-  3.04 and 1.78 respectively

# %% [markdown]
# From the above we can see:
# - Final Accuracy is 95.54% and RMSE is 3.04
# - That the ridge regression model has better performance
#
# HENCE WE CAN CONCLUDE OUR MODEL IS GOOD!!

# %% [markdown]
# # Step 8 - MODEL SAVING

# %%
filename='Machine_Model_Project_baseball'
pickle.dump(rr,open(filename,'wb'))
